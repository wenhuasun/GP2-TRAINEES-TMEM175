# %% [markdown]
# CTSB - Single gene analysis in GP2 Neurobooster genotyping data (all ancestries)

# %% [markdown]
# Project: GP2 CTSB
#
# Version: Python/3.10.15,  R/4.3.3

# %% [markdown]
# Notebook Overview
#
# 1. Description
# Loading Python libraries
# Set paths
# Make working directory
#
# 2. Installing packages
#
# 3. Create a covariate file with GP2 data
#
# 4. Annotation of the gene CTSB
#
# 5. Association analysis to compare allele frequencies between cases and controls
#
# 6. GLM analysis adjusting for gender, age, PC1-5
#
# 7. Burden test(SkatO, Skat, cmc,zeggini,mb,fp,cmcWald)
#
# 8. Conditional analysis

# %% [markdown]
# Loading Python libraries

# %%
# Use pathlib for file path manipulation
import pathlib

# Install numpy
import numpy as np

# Install Pandas for tabular data
import pandas as pd

# Install plotnine: a ggplot2-compatible Python plotting package
from plotnine import *

# Always show all columns in a Pandas DataFrame
pd.set_option('display.max_columns', None)

# %% [markdown]
# Set paths

# %%
REL7_PATH = pathlib.Path(pathlib.Path.home(), 'workspace/gp2_tier2_eu_release7_30042024')
# !ls -hal {REL7_PATH}
# Out:
# total 61K
# -r--r--r-- 1 jupyter jupyter 61K Jul 23  2024 README_release7_30042024.txt
# dr-xr-xr-x 1 jupyter jupyter   0 Jun 12 11:04 clinical_data
# dr-xr-xr-x 1 jupyter jupyter   0 Jun 12 11:04 imputed_genotypes
# dr-xr-xr-x 1 jupyter jupyter   0 Jun 12 11:04 meta_data
# dr-xr-xr-x 1 jupyter jupyter   0 Jun 12 11:04 raw_genotypes

# %% [markdown]
# Make working directory

# %%
WORK_DIR = "~/workspace/ws_files/CTSB/"

# %%
# make sure all tools installed
! ls /home/jupyter/tools
# Out:
# LICENSE		       plink2				rvtests
# annovar		       plink2_linux_x86_64_latest.zip	toy.map
# annovar.latest.tar.gz  plink_linux_x86_64_20190304.zip	toy.ped
# plink		       prettify

# %%
# give permission

# chmod to make sure you have permission to run the program
! chmod u+x /home/jupyter/tools/plink
! chmod u+x /home/jupyter/tools/plink2
! chmod 777 /home/jupyter/tools/rvtests/executable/rvtest

# %%
# %%bash
# # making working directory
# #Loop over all the ancestries
# for ancestry in {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'} ;
# do
#
# #Make a folder for each ancestry
# mkdir ~/workspace/ws_files/CTSB/CTSB_"$ancestry"
#
# done

# %% [markdown]
# Create a covariate file with GP2 data

# %%
CLINICAL_DATA_PATH = pathlib.Path(REL7_PATH, 'clinical_data/master_key_release7_final_vwb.csv')

# %%
# Let's load the master key
key = pd.read_csv(CLINICAL_DATA_PATH, low_memory=False)
print(key.shape)
key.head()

# %%
# Subsetting to keep only a few columns 
key = key[['GP2sampleID', 'baseline_GP2_phenotype_for_qc', 'biological_sex_for_qc', 'age_at_sample_collection', 'age_of_onset', 'label']]
# Renaming the columns
key.rename(columns = {'GP2sampleID':'IID',
                                     'baseline_GP2_phenotype_for_qc':'phenotype',
                                     'biological_sex_for_qc':'SEX', 
                                     'age_at_sample_collection':'AGE', 
                                     'age_of_onset':'AAO'}, inplace = True)
key

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    ## Subset to keep ancestry of interest 
    ancestry_key = key[key['label']==ancestry].copy()
    ancestry_key.reset_index(drop=True)
    
    # Load information about related individuals in the ancestry analyzed
    related_df = pd.read_csv(f'{REL7_PATH}/meta_data/related_samples/{ancestry}_release7_vwb.related')
    print(f'Related individuals: {related_df.shape}')
    
    # Make a list of just one set of related people
    related_list = list(related_df['IID1'])
    
    # Check value counts of related and remove only one related individual
    ancestry_key = ancestry_key[~ancestry_key["IID"].isin(related_list)]
    
    # Check size
    print(f'Unrelated individuals: {ancestry_key.shape}')
    
    # Convert phenotype to binary (1/2)
    ## Assign conditions so case=2 and controls=1, and -9 otherwise (matching PLINK convention)
    # PD = 2; control = 1
    pheno_mapping = {"PD": 2, "Control": 1}
    ancestry_key['PHENO'] = ancestry_key['phenotype'].map(pheno_mapping).astype('Int64')
    
    # Check value counts of pheno
    ancestry_key['PHENO'].value_counts(dropna=False)
    
    ## Get the PCs
    pcs = pd.read_csv(f'{REL7_PATH}/meta_data/qc_metrics/projected_pcs_vwb.csv')
    
    #Select just first 5 PCs
    selected_columns = ['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5']
    pcs = pd.DataFrame(data=pcs.iloc[:, 1:7].values, columns=selected_columns)
    
    # Drop the first row (since it's now the column names)
    pcs = pcs.drop(0)
    
    # Reset the index to remove any potential issues
    pcs = pcs.reset_index(drop=True)
    
    # Check size
    print(f'PCs: {pcs.shape}')
    
    # Check value counts of SEX
    sex_og_values = ancestry_key['SEX'].value_counts(dropna=False)
    print(f'Sex value counts - original:\n {sex_og_values.to_string()}')
    
    # Convert sex to binary (1/2)
    ## Assign conditions so female=2 and men=1, and -9 otherwise (matching PLINK convention)
    # Female = 2; Male = 1
    sex_mapping = {"Female": 2, "Male": 1}
    ancestry_key['SEX'] = ancestry_key['SEX'].map(sex_mapping).astype('Int64')
    
    # Check value counts of SEX after recoding
    sex_recode_values = ancestry_key['SEX'].value_counts(dropna=False)
    print(f'Sex value counts - recoded:\n{sex_recode_values.to_string()}')
    
    ## Make covariate file
    df = pd.merge(pcs, ancestry_key, on='IID', how='left')
    print(f'Check columns for covariate file: {df.columns}')
    
    #Make additional columns - FID, fatid and matid - these are needed for RVtests!!
    #RVtests needs the first 5 columns to be fid, iid, fatid, matid and sex otherwise it does not run correctly
    #Uppercase column name is ok
    #See https://zhanxw.github.io/rvtests/#phenotype-file
    df['FID'] = 0
    df['FATID'] = 0
    df['MATID'] = 0
    
    ## Clean up and keep columns we need 
    final_df = df[['FID','IID', 'FATID', 'MATID', 'SEX', 'AGE', 'PHENO','PC1', 'PC2', 'PC3', 'PC4', 'PC5']].copy()
    
    ##DO NOT replace missing values with -9 as this is misinterpreted by RVtests - needs to be nonnumeric
    #Leave missing values as NA
    
    #Check number of PD cases missing age
    pd_missAge = final_df[(final_df['PHENO']==2)&(final_df['AGE'].isna())]
    print(f'Number of PD cases missing age: {pd_missAge.shape[0]}')
    
    #Check number of controls missing age
    control_missAge = final_df[(final_df['PHENO']==1)&(final_df['AGE'].isna())]
    print(f'Number of controls missing age: {control_missAge.shape[0]}')
    
    ## Make file of sample IDs to keep 
    samples_toKeep = final_df[['FID', 'IID']].copy()
    samples_toKeep.to_csv(f'~/workspace/ws_files/CTSB/CTSB_{ancestry}/{ancestry}.samplestoKeep', sep = '\t', index=False, header=None)
    
    ## Make your covariate file
    #Included na_rep to write out missing/NA values explicitly as string/text, not as blank otherwise they are misread in RVtests
    final_df.to_csv(f'~/workspace/ws_files/CTSB/CTSB_{ancestry}/{ancestry}_covariate_file.txt', sep = '\t', na_rep='NA', index=False)
# Out:
# WORKING ON: AJ
# Related individuals: (245, 9)
# Unrelated individuals: (2675, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          1655
# Female                        1009
# Other/Unknown/Not Reported      11
# Sex value counts - recoded:
# SEX
# 1       1655
# 2       1009
# <NA>      11
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 95
# Number of controls missing age: 195
# WORKING ON: MDE
# Related individuals: (19, 9)
# Unrelated individuals: (589, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          368
# Female                        219
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 1       368
# 2       219
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 140
# Number of controls missing age: 12
# WORKING ON: EAS
# Related individuals: (350, 9)
# Unrelated individuals: (5303, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          3398
# Female                        1899
# Other/Unknown/Not Reported       6
# Sex value counts - recoded:
# SEX
# 1       3398
# 2       1899
# <NA>       6
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 1349
# Number of controls missing age: 1268
# WORKING ON: AMR
# Related individuals: (51, 9)
# Unrelated individuals: (672, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          374
# Female                        296
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 1       374
# 2       296
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 106
# Number of controls missing age: 55
# WORKING ON: CAS
# Related individuals: (137, 9)
# Unrelated individuals: (933, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female    483
# Male      450
# Sex value counts - recoded:
# SEX
# 2    483
# 1    450
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 111
# Number of controls missing age: 88
# WORKING ON: FIN
# Related individuals: (7, 9)
# Unrelated individuals: (117, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female    63
# Male      54
# Sex value counts - recoded:
# SEX
# 2    63
# 1    54
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 62
# Number of controls missing age: 3
# WORKING ON: CAH
# Related individuals: (65, 9)
# Unrelated individuals: (1108, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          585
# Female                        498
# Other/Unknown/Not Reported     25
# Sex value counts - recoded:
# SEX
# 1       585
# 2       498
# <NA>     25
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 136
# Number of controls missing age: 52
# WORKING ON: SAS
# Related individuals: (55, 9)
# Unrelated individuals: (624, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          397
# Female                        226
# Other/Unknown/Not Reported      1
# Sex value counts - recoded:
# SEX
# 1       397
# 2       226
# <NA>      1
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 203
# Number of controls missing age: 83
# WORKING ON: AFR
# Related individuals: (228, 9)
# Unrelated individuals: (2752, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          1553
# Female                        1197
# Other/Unknown/Not Reported       2
# Sex value counts - recoded:
# SEX
# 1       1553
# 2       1197
# <NA>       2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 835
# Number of controls missing age: 809
# WORKING ON: EUR
# Related individuals: (3662, 9)
# Unrelated individuals: (39710, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          23733
# Female                        15784
# Other/Unknown/Not Reported      193
# Sex value counts - recoded:
# SEX
# 1       23733
# 2       15784
# <NA>      193
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 5947
# Number of controls missing age: 3347
# WORKING ON: AAC
# Related individuals: (28, 9)
# Unrelated individuals: (1181, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female                        690
# Male                          489
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 2       690
# 1       489
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 91
# Number of controls missing age: 96

# %% [markdown]
# Annotation of the gene
#
# Extract the region using PLINK
#
# Extract CTSB gene
#
# CTSB coordinates: Chromosome 8: 11,842,524-11,869,533(GRCh38/hg38)

# %%
## extract region using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --pfile {REL7_PATH}/imputed_genotypes/{ancestry}/chr8_{ancestry}_release7_vwb \
    --chr 8 \
    --from-bp 11792524 \
    --to-bp 11919533 \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_CTSB
# Out:
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr8_AJ_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:05:56 2025
# 12984 MiB RAM detected, ~11272 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr8_AJ_release7_vwb.psam.
# 1308065 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr8_AJ_release7_vwb.pvar.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# 2136 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bed ... done.
# End time: Thu Jun 12 11:05:58 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr8_MDE_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:05:58 2025
# 12984 MiB RAM detected, ~11265 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr8_MDE_release7_vwb.psam.
# 1708855 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr8_MDE_release7_vwb.pvar.
# 1 binary phenotype loaded (311 cases, 225 controls).
# 2545 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:01 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr8_EAS_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:01 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr8_EAS_release7_vwb.psam.
# 2581801 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr8_EAS_release7_vwb.pvar.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# 4081 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bed ... 91done.
# End time: Thu Jun 12 11:06:05 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr8_AMR_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:05 2025
# 12984 MiB RAM detected, ~11252 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr8_AMR_release7_vwb.psam.
# 1937056 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr8_AMR_release7_vwb.pvar.
# 1 binary phenotype loaded (458 cases, 155 controls).
# 3038 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:09 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr8_CAS_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:09 2025
# 12984 MiB RAM detected, ~11255 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr8_CAS_release7_vwb.psam.
# 1742361 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr8_CAS_release7_vwb.pvar.
# 1 binary phenotype loaded (552 cases, 343 controls).
# 2607 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:12 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr8_FIN_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:12 2025
# 12984 MiB RAM detected, ~11257 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr8_FIN_release7_vwb.psam.
# 678945 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr8_FIN_release7_vwb.pvar.
# 1 binary phenotype loaded (98 cases, 8 controls).
# 1007 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:13 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr8_CAH_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:14 2025
# 12984 MiB RAM detected, ~11252 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr8_CAH_release7_vwb.psam.
# 2931233 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr8_CAH_release7_vwb.pvar.
# 1 binary phenotype loaded (525 cases, 302 controls).
# 4946 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:17 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr8_SAS_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:18 2025
# 12984 MiB RAM detected, ~11253 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr8_SAS_release7_vwb.psam.
# 1515719 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr8_SAS_release7_vwb.pvar.
# 1 binary phenotype loaded (387 cases, 222 controls).
# 2446 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:20 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr8_AFR_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:20 2025
# 12984 MiB RAM detected, ~11254 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr8_AFR_release7_vwb.psam.
# 3638791 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr8_AFR_release7_vwb.pvar.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# 6381 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bed ... 63done.
# End time: Thu Jun 12 11:06:24 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr8_EUR_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:24 2025
# 12984 MiB RAM detected, ~11255 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr8_EUR_release7_vwb.psam.
# 8334722 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr8_EUR_release7_vwb.pvar.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# 13481 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bed ... done.
# End time: Thu Jun 12 11:06:34 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr8_AAC_release7_vwb
#   --to-bp 11919533
#
# Start time: Thu Jun 12 11:06:35 2025
# 12984 MiB RAM detected, ~11250 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr8_AAC_release7_vwb.psam.
# 3182900 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr8_AAC_release7_vwb.pvar.
# 1 binary phenotype loaded (285 cases, 801 controls).
# 5351 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bed ... 65done.
# End time: Thu Jun 12 11:06:38 2025

# %%
# Visualize bim file
WORK_DIR = '/home/jupyter/workspace/ws_files/CTSB/'
! head {WORK_DIR}/CTSB_EUR/EUR_CTSB.bim
# Out:
# 8	chr8:11792554:C:T	0	11792554	T	C
# 8	chr8:11792575:T:C	0	11792575	C	T
# 8	chr8:11792593:T:G	0	11792593	G	T
# 8	chr8:11792594:C:G	0	11792594	G	C
# 8	chr8:11792658:C:G	0	11792658	G	C
# 8	chr8:11792660:C:G	0	11792660	G	C
# 8	chr8:11792663:T:C	0	11792663	C	T
# 8	chr8:11792668:T:G	0	11792668	G	T
# 8	chr8:11792679:G:C	0	11792679	C	G
# 8	chr8:11792680:C:T	0	11792680	T	C

# %%
# Visualize bim file
! head {WORK_DIR}/CTSB_EUR/EUR_CTSB.fam

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}/'
    
    ! head -n 1 {WORK_DIR}/{ancestry}_CTSB.fam > {WORK_DIR}/{ancestry}_s1.txt

# %%
! head /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_s1.txt

# %% [markdown]
# Turn binary files into VCF

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep {WORK_DIR}/{ancestry}_s1.txt \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_CTSB_v1
# Out:
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#
# Start time: Thu Jun 12 11:13:41 2025
# 12984 MiB RAM detected, ~11262 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam.
# 2136 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.fam ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bim ... done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bed ... done.
# End time: Thu Jun 12 11:13:41 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#
# Start time: Thu Jun 12 11:13:42 2025
# 12984 MiB RAM detected, ~11244 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam.
# 2545 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:42 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#
# Start time: Thu Jun 12 11:13:43 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam.
# 4081 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:43 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#
# Start time: Thu Jun 12 11:13:44 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam.
# 3038 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:45 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#
# Start time: Thu Jun 12 11:13:45 2025
# 12984 MiB RAM detected, ~11244 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam.
# 2607 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:46 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#
# Start time: Thu Jun 12 11:13:46 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam.
# 1007 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:47 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#
# Start time: Thu Jun 12 11:13:47 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam.
# 4946 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:48 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#
# Start time: Thu Jun 12 11:13:48 2025
# 12984 MiB RAM detected, ~11245 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam.
# 2446 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:49 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#
# Start time: Thu Jun 12 11:13:49 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam.
# 6381 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:50 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#
# Start time: Thu Jun 12 11:13:50 2025
# 12984 MiB RAM detected, ~11243 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam.
# 13481 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:51 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#
# Start time: Thu Jun 12 11:13:51 2025
# 12984 MiB RAM detected, ~11244 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam.
# 5351 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bed ...
# done.
# End time: Thu Jun 12 11:13:52 2025

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB_v1 \
    --recode vcf-fid \
    --out {WORK_DIR}/{ancestry}_CTSB_v1
# Out:
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#
# Start time: Thu Jun 12 11:18:34 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11295 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.fam.
# 2136 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:34 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#
# Start time: Thu Jun 12 11:18:34 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11264 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.fam.
# 2545 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:34 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#
# Start time: Thu Jun 12 11:18:35 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11250 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.fam.
# 4081 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:35 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#
# Start time: Thu Jun 12 11:18:35 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.fam.
# 3038 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:36 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#
# Start time: Thu Jun 12 11:18:36 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.fam.
# 2607 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:36 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#
# Start time: Thu Jun 12 11:18:37 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11249 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.fam.
# 1007 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:37 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#
# Start time: Thu Jun 12 11:18:37 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.fam.
# 4946 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:37 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#
# Start time: Thu Jun 12 11:18:38 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.fam.
# 2446 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:38 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#
# Start time: Thu Jun 12 11:18:38 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11250 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.fam.
# 6381 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:38 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#
# Start time: Thu Jun 12 11:18:39 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.fam.
# 13481 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:39 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#
# Start time: Thu Jun 12 11:18:39 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 12984 MiB RAM detected, ~11248 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.fam.
# 5351 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.vcf
# ... .
# End time: Thu Jun 12 11:18:40 2025

# %%
### Bgzip and Tabix (zip and index the file)
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    ! bgzip -f {WORK_DIR}/{ancestry}_CTSB_v1.vcf
    ! tabix -f -p vcf {WORK_DIR}/{ancestry}_CTSB_v1.vcf.gz

# %% [markdown]
# Annotate using ANNOVAR

# %%
## annotate using ANNOVAR

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ! perl /home/jupyter/tools/annovar/table_annovar.pl {WORK_DIR}/{ancestry}_CTSB_v1.vcf.gz /home/jupyter/tools/annovar/humandb/ -buildver hg38 \
    -out {WORK_DIR}/{ancestry}_CTSB.annovar \
    -remove -protocol refGene,clinvar_20140902 \
    -operation g,f \
    --nopolish \
    -nastring . \
    -vcfinput
# Out:
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput>
# NOTICE: Finished reading 2143 lines from VCF file
# NOTICE: A total of 2136 locus in VCF file passed QC threshold, representing 2024 SNPs (1187 transitions and 837 transversions) and 112 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2024 SNP genotypes (1187 transitions and 837 transversions) and 112 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2136 unique variants in 2136 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2136 unique variants in 2136 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput>
# NOTICE: Finished reading 2552 lines from VCF file
# NOTICE: A total of 2545 locus in VCF file passed QC threshold, representing 2405 SNPs (1425 transitions and 980 transversions) and 140 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2405 SNP genotypes (1425 transitions and 980 transversions) and 140 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2545 unique variants in 2545 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2545 unique variants in 2545 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 4088 lines from VCF file
# NOTICE: A total of 4081 locus in VCF file passed QC threshold, representing 3845 SNPs (2286 transitions and 1559 transversions) and 236 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3845 SNP genotypes (2286 transitions and 1559 transversions) and 236 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 4081 unique variants in 4081 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 4081 unique variants in 4081 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput>
# NOTICE: Finished reading 3045 lines from VCF file
# NOTICE: A total of 3038 locus in VCF file passed QC threshold, representing 2881 SNPs (1734 transitions and 1147 transversions) and 157 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2881 SNP genotypes (1734 transitions and 1147 transversions) and 157 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3038 unique variants in 3038 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3038 unique variants in 3038 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 2614 lines from VCF file
# NOTICE: A total of 2607 locus in VCF file passed QC threshold, representing 2466 SNPs (1460 transitions and 1006 transversions) and 141 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2466 SNP genotypes (1460 transitions and 1006 transversions) and 141 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2607 unique variants in 2607 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2607 unique variants in 2607 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput>
# NOTICE: Finished reading 1014 lines from VCF file
# NOTICE: A total of 1007 locus in VCF file passed QC threshold, representing 958 SNPs (590 transitions and 368 transversions) and 49 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 958 SNP genotypes (590 transitions and 368 transversions) and 49 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 1007 unique variants in 1007 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 1007 unique variants in 1007 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput>
# NOTICE: Finished reading 4953 lines from VCF file
# NOTICE: A total of 4946 locus in VCF file passed QC threshold, representing 4675 SNPs (2717 transitions and 1958 transversions) and 271 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 4675 SNP genotypes (2717 transitions and 1958 transversions) and 271 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 4946 unique variants in 4946 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 4946 unique variants in 4946 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 2453 lines from VCF file
# NOTICE: A total of 2446 locus in VCF file passed QC threshold, representing 2306 SNPs (1402 transitions and 904 transversions) and 140 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2306 SNP genotypes (1402 transitions and 904 transversions) and 140 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2446 unique variants in 2446 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2446 unique variants in 2446 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput>
# NOTICE: Finished reading 6388 lines from VCF file
# NOTICE: A total of 6381 locus in VCF file passed QC threshold, representing 6026 SNPs (3477 transitions and 2549 transversions) and 355 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 6026 SNP genotypes (3477 transitions and 2549 transversions) and 355 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 6381 unique variants in 6381 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 6381 unique variants in 6381 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput>
# NOTICE: Finished reading 13488 lines from VCF file
# NOTICE: A total of 13481 locus in VCF file passed QC threshold, representing 12749 SNPs (7496 transitions and 5253 transversions) and 732 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 12749 SNP genotypes (7496 transitions and 5253 transversions) and 732 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 13481 unique variants in 13481 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 13481 unique variants in 13481 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput>
# NOTICE: Finished reading 5358 lines from VCF file
# NOTICE: A total of 5351 locus in VCF file passed QC threshold, representing 5053 SNPs (2874 transitions and 2179 transversions) and 298 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 5053 SNP genotypes (2874 transitions and 2179 transversions) and 298 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 5351 unique variants in 5351 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 5351 unique variants in 5351 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe

# %%
WORK_DIR = "/home/jupyter/workspace/ws_files/CTSB"

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792650  11792650   G   T   intergenic   NEIL2;FDFT1
# 2       8  11792688  11792688   G   C   intergenic   NEIL2;FDFT1
# 3       8  11792691  11792691   C   T   intergenic   NEIL2;FDFT1
# 4       8  11792730  11792730   C   A   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 5346    8  11919417  11919417   T   C   intergenic  CTSB;DEFB136
# 5347    8  11919431  11919431   T   C   intergenic  CTSB;DEFB136
# 5348    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
# 5349    8  11919498  11919498   C   G   intergenic  CTSB;DEFB136
# 5350    8  11919512  11919512   T   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5305;dist=2923                  .                .
# 2       dist=5343;dist=2885                  .                .
# 3       dist=5346;dist=2882                  .                .
# 4       dist=5385;dist=2843                  .                .
# ...                     ...                ...              ...
# 5346  dist=51330;dist=54520                  .                .
# 5347  dist=51344;dist=54506                  .                .
# 5348  dist=51363;dist=54487                  .                .
# 5349  dist=51411;dist=54439                  .                .
# 5350  dist=51425;dist=54425                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 5346                .          0          .          .           8
# 5347                .          0          .          .           8
# 5348                .          0          .          .           8
# 5349                .          0          .          .           8
# 5350                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792650  chr8:11792650:G:T          G          T          .
# 2       11792688  chr8:11792688:G:C          G          C          .
# 3       11792691  chr8:11792691:C:T          C          T          .
# 4       11792730  chr8:11792730:C:A          C          A          .
# ...          ...                ...        ...        ...        ...
# 5346    11919417  chr8:11919417:T:C          T          C          .
# 5347    11919431  chr8:11919431:T:C          T          C          .
# 5348    11919450  chr8:11919450:G:C          G          C          .
# 5349    11919498  chr8:11919498:C:G          C          G          .
# 5350    11919512  chr8:11919512:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 5346           .          PR          GT         0/0
# 5347           .          PR          GT         0/0
# 5348           .          PR          GT         0/0
# 5349           .          PR          GT         0/0
# 5350           .          PR          GT         0/0
#
# [5351 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2872
# intergenic    1816
# UTR5           193
# UTR3           178
# upstream       108
# downstream     104
# exonic          78
# splicing         2
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# synonymous SNV       39
# nonsynonymous SNV    38
# stopgain              1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792594  11792594   C   A   intergenic   NEIL2;FDFT1
# 2       8  11792594  11792594   C   G   intergenic   NEIL2;FDFT1
# 3       8  11792691  11792691   C   T   intergenic   NEIL2;FDFT1
# 4       8  11792730  11792730   C   A   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 6376    8  11919417  11919417   T   C   intergenic  CTSB;DEFB136
# 6377    8  11919431  11919431   T   C   intergenic  CTSB;DEFB136
# 6378    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
# 6379    8  11919454  11919454   T   C   intergenic  CTSB;DEFB136
# 6380    8  11919512  11919512   T   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5249;dist=2979                  .                .
# 2       dist=5249;dist=2979                  .                .
# 3       dist=5346;dist=2882                  .                .
# 4       dist=5385;dist=2843                  .                .
# ...                     ...                ...              ...
# 6376  dist=51330;dist=54520                  .                .
# 6377  dist=51344;dist=54506                  .                .
# 6378  dist=51363;dist=54487                  .                .
# 6379  dist=51367;dist=54483                  .                .
# 6380  dist=51425;dist=54425                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 6376                .          0          .          .           8
# 6377                .          0          .          .           8
# 6378                .          0          .          .           8
# 6379                .          0          .          .           8
# 6380                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792594  chr8:11792594:C:A          C          A          .
# 2       11792594  chr8:11792594:C:G          C          G          .
# 3       11792691  chr8:11792691:C:T          C          T          .
# 4       11792730  chr8:11792730:C:A          C          A          .
# ...          ...                ...        ...        ...        ...
# 6376    11919417  chr8:11919417:T:C          T          C          .
# 6377    11919431  chr8:11919431:T:C          T          C          .
# 6378    11919450  chr8:11919450:G:C          G          C          .
# 6379    11919454  chr8:11919454:T:C          T          C          .
# 6380    11919512  chr8:11919512:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 6376           .          PR          GT         0/0
# 6377           .          PR          GT         0/0
# 6378           .          PR          GT         0/0
# 6379           .          PR          GT         0/0
# 6380           .          PR          GT         0/0
#
# [6381 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      3425
# intergenic    2182
# UTR5           240
# UTR3           203
# upstream       119
# downstream     119
# exonic          92
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    51
# synonymous SNV       41
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End      Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575        T   C   intergenic   NEIL2;FDFT1
# 1       8  11792661  11792662       TT   -   intergenic   NEIL2;FDFT1
# 2       8  11792812  11792812        C   T   intergenic   NEIL2;FDFT1
# 3       8  11792935  11792941  ATTAAGT   -   intergenic   NEIL2;FDFT1
# 4       8  11792966  11792966        T   C   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...      ...  ..          ...           ...
# 2131    8  11918972  11918972        G   A   intergenic  CTSB;DEFB136
# 2132    8  11919062  11919062        A   G   intergenic  CTSB;DEFB136
# 2133    8  11919200  11919200        G   A   intergenic  CTSB;DEFB136
# 2134    8  11919223  11919223        G   A   intergenic  CTSB;DEFB136
# 2135    8  11919450  11919450        G   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5316;dist=2911                  .                .
# 2       dist=5467;dist=2761                  .                .
# 3       dist=5590;dist=2632                  .                .
# 4       dist=5621;dist=2607                  .                .
# ...                     ...                ...              ...
# 2131  dist=50885;dist=54965                  .                .
# 2132  dist=50975;dist=54875                  .                .
# 2133  dist=51113;dist=54737                  .                .
# 2134  dist=51136;dist=54714                  .                .
# 2135  dist=51363;dist=54487                  .                .
#
#      clinvar_20140902  Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .         0.0          .          .           8
# 1                   .         0.0          .          .           8
# 2                   .         0.0          .          .           8
# 3                   .         0.0          .          .           8
# 4                   .         0.0          .          .           8
# ...               ...         ...        ...        ...         ...
# 2131                .         0.0          .          .           8
# 2132                .         0.0          .          .           8
# 2133                .         0.0          .          .           8
# 2134                .         0.0          .          .           8
# 2135                .         0.0          .          .           8
#
#       Otherinfo5                Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575         chr8:11792575:T:C          T          C          .
# 1       11792660       chr8:11792660:CTT:C        CTT          C          .
# 2       11792812         chr8:11792812:C:T          C          T          .
# 3       11792934  chr8:11792934:AATTAAGT:A   AATTAAGT          A          .
# 4       11792966         chr8:11792966:T:C          T          C          .
# ...          ...                       ...        ...        ...        ...
# 2131    11918972         chr8:11918972:G:A          G          A          .
# 2132    11919062         chr8:11919062:A:G          A          G          .
# 2133    11919200         chr8:11919200:G:A          G          A          .
# 2134    11919223         chr8:11919223:G:A          G          A          .
# 2135    11919450         chr8:11919450:G:C          G          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2131           .          PR          GT         0/0
# 2132           .          PR          GT         0/0
# 2133           .          PR          GT         0/0
# 2134           .          PR          GT         0/0
# 2135           .          PR          GT         0/0
#
# [2136 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1131
# intergenic     720
# UTR5            94
# UTR3            65
# downstream      49
# upstream        46
# exonic          31
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    22
# synonymous SNV        9
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792619  11792619   C   T   intergenic   NEIL2;FDFT1
# 2       8  11792691  11792691   C   T   intergenic   NEIL2;FDFT1
# 3       8  11792730  11792730   C   A   intergenic   NEIL2;FDFT1
# 4       8  11792798  11792798   G   A   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 3033    8  11919279  11919279   A   G   intergenic  CTSB;DEFB136
# 3034    8  11919300  11919300   G   T   intergenic  CTSB;DEFB136
# 3035    8  11919311  11919311   C   T   intergenic  CTSB;DEFB136
# 3036    8  11919332  11919332   C   T   intergenic  CTSB;DEFB136
# 3037    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5274;dist=2954                  .                .
# 2       dist=5346;dist=2882                  .                .
# 3       dist=5385;dist=2843                  .                .
# 4       dist=5453;dist=2775                  .                .
# ...                     ...                ...              ...
# 3033  dist=51192;dist=54658                  .                .
# 3034  dist=51213;dist=54637                  .                .
# 3035  dist=51224;dist=54626                  .                .
# 3036  dist=51245;dist=54605                  .                .
# 3037  dist=51363;dist=54487                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 3033                .          0          .          .           8
# 3034                .          0          .          .           8
# 3035                .          0          .          .           8
# 3036                .          0          .          .           8
# 3037                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792619  chr8:11792619:C:T          C          T          .
# 2       11792691  chr8:11792691:C:T          C          T          .
# 3       11792730  chr8:11792730:C:A          C          A          .
# 4       11792798  chr8:11792798:G:A          G          A          .
# ...          ...                ...        ...        ...        ...
# 3033    11919279  chr8:11919279:A:G          A          G          .
# 3034    11919300  chr8:11919300:G:T          G          T          .
# 3035    11919311  chr8:11919311:C:T          C          T          .
# 3036    11919332  chr8:11919332:C:T          C          T          .
# 3037    11919450  chr8:11919450:G:C          G          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 3033           .          PR          GT         0/0
# 3034           .          PR          GT         0/0
# 3035           .          PR          GT         0/0
# 3036           .          PR          GT         0/0
# 3037           .          PR          GT         0/0
#
# [3038 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1621
# intergenic    1016
# UTR5           118
# UTR3            97
# downstream      78
# exonic          55
# upstream        53
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    35
# synonymous SNV       20
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792594  11792594   C   G   intergenic   NEIL2;FDFT1
# 2       8  11792691  11792691   C   T   intergenic   NEIL2;FDFT1
# 3       8  11792713  11792713   T   C   intergenic   NEIL2;FDFT1
# 4       8  11792730  11792730   C   A   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 4941    8  11919376  11919376   A   T   intergenic  CTSB;DEFB136
# 4942    8  11919387  11919387   G   A   intergenic  CTSB;DEFB136
# 4943    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
# 4944    8  11919508  11919508   C   G   intergenic  CTSB;DEFB136
# 4945    8  11919512  11919512   T   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5249;dist=2979                  .                .
# 2       dist=5346;dist=2882                  .                .
# 3       dist=5368;dist=2860                  .                .
# 4       dist=5385;dist=2843                  .                .
# ...                     ...                ...              ...
# 4941  dist=51289;dist=54561                  .                .
# 4942  dist=51300;dist=54550                  .                .
# 4943  dist=51363;dist=54487                  .                .
# 4944  dist=51421;dist=54429                  .                .
# 4945  dist=51425;dist=54425                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 4941                .          0          .          .           8
# 4942                .          0          .          .           8
# 4943                .          0          .          .           8
# 4944                .          0          .          .           8
# 4945                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792594  chr8:11792594:C:G          C          G          .
# 2       11792691  chr8:11792691:C:T          C          T          .
# 3       11792713  chr8:11792713:T:C          T          C          .
# 4       11792730  chr8:11792730:C:A          C          A          .
# ...          ...                ...        ...        ...        ...
# 4941    11919376  chr8:11919376:A:T          A          T          .
# 4942    11919387  chr8:11919387:G:A          G          A          .
# 4943    11919450  chr8:11919450:G:C          G          C          .
# 4944    11919508  chr8:11919508:C:G          C          G          .
# 4945    11919512  chr8:11919512:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 4941           .          PR          GT         0/0
# 4942           .          PR          GT         0/0
# 4943           .          PR          GT         0/0
# 4944           .          PR          GT         0/0
# 4945           .          PR          GT         0/0
#
# [4946 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2646
# intergenic    1677
# UTR5           192
# UTR3           154
# downstream     106
# upstream        92
# exonic          78
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV      40
# synonymous SNV         37
# frameshift deletion     1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792660  11792660   C   G   intergenic   NEIL2;FDFT1
# 2       8  11792688  11792688   G   C   intergenic   NEIL2;FDFT1
# 3       8  11792784  11792784   G   A   intergenic   NEIL2;FDFT1
# 4       8  11792794  11792794   T   C   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 2602    8  11919223  11919223   G   A   intergenic  CTSB;DEFB136
# 2603    8  11919310  11919310   C   G   intergenic  CTSB;DEFB136
# 2604    8  11919373  11919373   C   T   intergenic  CTSB;DEFB136
# 2605    8  11919399  11919399   C   A   intergenic  CTSB;DEFB136
# 2606    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5315;dist=2913                  .                .
# 2       dist=5343;dist=2885                  .                .
# 3       dist=5439;dist=2789                  .                .
# 4       dist=5449;dist=2779                  .                .
# ...                     ...                ...              ...
# 2602  dist=51136;dist=54714                  .                .
# 2603  dist=51223;dist=54627                  .                .
# 2604  dist=51286;dist=54564                  .                .
# 2605  dist=51312;dist=54538                  .                .
# 2606  dist=51363;dist=54487                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 2602                .          0          .          .           8
# 2603                .          0          .          .           8
# 2604                .          0          .          .           8
# 2605                .          0          .          .           8
# 2606                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792660  chr8:11792660:C:G          C          G          .
# 2       11792688  chr8:11792688:G:C          G          C          .
# 3       11792784  chr8:11792784:G:A          G          A          .
# 4       11792794  chr8:11792794:T:C          T          C          .
# ...          ...                ...        ...        ...        ...
# 2602    11919223  chr8:11919223:G:A          G          A          .
# 2603    11919310  chr8:11919310:C:G          C          G          .
# 2604    11919373  chr8:11919373:C:T          C          T          .
# 2605    11919399  chr8:11919399:C:A          C          A          .
# 2606    11919450  chr8:11919450:G:C          G          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2602           .          PR          GT         0/0
# 2603           .          PR          GT         0/0
# 2604           .          PR          GT         0/0
# 2605           .          PR          GT         0/0
# 2606           .          PR          GT         0/0
#
# [2607 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1373
# intergenic     873
# UTR5           113
# UTR3            93
# downstream      54
# upstream        53
# exonic          47
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    31
# synonymous SNV       16
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792657  11792657   C   T   intergenic   NEIL2;FDFT1
# 2       8  11792660  11792660   C   G   intergenic   NEIL2;FDFT1
# 3       8  11792690  11792690   C   G   intergenic   NEIL2;FDFT1
# 4       8  11792717  11792717   C   T   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 4076    8  11919319  11919319   C   A   intergenic  CTSB;DEFB136
# 4077    8  11919359  11919359   G   C   intergenic  CTSB;DEFB136
# 4078    8  11919433  11919433   C   T   intergenic  CTSB;DEFB136
# 4079    8  11919510  11919510   C   T   intergenic  CTSB;DEFB136
# 4080    8  11919532  11919532   T   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5312;dist=2916                  .                .
# 2       dist=5315;dist=2913                  .                .
# 3       dist=5345;dist=2883                  .                .
# 4       dist=5372;dist=2856                  .                .
# ...                     ...                ...              ...
# 4076  dist=51232;dist=54618                  .                .
# 4077  dist=51272;dist=54578                  .                .
# 4078  dist=51346;dist=54504                  .                .
# 4079  dist=51423;dist=54427                  .                .
# 4080  dist=51445;dist=54405                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 4076                .          0          .          .           8
# 4077                .          0          .          .           8
# 4078                .          0          .          .           8
# 4079                .          0          .          .           8
# 4080                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792657  chr8:11792657:C:T          C          T          .
# 2       11792660  chr8:11792660:C:G          C          G          .
# 3       11792690  chr8:11792690:C:G          C          G          .
# 4       11792717  chr8:11792717:C:T          C          T          .
# ...          ...                ...        ...        ...        ...
# 4076    11919319  chr8:11919319:C:A          C          A          .
# 4077    11919359  chr8:11919359:G:C          G          C          .
# 4078    11919433  chr8:11919433:C:T          C          T          .
# 4079    11919510  chr8:11919510:C:T          C          T          .
# 4080    11919532  chr8:11919532:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 4076           .          PR          GT         0/0
# 4077           .          PR          GT         0/0
# 4078           .          PR          GT         0/0
# 4079           .          PR          GT         0/0
# 4080           .          PR          GT         0/0
#
# [4081 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2164
# intergenic    1351
# UTR5           170
# UTR3           137
# downstream      93
# exonic          84
# upstream        80
# splicing         2
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV      48
# synonymous SNV         34
# frameshift deletion     2
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792593  11792593   T   G   intergenic   NEIL2;FDFT1
# 2       8  11792688  11792688   G   C   intergenic   NEIL2;FDFT1
# 3       8  11792691  11792691   C   T   intergenic   NEIL2;FDFT1
# 4       8  11792812  11792812   C   T   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 2540    8  11919062  11919062   A   G   intergenic  CTSB;DEFB136
# 2541    8  11919200  11919200   G   A   intergenic  CTSB;DEFB136
# 2542    8  11919223  11919223   G   A   intergenic  CTSB;DEFB136
# 2543    8  11919263  11919263   G   T   intergenic  CTSB;DEFB136
# 2544    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5248;dist=2980                  .                .
# 2       dist=5343;dist=2885                  .                .
# 3       dist=5346;dist=2882                  .                .
# 4       dist=5467;dist=2761                  .                .
# ...                     ...                ...              ...
# 2540  dist=50975;dist=54875                  .                .
# 2541  dist=51113;dist=54737                  .                .
# 2542  dist=51136;dist=54714                  .                .
# 2543  dist=51176;dist=54674                  .                .
# 2544  dist=51363;dist=54487                  .                .
#
#      clinvar_20140902  Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .         0.0          .          .           8
# 1                   .         0.0          .          .           8
# 2                   .         0.0          .          .           8
# 3                   .         0.0          .          .           8
# 4                   .         0.0          .          .           8
# ...               ...         ...        ...        ...         ...
# 2540                .         0.0          .          .           8
# 2541                .         0.0          .          .           8
# 2542                .         0.0          .          .           8
# 2543                .         0.0          .          .           8
# 2544                .         0.0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792593  chr8:11792593:T:G          T          G          .
# 2       11792688  chr8:11792688:G:C          G          C          .
# 3       11792691  chr8:11792691:C:T          C          T          .
# 4       11792812  chr8:11792812:C:T          C          T          .
# ...          ...                ...        ...        ...        ...
# 2540    11919062  chr8:11919062:A:G          A          G          .
# 2541    11919200  chr8:11919200:G:A          G          A          .
# 2542    11919223  chr8:11919223:G:A          G          A          .
# 2543    11919263  chr8:11919263:G:T          G          T          .
# 2544    11919450  chr8:11919450:G:C          G          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2540           .          PR          GT         0/0
# 2541           .          PR          GT         0/0
# 2542           .          PR          GT         0/0
# 2543           .          PR          GT         0/0
# 2544           .          PR          GT         0/0
#
# [2545 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1379
# intergenic     857
# UTR5            90
# UTR3            82
# downstream      48
# upstream        46
# exonic          42
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    26
# synonymous SNV       16
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792683  11792683   C   G   intergenic   NEIL2;FDFT1
# 2       8  11792784  11792784   G   A   intergenic   NEIL2;FDFT1
# 3       8  11792794  11792794   T   C   intergenic   NEIL2;FDFT1
# 4       8  11792812  11792812   C   T   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 2441    8  11919223  11919223   G   A   intergenic  CTSB;DEFB136
# 2442    8  11919373  11919373   C   T   intergenic  CTSB;DEFB136
# 2443    8  11919376  11919376   A   T   intergenic  CTSB;DEFB136
# 2444    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
# 2445    8  11919469  11919469   T   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5338;dist=2890                  .                .
# 2       dist=5439;dist=2789                  .                .
# 3       dist=5449;dist=2779                  .                .
# 4       dist=5467;dist=2761                  .                .
# ...                     ...                ...              ...
# 2441  dist=51136;dist=54714                  .                .
# 2442  dist=51286;dist=54564                  .                .
# 2443  dist=51289;dist=54561                  .                .
# 2444  dist=51363;dist=54487                  .                .
# 2445  dist=51382;dist=54468                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .        0.5          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 2441                .          0          .          .           8
# 2442                .          0          .          .           8
# 2443                .          0          .          .           8
# 2444                .          0          .          .           8
# 2445                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792683  chr8:11792683:C:G          C          G          .
# 2       11792784  chr8:11792784:G:A          G          A          .
# 3       11792794  chr8:11792794:T:C          T          C          .
# 4       11792812  chr8:11792812:C:T          C          T          .
# ...          ...                ...        ...        ...        ...
# 2441    11919223  chr8:11919223:G:A          G          A          .
# 2442    11919373  chr8:11919373:C:T          C          T          .
# 2443    11919376  chr8:11919376:A:T          A          T          .
# 2444    11919450  chr8:11919450:G:C          G          C          .
# 2445    11919469  chr8:11919469:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/1
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2441           .          PR          GT         0/0
# 2442           .          PR          GT         0/0
# 2443           .          PR          GT         0/0
# 2444           .          PR          GT         0/0
# 2445           .          PR          GT         0/0
#
# [2446 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1254
# intergenic     871
# UTR5            94
# UTR3            86
# upstream        55
# exonic          47
# downstream      39
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV         31
# synonymous SNV            15
# nonframeshift deletion     1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 1       8  11792812  11792812   C   T   intergenic   NEIL2;FDFT1
# 2       8  11792966  11792966   T   C   intergenic   NEIL2;FDFT1
# 3       8  11793099  11793099   T   C   intergenic   NEIL2;FDFT1
# 4       8  11793200  11793200   G   C   intergenic   NEIL2;FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 1002    8  11918551  11918551   G   T   intergenic  CTSB;DEFB136
# 1003    8  11918618  11918618   T   C   intergenic  CTSB;DEFB136
# 1004    8  11919200  11919200   G   A   intergenic  CTSB;DEFB136
# 1005    8  11919263  11919263   G   T   intergenic  CTSB;DEFB136
# 1006    8  11919450  11919450   G   C   intergenic  CTSB;DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5467;dist=2761                  .                .
# 2       dist=5621;dist=2607                  .                .
# 3       dist=5754;dist=2474                  .                .
# 4       dist=5855;dist=2373                  .                .
# ...                     ...                ...              ...
# 1002  dist=50464;dist=55386                  .                .
# 1003  dist=50531;dist=55319                  .                .
# 1004  dist=51113;dist=54737                  .                .
# 1005  dist=51176;dist=54674                  .                .
# 1006  dist=51363;dist=54487                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .          0          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 1002                .          1          .          .           8
# 1003                .          1          .          .           8
# 1004                .          0          .          .           8
# 1005                .          0          .          .           8
# 1006                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792812  chr8:11792812:C:T          C          T          .
# 2       11792966  chr8:11792966:T:C          T          C          .
# 3       11793099  chr8:11793099:T:C          T          C          .
# 4       11793200  chr8:11793200:G:C          G          C          .
# ...          ...                ...        ...        ...        ...
# 1002    11918551  chr8:11918551:G:T          G          T          .
# 1003    11918618  chr8:11918618:T:C          T          C          .
# 1004    11919200  chr8:11919200:G:A          G          A          .
# 1005    11919263  chr8:11919263:G:T          G          T          .
# 1006    11919450  chr8:11919450:G:C          G          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 1002           .          PR          GT         1/1
# 1003           .          PR          GT         1/1
# 1004           .          PR          GT         0/0
# 1005           .          PR          GT         0/0
# 1006           .          PR          GT         0/0
#
# [1007 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      524
# intergenic    358
# UTR5           38
# UTR3           37
# upstream       18
# downstream     18
# exonic         14
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    8
# synonymous SNV       6
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#        Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0        8  11792554  11792554   C   T   intergenic   NEIL2;FDFT1
# 1        8  11792575  11792575   T   C   intergenic   NEIL2;FDFT1
# 2        8  11792593  11792593   T   G   intergenic   NEIL2;FDFT1
# 3        8  11792594  11792594   C   G   intergenic   NEIL2;FDFT1
# 4        8  11792658  11792658   C   G   intergenic   NEIL2;FDFT1
# ...    ...       ...       ...  ..  ..          ...           ...
# 13476    8  11919475  11919475   T   C   intergenic  CTSB;DEFB136
# 13477    8  11919503  11919503   T   C   intergenic  CTSB;DEFB136
# 13478    8  11919510  11919510   C   T   intergenic  CTSB;DEFB136
# 13479    8  11919512  11919512   T   C   intergenic  CTSB;DEFB136
# 13480    8  11919513  11919513   G   C   intergenic  CTSB;DEFB136
#
#           GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0        dist=5209;dist=3019                  .                .
# 1        dist=5230;dist=2998                  .                .
# 2        dist=5248;dist=2980                  .                .
# 3        dist=5249;dist=2979                  .                .
# 4        dist=5313;dist=2915                  .                .
# ...                      ...                ...              ...
# 13476  dist=51388;dist=54462                  .                .
# 13477  dist=51416;dist=54434                  .                .
# 13478  dist=51423;dist=54427                  .                .
# 13479  dist=51425;dist=54425                  .                .
# 13480  dist=51426;dist=54424                  .                .
#
#       clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                    .          0          .          .           8
# 1                    .          0          .          .           8
# 2                    .          .          .          .           8
# 3                    .          .          .          .           8
# 4                    .          0          .          .           8
# ...                ...        ...        ...        ...         ...
# 13476                .          .          .          .           8
# 13477                .          0          .          .           8
# 13478                .          0          .          .           8
# 13479                .          0          .          .           8
# 13480                .          0          .          .           8
#
#        Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0        11792554  chr8:11792554:C:T          C          T          .
# 1        11792575  chr8:11792575:T:C          T          C          .
# 2        11792593  chr8:11792593:T:G          T          G          .
# 3        11792594  chr8:11792594:C:G          C          G          .
# 4        11792658  chr8:11792658:C:G          C          G          .
# ...           ...                ...        ...        ...        ...
# 13476    11919475  chr8:11919475:T:C          T          C          .
# 13477    11919503  chr8:11919503:T:C          T          C          .
# 13478    11919510  chr8:11919510:C:T          C          T          .
# 13479    11919512  chr8:11919512:T:C          T          C          .
# 13480    11919513  chr8:11919513:G:C          G          C          .
#
#       Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0               .          PR          GT         0/0
# 1               .          PR          GT         0/0
# 2               .          PR          GT         ./.
# 3               .          PR          GT         ./.
# 4               .          PR          GT         0/0
# ...           ...         ...         ...         ...
# 13476           .          PR          GT         ./.
# 13477           .          PR          GT         0/0
# 13478           .          PR          GT         0/0
# 13479           .          PR          GT         0/0
# 13480           .          PR          GT         0/0
#
# [13481 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      7065
# intergenic    4618
# UTR5           537
# UTR3           455
# upstream       270
# downstream     269
# exonic         264
# splicing         3
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV         164
# synonymous SNV             91
# nonframeshift deletion      6
# frameshift deletion         2
# frameshift insertion        1
# Name: count, dtype: int64

# %% [markdown]
# ASSOC

# %%
#Run case-control analysis using plink assoc for all variants, not adjusting for any covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ! /home/jupyter/tools/plink \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep {WORK_DIR}/{ancestry}.samplestoKeep \
    --assoc \
    --allow-no-sex \
    --ci 0.95 \
    --maf 0.01 \
    --out {WORK_DIR}/{ancestry}_CTSB.all
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 5351 variants loaded from .bim file.
# 1111 people (455 males, 656 females) loaded from .fam.
# 1086 phenotype values loaded from .fam.
# --keep: 1111 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1111 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997295.
# 4134 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1217 variants and 1111 people pass filters and QC.
# Among remaining phenotypes, 285 are cases and 801 are controls.  (25 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all.assoc ...
# 84done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 6381 variants loaded from .bim file.
# 2643 people (1480 males, 1163 females) loaded from .fam.
# 2621 phenotype values loaded from .fam.
# --keep: 2643 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2643 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.994838.
# 5149 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1232 variants and 2643 people pass filters and QC.
# Among remaining phenotypes, 942 are cases and 1679 are controls.  (22
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all.assoc ...
# 83done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 2136 variants loaded from .bim file.
# 2655 people (1648 males, 1007 females) loaded from .fam.
# 1703 phenotype values loaded from .fam.
# --keep: 2655 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2655 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.994732.
# 1393 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 743 variants and 2655 people pass filters and QC.
# Among remaining phenotypes, 1292 are cases and 411 are controls.  (952
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 3038 variants loaded from .bim file.
# 646 people (363 males, 283 females) loaded from .fam.
# 613 phenotype values loaded from .fam.
# --keep: 646 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 646 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.993416.
# 2319 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 719 variants and 646 people pass filters and QC.
# Among remaining phenotypes, 458 are cases and 155 are controls.  (33 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 2607 variants loaded from .bim file.
# 903 people (439 males, 464 females) loaded from .fam.
# 895 phenotype values loaded from .fam.
# --keep: 903 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 903 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.987931.
# 1904 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 703 variants and 903 people pass filters and QC.
# Among remaining phenotypes, 552 are cases and 343 are controls.  (8 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 4081 variants loaded from .bim file.
# 5167 people (3278 males, 1889 females) loaded from .fam.
# 5123 phenotype values loaded from .fam.
# --keep: 5167 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 5167 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.986103.
# 3593 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 488 variants and 5167 people pass filters and QC.
# Among remaining phenotypes, 2662 are cases and 2461 are controls.  (44
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 13481 variants loaded from .bim file.
# 38839 people (23296 males, 15543 females) loaded from .fam.
# 30412 phenotype values loaded from .fam.
# --keep: 38838 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 38838 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.753414.
# 12797 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 684 variants and 38838 people pass filters and QC.
# Among remaining phenotypes, 21197 are cases and 9214 are controls.  (8427
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 1007 variants loaded from .bim file.
# 114 people (53 males, 61 females) loaded from .fam.
# 106 phenotype values loaded from .fam.
# --keep: 114 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 114 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991768.
# 305 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 702 variants and 114 people pass filters and QC.
# Among remaining phenotypes, 98 are cases and 8 are controls.  (8 phenotypes are
# missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 2545 variants loaded from .bim file.
# 581 people (369 males, 212 females) loaded from .fam.
# 536 phenotype values loaded from .fam.
# --keep: 581 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 581 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.990923.
# 1856 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 689 variants and 581 people pass filters and QC.
# Among remaining phenotypes, 311 are cases and 225 are controls.  (45 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 2446 variants loaded from .bim file.
# 635 people (408 males, 227 females) loaded from .fam.
# 609 phenotype values loaded from .fam.
# --keep: 635 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 635 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.992566.
# 1730 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 716 variants and 635 people pass filters and QC.
# Among remaining phenotypes, 387 are cases and 222 are controls.  (26 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all
#
# 12984 MB RAM detected; reserving 6492 MB for main workspace.
# 4946 variants loaded from .bim file.
# 851 people (446 males, 405 females) loaded from .fam.
# 827 phenotype values loaded from .fam.
# --keep: 851 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 851 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995169.
# 3966 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 980 variants and 851 people pass filters and QC.
# Among remaining phenotypes, 525 are cases and 302 are controls.  (24 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all.assoc ...
# done.

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Look at assoc results, only variants with nominal p-value < 0.05
    freq = pd.read_csv(f'{WORK_DIR}/{ancestry}_CTSB.all.assoc', sep='\s+')
    sig_all_nonadj = freq[freq['P']<0.05]
    
    print(f'Variants with p-value < 0.05: {sig_all_nonadj.shape}')
    
    #Save FREQ to csv
    freq.to_csv(f'{WORK_DIR}/{ancestry}.all_nonadj.csv')
# Out:
# WORKING ON: AAC
# Variants with p-value < 0.05: (142, 13)
# WORKING ON: AFR
# Variants with p-value < 0.05: (101, 13)
# WORKING ON: AJ
# Variants with p-value < 0.05: (6, 13)
# WORKING ON: AMR
# Variants with p-value < 0.05: (200, 13)
# WORKING ON: CAS
# Variants with p-value < 0.05: (167, 13)
# WORKING ON: EAS
# Variants with p-value < 0.05: (167, 13)
# WORKING ON: EUR
# Variants with p-value < 0.05: (208, 13)
# WORKING ON: FIN
# Variants with p-value < 0.05: (25, 13)
# WORKING ON: MDE
# Variants with p-value < 0.05: (80, 13)
# WORKING ON: SAS
# Variants with p-value < 0.05: (26, 13)
# WORKING ON: CAH
# Variants with p-value < 0.05: (53, 13)

# %% [markdown]
# GLM

# %%
#Run case-control analysis with covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep {WORK_DIR}/{ancestry}.samplestoKeep \
    --allow-no-sex \
    --maf 0.01 \
    --ci 0.95 \
    --glm \
    --covar {WORK_DIR}/{ancestry}_covariate_file.txt \
    --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
    --covar-variance-standardize \
    --neg9-pheno-really-missing \
    --out {WORK_DIR}/{ancestry}_CTSB.all_adj
# Out:
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:51 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11226 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam.
# 5351 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --keep: 1111 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_covariate_file.txt.
# 1111 samples (656 females, 455 males; 1111 founders) remaining after main
# filters.
# 285 cases and 801 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 4134 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1217 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:52 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:53 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11236 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam.
# 6381 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --keep: 2643 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_covariate_file.txt.
# 2643 samples (1163 females, 1480 males; 2643 founders) remaining after main
# filters.
# 942 cases and 1679 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 5149 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1232 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:53 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:54 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11226 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam.
# 2136 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --keep: 2655 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_covariate_file.txt.
# 2655 samples (1007 females, 1648 males; 2655 founders) remaining after main
# filters.
# 1292 cases and 411 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1393 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 743 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:54 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:55 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11225 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam.
# 3038 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --keep: 646 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_covariate_file.txt.
# 646 samples (283 females, 363 males; 646 founders) remaining after main
# filters.
# 458 cases and 155 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2319 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 719 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:55 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:56 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11224 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam.
# 2607 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --keep: 903 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_covariate_file.txt.
# 903 samples (464 females, 439 males; 903 founders) remaining after main
# filters.
# 552 cases and 343 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1904 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 703 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:56 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:56 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11225 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam.
# 4081 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --keep: 5167 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_covariate_file.txt.
# 5167 samples (1889 females, 3278 males; 5167 founders) remaining after main
# filters.
# 2662 cases and 2461 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3593 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 488 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:30:57 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj
#
# Start time: Thu Jun 12 11:30:57 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11223 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam.
# 13481 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --keep: 38838 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_covariate_file.txt.
# 38838 samples (15543 females, 23295 males; 38838 founders) remaining after main
# filters.
# 21197 cases and 9214 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 12797 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 684 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:31:02 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj
#
# Start time: Thu Jun 12 11:31:02 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11210 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam.
# 1007 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --keep: 114 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_covariate_file.txt.
# 114 samples (61 females, 53 males; 114 founders) remaining after main filters.
# 98 cases and 8 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 305 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 702 variants remaining after main filters.
# Warning: --glm remaining control count is less than 10x predictor count for
# phenotype 'PHENO1'.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:31:03 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj
#
# Start time: Thu Jun 12 11:31:03 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11218 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam.
# 2545 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --keep: 581 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_covariate_file.txt.
# 581 samples (212 females, 369 males; 581 founders) remaining after main
# filters.
# 311 cases and 225 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1856 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 689 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:31:04 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj
#
# Start time: Thu Jun 12 11:31:04 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11195 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam.
# 2446 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --keep: 635 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_covariate_file.txt.
# 635 samples (227 females, 408 males; 635 founders) remaining after main
# filters.
# 387 cases and 222 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1730 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 716 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:31:05 2025
# PLINK v2.0.0-a.6.0LM 64-bit Intel (11 Nov 2024)    cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj
#
# Start time: Thu Jun 12 11:31:05 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 12984 MiB RAM detected, ~11203 available; reserving 6492 MiB for main
# workspace.
# Using up to 2 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam.
# 4946 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --keep: 851 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_covariate_file.txt.
# 851 samples (405 females, 446 males; 851 founders) remaining after main
# filters.
# 525 cases and 302 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3966 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 980 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Thu Jun 12 11:31:06 2025

# %%
#Process results from plink glm analysis including covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Read in plink glm results
    assoc = pd.read_csv(f'{WORK_DIR}/{ancestry}_CTSB.all_adj.PHENO1.glm.logistic.hybrid', delim_whitespace=True)
    
    #Filter for additive test only - this is the variant results
    assoc_add = assoc[assoc['TEST']=="ADD"]
    
    #Check if there are any significant (p < 0.05) variants
    significant = assoc_add[assoc_add['P']<0.05]

    print(f'There are {len(significant)} variants with p-value < 0.05 in glm')
    
    #Check if there are any significant (p < 0.05) variants
    GWsignificant = assoc_add[assoc_add['P']<5e-8]

    print(f'There are {len(GWsignificant)} variants with p-value < 5e-8 in glm')
    
    #Save assoc_add to csv
    assoc_add.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
# Out:
# WORKING ON: AAC
# There are 42 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AFR
# There are 126 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AJ
# There are 21 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AMR
# There are 160 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAS
# There are 44 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EAS
# There are 9 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EUR
# There are 189 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: FIN
# There are 6 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: MDE
# There are 32 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: SAS
# There are 26 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAH
# There are 75 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_40616/973086827.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# change format of association file in EUR

# %%
WORK_DIR = "~/workspace/ws_files/CTSB/"

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = "~/workspace/ws_files/CTSB/"
    print(f'WORKING ON: {ancestry}')
    
    df = pd.read_csv(f'{WORK_DIR}/CTSB_{ancestry}/{ancestry}.all_adj.csv')
    
    #First just select relevant columns: chromosome, bp position and p-value
    export_ldassoc = df[['#CHROM', 'POS', 'P']].copy()
    
    #Rename the #CHROM column to remove the hashtag as I think this might be confusing LDassoc
    export_ldassoc = export_ldassoc.rename(columns={'#CHROM': 'CHROM'}) 
    
    #Then export as a tab-separated, not comma-separated file

    export_ldassoc.to_csv(f'{WORK_DIR}/CTSB_{ancestry}/{ancestry}.all_adj.formatted.tab', sep = '\t', index=False)
# Out:
# WORKING ON: AJ
# WORKING ON: MDE
# WORKING ON: EAS
# WORKING ON: AMR
# WORKING ON: CAS
# WORKING ON: FIN
# WORKING ON: CAH
# WORKING ON: SAS
# WORKING ON: AFR
# WORKING ON: EUR
# WORKING ON: AAC

# %% [markdown]
# GCTA conditional analysis

# %%
# prepare file for COJO
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    #Read in summary statistics
    sumstats = pd.read_csv(f'{WORK_DIR}/CTSB_{ancestry}/{ancestry}.all_adj.csv')
    
    #Format summary statistics for GCTA-COJO
    #First get the log odds ratio - this is required for COJO
    #1) For a case-control study, the effect size should be log(odds ratio) with its corresponding standard error.
    sumstats_formatted = sumstats.copy()
    sumstats_formatted['b'] = np.log(sumstats_formatted['OR'])
    
    #Now select just the necessary columns for COJO
    sumstats_export = sumstats_formatted[['ID', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P', 'OBS_CT']].copy()
    
    #Rename columns following COJO format
    sumstats_export = sumstats_export.rename(columns = {'ID':'SNP', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p', 'OBS_CT':'N'})
    
    #Export
    sumstats_export.to_csv(f'{WORK_DIR}/CTSB_{ancestry}/{ancestry}.all_adj.sumstats.ma', sep = '\t', index=False)

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 5e-8 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.COJO

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 4.27e-4 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.LDprune.COJO

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-top-SNPs 10 \
    --out {WORK_DIR}/{ancestry}.all_adj.top10
