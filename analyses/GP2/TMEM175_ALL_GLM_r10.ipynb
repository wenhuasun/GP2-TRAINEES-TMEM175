# %% [markdown]
# TMEM175 - Single gene analysis in GP2 Neurobooster genotyping data (all ancestries)
#
# Project: GP2 TMEM175
#
# Version: Python/3.10.15, R/4.3.3
#
# Notebook Overview
#
# Description Loading Python libraries Set paths Make working directory
#
# Installing packages
#
# Create a covariate file with GP2 data
#
# Annotation of the gene TMEM175
#
# Association analysis to compare allele frequencies between cases and controls
#
# GLM analysis adjusting for gender, age, PC1-5
#
# Burden test(SkatO, Skat, cmc,zeggini,mb,fp,cmcWald)
#
# Conditional analysis

# %% [markdown]
# Loading Python libraries

# %%
# Use pathlib for file path manipulation
import pathlib

# Install numpy
import numpy as np

# Install Pandas for tabular data
import pandas as pd

# Install plotnine: a ggplot2-compatible Python plotting package
from plotnine import *

# Always show all columns in a Pandas DataFrame
pd.set_option('display.max_columns', None)

# %% [markdown]
# Set paths

# %%
REL10_PATH = pathlib.Path(pathlib.Path.home(), 'workspace/gp2_tier2_eu_release10')
# !ls -hal {REL10_PATH}
# Out:
# total 100K
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 clinical_data
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 imputed_genotypes
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 meta_data
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 raw_genotypes
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 raw_genotypes_flipped
# -r--r--r--. 1 jupyter users 100K Jun 30 20:07 README_release10_01072025.txt
# dr-xr-xr-x. 1 jupyter users    0 Jul 25 13:32 wgs

# %% [markdown]
# Make working directory

# %%
! mkdir ~/workspace/ws_files/TMEM175

# %%
WORK_DIR = "~/workspace/ws_files/TMEM175/"

# %%
# make sure all tools installed
! ls /home/jupyter/tools
# Out:
# annovar				       plink_linux_x86_64_20190304.zip
# annovar.latest.tar.gz		       prettify
# intel-simplified-software-license.txt  rvtests
# LICENSE				       toy.map
# plink				       toy.ped
# plink2				       vcf_subset
# plink2_linux_x86_64_latest.zip

# %% [markdown]
# install packages

# %% [markdown]
# RVTests

# %%
# %%bash
#
# #Install RVTESTS: Option 1 (~15min)
# if test -e /home/jupyter/tools/rvtests; then
#
# echo "rvtests is already installed"
# else
# echo "rvtests is not installed"
#
# mkdir /home/jupyter/tools/rvtests
# cd /home/jupyter/tools/rvtests
#
# wget https://github.com/zhanxw/rvtests/releases/download/v2.1.0/rvtests_linux64.tar.gz
#
# tar -zxvf rvtests_linux64.tar.gz
# fi
# Out:
# rvtests is not installed
# --2025-07-24 15:16:49--  https://github.com/zhanxw/rvtests/releases/download/v2.1.0/rvtests_linux64.tar.gz
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/7528862/63fbb780-29ae-11e9-91d3-99ec3c3134cc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-24T16%3A10%3A13Z&rscd=attachment%3B+filename%3Drvtests_linux64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-24T15%3A09%3A25Z&ske=2025-07-24T16%3A10%3A13Z&sks=b&skv=2018-11-09&sig=v%2Bg0ZHemeimaLBK7%2B25gwCWFnKuu9C755inMrILqaMs%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MzM3MDUwOSwibmJmIjoxNzUzMzcwMjA5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ
#  37050K .......... .......... .......... .......... .......... 99%  168M 0s
#  37100K .......... .......... .......... .......... .......... 99%  213M 0s
#  37150K ........                                              100%  220M=0.7s
#
# 2025-07-24 15:16:50 (51.7 MB/s) - ‘rvtests_linux64.tar.gz’ saved [38050737/38050737]
# executable/
# executable/combineKinship
# executable/plink2vcf
# executable/vcf2plink
# executable/vcfAnnoSummaryLite
# executable/explainCSI2
# executable/vcf2kinship
# executable/vcfIndvSummary
# executable/createVCFIndex
# executable/extractVCFIndex
# executable/explainTabix
# executable/vcf2ld_neighbor
# executable/vcfConcordance
# executable/vcfExtractSite
# executable/vcfSummaryLite
# executable/bgenFileInfo
# executable/vcfPeek
# executable/vcfVariantSummaryLite
# executable/kinshipDecompose
# executable/rvtest
# executable/vcfPair
# executable/vcfSummary
# executable/explainCSI1
# executable/vcf2ld_window
# executable/queryVCFIndex
# executable/bgen2vcf
# executable/vcf2ld_gene
# executable/vcf2geno
# example/
# example/README.md
# example/example.vcf
# example/covar.missing
# example/pheno
# example/experimental/
# example/experimental/1k.fam
# example/experimental/1k.bed
# example/experimental/1k.bim
# example/experimental/1k.1m.bgen
# example/experimental/cmd.sh
# example/experimental/1k.1m.vcf.gz
# example/experimental/1k.ped
# example/experimental/1k.1m.samples
# example/example.vcf.gz.tbi
# example/example.vcf.gz
# example/cmd.sh
# example/setFile
# example/covar
# README.md

# %%
# give permission

# chmod to make sure you have permission to run the program
! chmod u+x /home/jupyter/tools/plink
! chmod u+x /home/jupyter/tools/plink2
! chmod 777 /home/jupyter/tools/rvtests/executable/rvtest

# %%
# %%bash
# # making working directory
# #Loop over all the ancestries
# for ancestry in {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'} ;
# do
#
# #Make a folder for each ancestry
# mkdir ~/workspace/ws_files/TMEM175/TMEM175_"$ancestry"
#
# done

# %%
# covariate file has been created in another notebook without GBA carriers

# %% [markdown]
# Annotation of the gene
#
# Extract the region using PLINK
#
# Extract TMEM175 gene
#
# TMEM175 coordinates: Chromosome 4:932387-4:958656(GRCh38/hg38)

# %%
## extract region using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release10_vwb \
    --chr 4 \
    --from-bp 882387 \
    --to-bp 1008656 \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_TMEM175
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:23:46 2025
# 26046 MiB RAM detected, ~24020 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.psam.
# 7745089 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# 7209 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:23:55 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:23:56 2025
# 26046 MiB RAM detected, ~24029 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.psam.
# 4434664 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# 3883 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:00 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:01 2025
# 26046 MiB RAM detected, ~23952 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.psam.
# 3023064 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# 2741 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:04 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:05 2025
# 26046 MiB RAM detected, ~23980 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.psam.
# 1752681 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# 1378 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bed ...
# done.
# End time: Thu Jul 24 15:24:07 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:08 2025
# 26046 MiB RAM detected, ~23984 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.psam.
# 2227587 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# 2103 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:11 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:12 2025
# 26046 MiB RAM detected, ~24009 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.psam.
# 4063160 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# 3430 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:15 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:16 2025
# 26046 MiB RAM detected, ~23977 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.psam.
# 939049 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# 645 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:17 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:18 2025
# 26046 MiB RAM detected, ~23976 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.psam.
# 3379769 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# 3374 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:22 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:23 2025
# 26046 MiB RAM detected, ~23985 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.psam.
# 4117743 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# 3520 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:26 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:27 2025
# 26046 MiB RAM detected, ~23984 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.psam.
# 2741528 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# 2501 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:30 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.log.
# Options in effect:
#   --chr 4
#   --from-bp 882387
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb
#   --to-bp 1008656
#
# Start time: Thu Jul 24 15:24:31 2025
# 26046 MiB RAM detected, ~23982 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.psam.
# 5095310 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# 4429 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.fam
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bim
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bed
# done.%
# End time: Thu Jul 24 15:24:36 2025

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}/'
    
    ! head -n 1 {WORK_DIR}/{ancestry}_TMEM175.fam > {WORK_DIR}/{ancestry}_s1.txt

# %%
! head /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_s1.txt

# %% [markdown]
# Turn binary files into VCF

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_TMEM175 \
    --keep {WORK_DIR}/{ancestry}_s1.txt \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_TMEM175_v1

# %%
### Bgzip and Tabix (zip and index the file)
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    ! bgzip -f {WORK_DIR}/{ancestry}_TMEM175_v1.vcf
    ! tabix -f -p vcf {WORK_DIR}/{ancestry}_TMEM175_v1.vcf.gz

# %% [markdown]
# Annotate using ANNOVAR

# %%
## annotate using ANNOVAR

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    
    ! perl /home/jupyter/tools/annovar/table_annovar.pl {WORK_DIR}/{ancestry}_TMEM175_v1.vcf.gz /home/jupyter/tools/annovar/humandb/ -buildver hg38 \
    -out {WORK_DIR}/{ancestry}_TMEM175.annovar \
    -remove -protocol refGene,clinvar_20140902 \
    -operation g,f \
    --nopolish \
    -nastring . \
    -vcfinput
# Out:
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.avinput>
# NOTICE: Finished reading 7216 lines from VCF file
# NOTICE: A total of 7209 locus in VCF file passed QC threshold, representing 6826 SNPs (5193 transitions and 1633 transversions) and 383 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 6826 SNP genotypes (5193 transitions and 1633 transversions) and 383 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 7209 unique variants in 7209 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 7209 unique variants in 7209 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.avinput>
# NOTICE: Finished reading 3890 lines from VCF file
# NOTICE: A total of 3883 locus in VCF file passed QC threshold, representing 3659 SNPs (2735 transitions and 924 transversions) and 224 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3659 SNP genotypes (2735 transitions and 924 transversions) and 224 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3883 unique variants in 3883 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3883 unique variants in 3883 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.avinput>
# NOTICE: Finished reading 2748 lines from VCF file
# NOTICE: A total of 2741 locus in VCF file passed QC threshold, representing 2588 SNPs (1971 transitions and 617 transversions) and 153 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2588 SNP genotypes (1971 transitions and 617 transversions) and 153 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2741 unique variants in 2741 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2741 unique variants in 2741 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.avinput>
# NOTICE: Finished reading 1385 lines from VCF file
# NOTICE: A total of 1378 locus in VCF file passed QC threshold, representing 1303 SNPs (972 transitions and 331 transversions) and 75 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1303 SNP genotypes (972 transitions and 331 transversions) and 75 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 1378 unique variants in 1378 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 1378 unique variants in 1378 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.annovar.hg38_multianno.vcf
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.avinput>
# NOTICE: Finished reading 2110 lines from VCF file
# NOTICE: A total of 2103 locus in VCF file passed QC threshold, representing 1987 SNPs (1521 transitions and 466 transversions) and 116 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1987 SNP genotypes (1521 transitions and 466 transversions) and 116 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2103 unique variants in 2103 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2103 unique variants in 2103 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.avinput>
# NOTICE: Finished reading 3437 lines from VCF file
# NOTICE: A total of 3430 locus in VCF file passed QC threshold, representing 3245 SNPs (2454 transitions and 791 transversions) and 185 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3245 SNP genotypes (2454 transitions and 791 transversions) and 185 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3430 unique variants in 3430 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3430 unique variants in 3430 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.avinput>
# NOTICE: Finished reading 652 lines from VCF file
# NOTICE: A total of 645 locus in VCF file passed QC threshold, representing 610 SNPs (456 transitions and 154 transversions) and 35 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 610 SNP genotypes (456 transitions and 154 transversions) and 35 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 645 unique variants in 645 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 645 unique variants in 645 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.annovar.hg38_multianno.vcf
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.avinput>
# NOTICE: Finished reading 3381 lines from VCF file
# NOTICE: A total of 3374 locus in VCF file passed QC threshold, representing 3198 SNPs (2497 transitions and 701 transversions) and 176 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3198 SNP genotypes (2497 transitions and 701 transversions) and 176 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3374 unique variants in 3374 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3374 unique variants in 3374 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.avinput>
# NOTICE: Finished reading 3527 lines from VCF file
# NOTICE: A total of 3520 locus in VCF file passed QC threshold, representing 3327 SNPs (2494 transitions and 833 transversions) and 193 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3327 SNP genotypes (2494 transitions and 833 transversions) and 193 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3520 unique variants in 3520 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3520 unique variants in 3520 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.avinput>
# NOTICE: Finished reading 2508 lines from VCF file
# NOTICE: A total of 2501 locus in VCF file passed QC threshold, representing 2365 SNPs (1807 transitions and 558 transversions) and 136 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2365 SNP genotypes (1807 transitions and 558 transversions) and 136 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2501 unique variants in 2501 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2501 unique variants in 2501 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175_v1.vcf.gz > /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.avinput>
# NOTICE: Finished reading 4436 lines from VCF file
# NOTICE: A total of 4429 locus in VCF file passed QC threshold, representing 4173 SNPs (3193 transitions and 980 transversions) and 256 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 4173 SNP genotypes (3193 transitions and 980 transversions) and 256 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 4429 unique variants in 4429 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 15 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 4429 unique variants in 4429 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 10
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/TMEM175_SAS/SAS_TMEM175.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr    Start      End Ref Alt Func.refGene Gene.refGene  \
# 0       4   882397   882397   C   T     intronic          GAK
# 1       4   882432   882432   G   A     intronic          GAK
# 2       4   882530   882530   C   T     intronic          GAK
# 3       4   882566   882566   G   -     intronic          GAK
# 4       4   882611   882611   T   C     intronic          GAK
# ...   ...      ...      ...  ..  ..          ...          ...
# 2098    4  1008337  1008337   C   T   intergenic  IDUA,FGFRL1
# 2099    4  1008371  1008371   C   -   intergenic  IDUA,FGFRL1
# 2100    4  1008480  1008480   A   G   intergenic  IDUA,FGFRL1
# 2101    4  1008515  1008515   C   T   intergenic  IDUA,FGFRL1
# 2102    4  1008538  1008538   A   G   intergenic  IDUA,FGFRL1
#
#        GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0                       .                  .                .
# 1                       .                  .                .
# 2                       .                  .                .
# 3                       .                  .                .
# 4                       .                  .                .
# ...                   ...                ...              ...
# 2098  dist=3773;dist=3289                  .                .
# 2099  dist=3807;dist=3255                  .                .
# 2100  dist=3916;dist=3146                  .                .
# 2101  dist=3951;dist=3111                  .                .
# 2102  dist=3974;dist=3088                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           4
# 1                   .          0          .          .           4
# 2                   .          0          .          .           4
# 3                   .          0          .          .           4
# 4                   .          0          .          .           4
# ...               ...        ...        ...        ...         ...
# 2098                .        0.5          .          .           4
# 2099                .          0          .          .           4
# 2100                .          0          .          .           4
# 2101                .          0          .          .           4
# 2102                .          0          .          .           4
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0         882397    chr4:882397:C:T          C          T          .
# 1         882432    chr4:882432:G:A          G          A          .
# 2         882530    chr4:882530:C:T          C          T          .
# 3         882565   chr4:882565:AG:A         AG          A          .
# 4         882611    chr4:882611:T:C          T          C          .
# ...          ...                ...        ...        ...        ...
# 2098     1008337   chr4:1008337:C:T          C          T          .
# 2099     1008370  chr4:1008370:TC:T         TC          T          .
# 2100     1008480   chr4:1008480:A:G          A          G          .
# 2101     1008515   chr4:1008515:C:T          C          T          .
# 2102     1008538   chr4:1008538:A:G          A          G          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/0
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2098           .          PR          GT         0/1
# 2099           .          PR          GT         0/0
# 2100           .          PR          GT         0/0
# 2101           .          PR          GT         0/0
# 2102           .          PR          GT         0/0
#
# [2103 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic           1701
# exonic              187
# intergenic           94
# UTR3                 59
# UTR5                 25
# downstream           24
# upstream             12
# exonic;splicing       1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV         104
# synonymous SNV             78
# stopgain                    2
# frameshift deletion         2
# nonframeshift deletion      1
# Name: count, dtype: int64

# %%
#Make lists of variants to keep - all coding, coding nonsynonymous (missense - as they are coded in ANNOVAR), deleterious (CADD_phred > 20)

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    print(f'WORKING ON: {ancestry}')

    # Read in ANNOVAR multianno file
    gene = pd.read_csv(f'{WORK_DIR}/{ancestry}_TMEM175.annovar.hg38_multianno.txt', sep = '\t')
    
    #Print number of variants in the different categories
    results = [] 

    utr5 = gene[gene['Func.refGene']== 'UTR5']
    intronic = gene[gene['Func.refGene']== 'intronic']
    exonic = gene[gene['Func.refGene']== 'exonic']
    utr3 = gene[gene['Func.refGene']== 'UTR3']
    coding_nonsynonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] == 'nonsynonymous SNV')]
    coding_synonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] != 'nonsynonymous SNV')]
    lof = exonic[(exonic['ExonicFunc.refGene'] == 'stopgain') | (exonic['ExonicFunc.refGene'] == 'stoploss') | (exonic['ExonicFunc.refGene'] == 'frameshift deletion') | (exonic['ExonicFunc.refGene'] == 'frameshift insertion')]
    nonsynonymous_lof = pd.concat([coding_nonsynonymous, lof])

    print({ancestry})
    print('Total variants: ', len(gene))
    print("Intronic: ", len(intronic))
    print('UTR3: ', len(utr3))
    print('UTR5: ', len(utr5))
    print("Total exonic: ", len(exonic))
    print('  Synonymous: ', len(coding_synonymous))
    print("  Nonsynonymous: ", len(coding_nonsynonymous))
    print("nonsynonymous_lof: ", len(nonsynonymous_lof))
    results.append((gene, intronic, utr3, utr5, exonic, coding_synonymous, coding_nonsynonymous, nonsynonymous_lof))
    print('\n')

    # Save in PLINK format - coding nonsynonymous 
    # These are missense variants - other types of nonsynonymous variants (e.g stopgain/loss, or frameshift variants are coded differently in the ExonicFunc.refGene 
    variants_toKeep = nonsynonymous_lof[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep.to_csv(f'{WORK_DIR}/{ancestry}_TMEM175.nonsynonymous_lof.variantstoKeep.txt', sep="\t", index=False, header=False)


    # Save in PLINK format - all coding variants
    variants_toKeep2 = exonic[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep2.to_csv(f'{WORK_DIR}/{ancestry}_TMEM175.exonic.variantstoKeep.txt', sep="\t", index=False, header=False)
# Out:
# WORKING ON: EUR
# {'EUR'}
# Total variants:  7209
# Intronic:  5651
# UTR3:  214
# UTR5:  82
# Total exonic:  731
#   Synonymous:  313
#   Nonsynonymous:  418
# nonsynonymous_lof:  437
#
#
# WORKING ON: AMR
# {'AMR'}
# Total variants:  3883
# Intronic:  3134
# UTR3:  102
# UTR5:  42
# Total exonic:  323
#   Synonymous:  150
#   Nonsynonymous:  173
# nonsynonymous_lof:  180
#
#
# WORKING ON: MDE
# {'MDE'}
# Total variants:  2741
# Intronic:  2182
# UTR3:  77
# UTR5:  34
# Total exonic:  257
#   Synonymous:  123
#   Nonsynonymous:  134
# nonsynonymous_lof:  136
#
#
# WORKING ON: AJ
# {'AJ'}
# Total variants:  1378
# Intronic:  1086
# UTR3:  46
# UTR5:  7
# Total exonic:  141
#   Synonymous:  66
#   Nonsynonymous:  75
# nonsynonymous_lof:  79
#
#
# WORKING ON: SAS
# {'SAS'}
# Total variants:  2103
# Intronic:  1701
# UTR3:  59
# UTR5:  25
# Total exonic:  187
#   Synonymous:  83
#   Nonsynonymous:  104
# nonsynonymous_lof:  108
#
#
# WORKING ON: CAH
# {'CAH'}
# Total variants:  3430
# Intronic:  2746
# UTR3:  95
# UTR5:  32
# Total exonic:  282
#   Synonymous:  128
#   Nonsynonymous:  154
# nonsynonymous_lof:  162
#
#
# WORKING ON: FIN
# {'FIN'}
# Total variants:  645
# Intronic:  526
# UTR3:  22
# UTR5:  3
# Total exonic:  54
#   Synonymous:  30
#   Nonsynonymous:  24
# nonsynonymous_lof:  25
#
#
# WORKING ON: EAS
# {'EAS'}
# Total variants:  3374
# Intronic:  2659
# UTR3:  109
# UTR5:  51
# Total exonic:  312
#   Synonymous:  131
#   Nonsynonymous:  181
# nonsynonymous_lof:  190
#
#
# WORKING ON: AAC
# {'AAC'}
# Total variants:  3520
# Intronic:  2811
# UTR3:  98
# UTR5:  41
# Total exonic:  293
#   Synonymous:  138
#   Nonsynonymous:  155
# nonsynonymous_lof:  160
#
#
# WORKING ON: CAS
# {'CAS'}
# Total variants:  2501
# Intronic:  2010
# UTR3:  70
# UTR5:  27
# Total exonic:  231
#   Synonymous:  101
#   Nonsynonymous:  130
# nonsynonymous_lof:  135
#
#
# WORKING ON: AFR
# {'AFR'}
# Total variants:  4429
# Intronic:  3516
# UTR3:  135
# UTR5:  50
# Total exonic:  374
#   Synonymous:  180
#   Nonsynonymous:  194
# nonsynonymous_lof:  200

# %% [markdown]
# ALL variants
#
# assoc
#
# glm
#
# ASSOC

# %%
! pwd
# Out:
# /home/jupyter/workspace/Sample_Notebooks

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','FIN','MDE','SAS','CAH', 'EUR'}

for ancestry in ancestries:
    # read cov file
    cov = pd.read_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt', sep = '\t')

    ## Make file of sample IDs to keep 
    samples_toKeep = cov[['FID', 'IID']].copy()
    samples_toKeep.to_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep', sep = '\t', index=False, header=None)

# %%
#Run case-control analysis using plink assoc for all variants, not adjusting for any covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    
    ! /home/jupyter/tools/plink \
    --bfile {WORK_DIR}/{ancestry}_TMEM175 \
    --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
    --assoc \
    --allow-no-sex \
    --ci 0.95 \
    --maf 0.01 \
    --out {WORK_DIR}/{ancestry}_TMEM175.all
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3520 variants loaded from .bim file.
# 1215 people (532 males, 683 females) loaded from .fam.
# 1133 phenotype values loaded from .fam.
# --keep: 1207 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1207 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.998418.
# 2916 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 604 variants and 1207 people pass filters and QC.
# Among remaining phenotypes, 369 are cases and 756 are controls.  (82 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 4429 variants loaded from .bim file.
# 3780 people (2087 males, 1693 females) loaded from .fam.
# 3498 phenotype values loaded from .fam.
# --keep: 3581 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3581 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.997315.
# 3833 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 596 variants and 3581 people pass filters and QC.
# Among remaining phenotypes, 1147 are cases and 2169 are controls.  (265
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 1378 variants loaded from .bim file.
# 3472 people (2146 males, 1326 females) loaded from .fam.
# 1966 phenotype values loaded from .fam.
# --keep: 2716 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2716 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.998983.
# 964 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 414 variants and 2716 people pass filters and QC.
# Among remaining phenotypes, 1285 are cases and 408 are controls.  (1023
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3883 variants loaded from .bim file.
# 3608 people (1735 males, 1873 females) loaded from .fam.
# 3434 phenotype values loaded from .fam.
# --keep: 3471 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3471 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.997517.
# 3509 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 374 variants and 3471 people pass filters and QC.
# Among remaining phenotypes, 1917 are cases and 1402 are controls.  (152
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 2501 variants loaded from .bim file.
# 1691 people (737 males, 954 females) loaded from .fam.
# 1408 phenotype values loaded from .fam.
# --keep: 1518 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1518 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.996579.
# 2109 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 392 variants and 1518 people pass filters and QC.
# Among remaining phenotypes, 734 are cases and 578 are controls.  (206
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3374 variants loaded from .bim file.
# 6662 people (4001 males, 2661 females) loaded from .fam.
# 5116 phenotype values loaded from .fam.
# --keep: 6414 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 6414 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.994617.
# 3006 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 368 variants and 6414 people pass filters and QC.
# Among remaining phenotypes, 2377 are cases and 2598 are controls.  (1439
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 7209 variants loaded from .bim file.
# 58823 people (33074 males, 25749 females) loaded from .fam.
# 37150 phenotype values loaded from .fam.
# --keep: 53641 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 53641 founders and 0 nonfounders present.
# Calculating allele frequencies done.
# Total genotyping rate in remaining samples is 0.75561.
# 6812 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 397 variants and 53641 people pass filters and QC.
# Among remaining phenotypes, 24208 are cases and 9662 are controls.  (19771
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 645 variants loaded from .bim file.
# 144 people (62 males, 82 females) loaded from .fam.
# 118 phenotype values loaded from .fam.
# --keep: 111 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 111 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.994022.
# 240 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 405 variants and 111 people pass filters and QC.
# Among remaining phenotypes, 80 are cases and 11 are controls.  (20 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 2741 variants loaded from .bim file.
# 1493 people (815 males, 678 females) loaded from .fam.
# 1311 phenotype values loaded from .fam.
# --keep: 1448 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1448 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.99619.
# 2344 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 397 variants and 1448 people pass filters and QC.
# Among remaining phenotypes, 724 are cases and 551 are controls.  (173
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 2103 variants loaded from .bim file.
# 945 people (606 males, 339 females) loaded from .fam.
# 586 phenotype values loaded from .fam.
# --keep: 870 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 870 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.995001.
# 1630 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 473 variants and 870 people pass filters and QC.
# Among remaining phenotypes, 309 are cases and 261 are controls.  (300
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3430 variants loaded from .bim file.
# 1111 people (589 males, 522 females) loaded from .fam.
# 1040 phenotype values loaded from .fam.
# --keep: 1039 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1039 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.997672.
# 2897 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 533 variants and 1039 people pass filters and QC.
# Among remaining phenotypes, 663 are cases and 318 are controls.  (58 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all.assoc ...
# done.

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Look at assoc results, only variants with nominal p-value < 0.05
    freq = pd.read_csv(f'{WORK_DIR}/{ancestry}_TMEM175.all.assoc', sep='\s+')
    sig_all_nonadj = freq[freq['P']<0.05]
    
    print(f'Variants with p-value < 0.05: {sig_all_nonadj.shape}')
    
    #Save FREQ to csv
    freq.to_csv(f'{WORK_DIR}/{ancestry}.all_nonadj.csv')
# Out:
# WORKING ON: AAC
# Variants with p-value < 0.05: (23, 13)
# WORKING ON: AFR
# Variants with p-value < 0.05: (76, 13)
# WORKING ON: AJ
# Variants with p-value < 0.05: (150, 13)
# WORKING ON: AMR
# Variants with p-value < 0.05: (297, 13)
# WORKING ON: CAS
# Variants with p-value < 0.05: (8, 13)
# WORKING ON: EAS
# Variants with p-value < 0.05: (203, 13)
# WORKING ON: EUR
# Variants with p-value < 0.05: (218, 13)
# WORKING ON: FIN
# Variants with p-value < 0.05: (14, 13)
# WORKING ON: MDE
# Variants with p-value < 0.05: (107, 13)
# WORKING ON: SAS
# Variants with p-value < 0.05: (10, 13)
# WORKING ON: CAH
# Variants with p-value < 0.05: (88, 13)

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','FIN','MDE','SAS','CAH', 'EUR'}

for ancestry in ancestries:
    # read cov file
    cov = pd.read_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt', sep = '\t')
    cov = cov.dropna()
    cov.columns = ['FID', 'IID', 'FATID', 'MATID', 'SEX', 'AGE', 'PHENO', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5']

    ## save files 
    cov.to_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}.noGBA.noNA.txt', sep = '\t', index=False)

# %%
from sklearn.decomposition import PCA
cov = pd.read_csv(f'~/workspace/ws_files/AMR/AMR_covariate_file_noGBA.txt', sep = '\t')
pcs = cov[['PC1', 'PC2', 'PC3', 'PC4', 'PC5']]
pca = PCA(n_components=5)
pcs_ortho = pca.fit_transform(pcs)
for i in range(5):
    cov[f'PC{i+1}_ortho'] = pcs_ortho[:, i]

# (Optional) Drop old PCs
cov = cov.drop(columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
cov = cov.rename(columns={
    'PC1_ortho': 'PC1',
    'PC2_ortho': 'PC2',
    'PC3_ortho': 'PC3',
    'PC4_ortho': 'PC4',
    'PC5_ortho': 'PC5'
})

cov.to_csv('~/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt', sep='\t', index=False)

# %%
cov = pd.read_csv(f'~/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt', sep = '\t')
cov = cov.dropna()
cov.to_csv('~/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt', sep='\t', index=False)

# %%
#Run case-control analysis with covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_TMEM175 \
    --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
    --allow-no-sex \
    --maf 0.01 \
    --ci 0.95 \
    --glm \
    --covar /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.noNA.txt \
    --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
    --covar-variance-standardize \
    --neg9-pheno-really-missing \
    --out {WORK_DIR}/{ancestry}_TMEM175.all_adj
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:36 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24894 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.fam.
# 3520 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bim.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --keep: 1207 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.noNA.txt.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2916 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 604 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:37 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:38 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24872 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.fam.
# 4429 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bim.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --keep: 3581 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.noNA.txt.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3833 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 596 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:39 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:40 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24857 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.fam.
# 1378 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bim.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --keep: 2716 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.noNA.txt.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 964 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 414 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:41 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:42 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24839 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.fam.
# 3883 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.noNA.txt.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3509 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 374 variants remaining after main filters.
# Error: Cannot proceed with --glm regression on phenotype 'PHENO1', since
# variance inflation factor for covariate 'PC2' is too high (VIF_TOO_HIGH). You
# may want to remove redundant covariates and try again.
# End time: Fri Jul 25 08:23:42 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:43 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24850 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.fam.
# 2501 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bim.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --keep: 1518 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.noNA.txt.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2109 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 392 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:44 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:45 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24855 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.fam.
# 3374 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bim.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --keep: 6414 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.noNA.txt.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3006 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 368 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:46 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:47 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24848 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.fam.
# 7209 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --keep: 53641 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.noNA.txt.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# done.lating allele frequencies... 0%
# 6812 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 397 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:49 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:50 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24842 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.fam.
# 645 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bim.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --keep: 111 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.noNA.txt.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 240 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 405 variants remaining after main filters.
# Warning: --glm remaining control count is less than 10x predictor count for
# phenotype 'PHENO1'.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:50 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:52 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24853 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.fam.
# 2741 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bim.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --keep: 1448 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.noNA.txt.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2344 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 397 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:52 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:54 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24855 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.fam.
# 2103 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bim.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --keep: 870 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.noNA.txt.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1630 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 473 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:54 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:23:55 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24857 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.fam.
# 3430 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bim.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --keep: 1039 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.noNA.txt.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2897 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 533 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:23:56 2025

# %%
WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_AMR'

! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/AMR_TMEM175 \
--keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep \
--allow-no-sex \
--maf 0.01 \
--ci 0.95 \
--glm \
--covar /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt \
--covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
--covar-variance-standardize \
--neg9-pheno-really-missing \
--out {WORK_DIR}/AMR_TMEM175.all_adj
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all_adj
#
# Start time: Fri Jul 25 08:37:12 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24828 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.fam.
# 3883 variants loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3509 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 374 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Fri Jul 25 08:37:12 2025

# %%
#Process results from plink glm analysis including covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Read in plink glm results
    assoc = pd.read_csv(f'{WORK_DIR}/{ancestry}_TMEM175.all_adj.PHENO1.glm.logistic.hybrid', delim_whitespace=True)

    #Filter for additive test only - this is the variant results
    assoc_add = assoc[assoc['TEST']=="ADD"]
    
    #Check if there are any significant (p < 0.05) variants
    significant = assoc_add[assoc_add['P']<0.05]

    print(f'There are {len(significant)} variants with p-value < 0.05 in glm')
    
    #Check if there are any significant (p < 0.05) variants
    GWsignificant = assoc_add[assoc_add['P']<5e-8]

    print(f'There are {len(GWsignificant)} variants with p-value < 5e-8 in glm')
    
    #Save assoc_add to csv
    assoc_add.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
# Out:
# WORKING ON: AAC
# There are 33 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AFR
# There are 55 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AJ
# There are 152 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AMR
# There are 24 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAS
# There are 3 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EAS
# There are 55 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EUR
# There are 171 variants with p-value < 0.05 in glm
# There are 33 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: FIN
# There are 10 variants with p-value < 0.05 in glm
# There are 2 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: MDE
# There are 94 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: SAS
# There are 66 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAH
# There are 67 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_440/3155684219.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# format assoc file to do meta analysis(AFR/AJ/AMR/EAS/EUR)

# %%
# Define ancestry groups and their sample sizes
ancestry_sample_sizes = {
    'AFR': 3316,
    'AJ': 1693,
    'AMR': 3319,
    'EAS': 4975,
    'EUR': 33870
}

# Output container (optional)
cleaned_results = {}

# Loop over each ancestry
for ancestry, sample_size in ancestry_sample_sizes.items():
    # Load PLINK association result file
    file_path = f'/home/jupyter/workspace/ws_files/TMEM175/TMEM175_{ancestry}/{ancestry}.all_adj.csv'
    df = pd.read_csv(file_path)

    # Build MARKERNAME
    df['MARKERNAME'] = 'chr' + df['#CHROM'].astype(str) + ':' + df['POS'].astype(str)

    # Rename columns
    df.rename(columns={
        '#CHROM': 'CHROMOSOME',
        'POS': 'POSITION',
        'REF': 'NEA',
        'ALT': 'EA',
        'A1_FREQ': 'EAF',
        'LOG(OR)_SE': 'SE',
        'L95': 'OR_95L',
        'U95': 'OR_95U'
    }, inplace=True)

    # Add BETA = log(OR)
    df['BETA'] = np.log(df['OR'])

    # Add sample size
    df['N'] = sample_size

    # Keep desired columns
    final_cols = [
        'MARKERNAME', 'CHROMOSOME', 'POSITION', 'NEA', 'EA', 'EAF',
        'BETA', 'OR', 'SE', 'OR_95L', 'OR_95U', 'P', 'N'
    ]
    df_cleaned = df[final_cols]

    # Store or save
    cleaned_results[ancestry] = df_cleaned

    # Optional: save to file
    output_path = f'/home/jupyter/workspace/ws_files/TMEM175/TMEM175_{ancestry}/{ancestry}.cleaned_assoc.txt.gz'
    df_cleaned.to_csv(output_path, sep='\t', index=False)

# %%
df = pd.read_csv('/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.cleaned_assoc.txt.gz', sep='\t')
df
# Out:
#        MARKERNAME  CHROMOSOME  POSITION NEA EA       EAF      BETA        OR  \
# 0     chr4:882530           4    882530   C  T  0.249648  0.278139  1.320670
# 1     chr4:882611           4    882611   T  C  0.039216  0.259213  1.295910
# 2     chr4:883018           4    883018   G  A  0.036765  0.207095  1.230100
# 3     chr4:883133           4    883133   G  A  0.015406 -0.502955  0.604741
# 4     chr4:883483           4    883483   G  A  0.025210 -0.468553  0.625907
# ..            ...         ...       ...  .. ..       ...       ...       ...
# 409  chr4:1007954           4   1007954   T  C  0.267157  0.015736  1.015860
# 410  chr4:1008009           4   1008009   C  T  0.432489  0.060521  1.062390
# 411  chr4:1008209           4   1008209   C  T  0.044210 -0.110261  0.895600
# 412  chr4:1008337           4   1008337   C  T  0.267157  0.015736  1.015860
# 413  chr4:1008480           4   1008480   A  G  0.058246 -0.141322  0.868210
#
#            SE    OR_95L   OR_95U         P     N
# 0    0.130923  1.021770  1.70702  0.033631  1693
# 1    0.292887  0.729911  2.30081  0.376139  1693
# 2    0.293740  0.691686  2.18762  0.480791  1693
# 3    0.366620  0.294783  1.24062  0.170104  1693
# 4    0.295532  0.350714  1.11703  0.112862  1693
# ..        ...       ...      ...       ...   ...
# 409  0.121593  0.800447  1.28924  0.897053  1693
# 410  0.109869  0.856571  1.31766  0.581740  1693
# 411  0.245206  0.553853  1.44822  0.652950  1693
# 412  0.121593  0.800447  1.28924  0.897053  1693
# 413  0.221412  0.562547  1.33996  0.523296  1693
#
# [414 rows x 13 columns]

# %% [markdown]
# create PCs file for meta analysis

# %%
# Define ancestries and base path
ancestries = ['AFR', 'AJ', 'AMR', 'EAS', 'EUR']
base_path = '~/workspace/ws_files/'

# List to store each ancestry's PC dataframe
dfs = []

for ancestry in ancestries:
    file_path = f'{base_path}{ancestry}/{ancestry}.noGBA.noNA.txt'
    
    # Read the file
    df = pd.read_csv(file_path, sep='\t')
    
    # Keep only PC1–PC5
    df_pcs = df[['IID','PC1', 'PC2', 'PC3', 'PC4', 'PC5']].copy()
    
    # Add group label
    df_pcs['GROUP'] = ancestry
    
    # Store
    dfs.append(df_pcs)

# Combine all ancestries
merged_df = pd.concat(dfs, ignore_index=True)

# View merged structure
merged_df

# %%
merged_df = merged_df.drop(columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
merged_df

# %%
pcs = pd.read_csv(f'{REL10_PATH}/meta_data/qc_metrics/projected_pcs_vwb.csv')
pcs

# %%
# Merge on IID, keeping all rows from merged_df
final_df = merged_df.merge(pcs.drop(columns=['FID']), on='IID', how='left')

# View result
final_df

# %%
final_df.to_csv('~/workspace/ws_files/PCs_meta.txt', sep='\t', index=False)

# %% [markdown]
# Burden Analyses using RVTests

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

#Loop over all the ancestries and the 2 variant classes - run rvtests for all coding and missense variants
for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running plink to extract {variant_class} variants for ancestry: {ancestry}')
        
        #Extract relevant variants
        ! /home/jupyter/tools/plink2 \
        --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release10_vwb \
        --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
        --extract range {WORK_DIR}/{ancestry}_TMEM175.{variant_class}.variantstoKeep.txt \
        --recode vcf-iid \
        --out {WORK_DIR}/{ancestry}_TMEM175.{variant_class}
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running bgzip and tabix for {variant_class} variants for ancestry: {ancestry}')
        
        ## Bgzip and Tabix (zip and index the file)
        ! bgzip -f {WORK_DIR}/{ancestry}_TMEM175.{variant_class}.vcf
        ! tabix -f -p vcf {WORK_DIR}/{ancestry}_TMEM175.{variant_class}.vcf.gz
# Out:
# Running plink to extract exonic variants for ancestry: AAC
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb
#
# Start time: Fri Jul 25 13:38:41 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24836 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.psam.
# 4117743 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --extract bed1: 4117453 variants excluded.
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# 290 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:38:44 2025
# Running bgzip and tabix for exonic variants for ancestry: AAC
# Running plink to extract nonsynonymous_lof variants for ancestry: AAC
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb
#
# Start time: Fri Jul 25 13:38:48 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24791 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.psam.
# 4117743 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --extract bed1: 4117584 variants excluded.
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# 159 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:38:49 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AAC
# Running plink to extract exonic variants for ancestry: AFR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb
#
# Start time: Fri Jul 25 13:38:53 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24778 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.psam.
# 5095310 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --extract bed1: 5094943 variants excluded.
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# 367 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:38:58 2025
# Running bgzip and tabix for exonic variants for ancestry: AFR
# Running plink to extract nonsynonymous_lof variants for ancestry: AFR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb
#
# Start time: Fri Jul 25 13:39:02 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24819 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.psam.
# 5095310 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --extract bed1: 5095114 variants excluded.
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# 196 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:39:03 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AFR
# Running plink to extract exonic variants for ancestry: AJ
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb
#
# Start time: Fri Jul 25 13:39:07 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24825 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.psam.
# 1752681 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --extract bed1: 1752544 variants excluded.
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# 137 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:39:09 2025
# Running bgzip and tabix for exonic variants for ancestry: AJ
# Running plink to extract nonsynonymous_lof variants for ancestry: AJ
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb
#
# Start time: Fri Jul 25 13:39:13 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24805 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.psam.
# 1752681 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --extract bed1: 1752605 variants excluded.
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# 76 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:39:14 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AJ
# Running plink to extract exonic variants for ancestry: AMR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb
#
# Start time: Fri Jul 25 13:39:18 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24827 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.psam.
# 4434664 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --extract bed1: 4434343 variants excluded.
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# 321 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:39:21 2025
# Running bgzip and tabix for exonic variants for ancestry: AMR
# Running plink to extract nonsynonymous_lof variants for ancestry: AMR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb
#
# Start time: Fri Jul 25 13:39:25 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24800 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.psam.
# 4434664 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --extract bed1: 4434486 variants excluded.
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# 178 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof.vcf
# done.
# End time: Fri Jul 25 13:39:26 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AMR
# Running plink to extract exonic variants for ancestry: CAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb
#
# Start time: Fri Jul 25 13:39:30 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24791 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.psam.
# 2741528 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --extract bed1: 2741300 variants excluded.
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# 228 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:39:33 2025
# Running bgzip and tabix for exonic variants for ancestry: CAS
# Running plink to extract nonsynonymous_lof variants for ancestry: CAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb
#
# Start time: Fri Jul 25 13:39:37 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24822 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.psam.
# 2741528 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --extract bed1: 2741393 variants excluded.
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# 135 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.nonsynonymous_lof.vcf
# done.
# End time: Fri Jul 25 13:39:37 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAS
# Running plink to extract exonic variants for ancestry: EAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb
#
# Start time: Fri Jul 25 13:39:41 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24826 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.psam.
# 3379769 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --extract bed1: 3379462 variants excluded.
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# 307 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:39:46 2025
# Running bgzip and tabix for exonic variants for ancestry: EAS
# Running plink to extract nonsynonymous_lof variants for ancestry: EAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb
#
# Start time: Fri Jul 25 13:39:49 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24811 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.psam.
# 3379769 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --extract bed1: 3379582 variants excluded.
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# 187 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.nonsynonymous_lof.vcf
# done.
# End time: Fri Jul 25 13:39:50 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EAS
# Running plink to extract exonic variants for ancestry: EUR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb
#
# Start time: Fri Jul 25 13:39:54 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24805 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.psam.
# 7745089 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --extract bed1: 7744368 variants excluded.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# 721 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:40:03 2025
# Running bgzip and tabix for exonic variants for ancestry: EUR
# Running plink to extract nonsynonymous_lof variants for ancestry: EUR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb
#
# Start time: Fri Jul 25 13:40:08 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24829 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.psam.
# 7745089 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --extract bed1: 7744655 variants excluded.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# 434 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.nonsynonymous_lof.vcf
# done.
# End time: Fri Jul 25 13:40:11 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EUR
# Running plink to extract exonic variants for ancestry: FIN
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb
#
# Start time: Fri Jul 25 13:40:15 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24836 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.psam.
# 939049 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --extract bed1: 938995 variants excluded.
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# 54 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:40:17 2025
# Running bgzip and tabix for exonic variants for ancestry: FIN
# Running plink to extract nonsynonymous_lof variants for ancestry: FIN
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb
#
# Start time: Fri Jul 25 13:40:21 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24800 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.psam.
# 939049 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --extract bed1: 939024 variants excluded.
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# 25 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:40:21 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: FIN
# Running plink to extract exonic variants for ancestry: MDE
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb
#
# Start time: Fri Jul 25 13:40:25 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24810 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.psam.
# 3023064 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --extract bed1: 3022809 variants excluded.
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# 255 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:40:28 2025
# Running bgzip and tabix for exonic variants for ancestry: MDE
# Running plink to extract nonsynonymous_lof variants for ancestry: MDE
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb
#
# Start time: Fri Jul 25 13:40:32 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24817 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.psam.
# 3023064 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --extract bed1: 3022929 variants excluded.
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# 135 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:40:32 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: MDE
# Running plink to extract exonic variants for ancestry: SAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb
#
# Start time: Fri Jul 25 13:40:36 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24820 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.psam.
# 2227587 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --extract bed1: 2227403 variants excluded.
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# 184 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:40:39 2025
# Running bgzip and tabix for exonic variants for ancestry: SAS
# Running plink to extract nonsynonymous_lof variants for ancestry: SAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb
#
# Start time: Fri Jul 25 13:40:42 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24801 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.psam.
# 2227587 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --extract bed1: 2227480 variants excluded.
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# 107 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof.vcf
# done.
# End time: Fri Jul 25 13:40:43 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: SAS
# Running plink to extract exonic variants for ancestry: CAH
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb
#
# Start time: Fri Jul 25 13:40:47 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24807 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.psam.
# 4063160 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --extract bed1: 4062881 variants excluded.
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# 279 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic.vcf ...
# done.
# End time: Fri Jul 25 13:40:51 2025
# Running bgzip and tabix for exonic variants for ancestry: CAH
# Running plink to extract nonsynonymous_lof variants for ancestry: CAH
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb
#
# Start time: Fri Jul 25 13:40:54 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24802 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.psam.
# 4063160 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --extract bed1: 4063000 variants excluded.
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# 160 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof.vcf
# .done.
# End time: Fri Jul 25 13:40:55 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAH

# %%
#Run RVtests
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running RVtests for {variant_class} variants for ancestry: {ancestry}')
        
        ## RVtests with covariates 
        #Make sure the pheno and covariate file starts with the first 5 columsn: fid, iid, fatid, matid, sex
        #The pheno-name flag only works when the pheno/covar file is structured properly
        ! /home/jupyter/tools/rvtests/executable/rvtest --noweb --hide-covar \
        --out {WORK_DIR}/{ancestry}_TMEM175.burden.{variant_class} \
        --kernel skato \
        --inVcf {WORK_DIR}/{ancestry}_TMEM175.{variant_class}.vcf.gz \
        --pheno /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt \
        --pheno-name PHENO \
        --gene TMEM175 \
        --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt \
        --covar /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt \
        --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
        --freqUpper 0.01
# --burden cmc,zeggini,mb,fp,cmcWald --kernel skat,skato \

# %% [markdown]
# Look at RVtest results SKAT-O

# %%
WORK_DIR = "~/workspace/ws_files/TMEM175"

# %%
# %load_ext rpy2.ipython
# Out:
# /opt/conda/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpmxFdFs", R: "/tmp/RtmpwZrfZW"

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/TMEM175_EUR/EUR_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	40128	128	103	800191	0	0.40194

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/TMEM175_EUR/EUR_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	40128	69	56	76157.3	1	0.856905

# %%
#Check AAC all_coding variant results
! cat {WORK_DIR}/TMEM175_AAC/AAC_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1061	59	46	36140.1	0	0.628155

# %%
#Check AAC all_coding variant results
! cat {WORK_DIR}/TMEM175_AAC/AAC_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1061	38	32	25101.9	0	0.524219

# %%
#Check AFR all_coding variant results
! cat {WORK_DIR}/TMEM175_AFR/AFR_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2738	76	61	37231.7	1	0.738165

# %%
#Check AFR nonsynonymous_lof results
! cat {WORK_DIR}/TMEM175_AFR/AFR_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2738	47	37	22926.7	1	0.743344

# %%
#Check AJ all_coding variant results
! cat {WORK_DIR}/TMEM175_AJ/AJ_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2174	24	18	21568.3	0	0.746508

# %%
#Check AJ nonsynonymous_lof  variant results
! cat {WORK_DIR}/TMEM175_AJ/AJ_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2174	15	12	14410	1	0.580701

# %%
#Check AMR all_coding variant results
! cat {WORK_DIR}/TMEM175_AMR/AMR_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3265	72	53	41022.6	0	0.62126

# %%
#Check AMR nonsynonymous_lof  variant results
! cat {WORK_DIR}/TMEM175_AMR/AMR_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3265	42	29	5872.81	1	0.829141

# %%
#Check CAS all_coding variant results
! cat {WORK_DIR}/TMEM175_CAS/CAS_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1104	39	22	22431.3	1	0.179996

# %%
#Check CAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_CAS/CAS_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1104	26	12	7573.21	0	0.261768

# %%
#Check EAS all_coding variant results
! cat {WORK_DIR}/TMEM175_EAS/EAS_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	4670	52	34	32480.5	0	0.85871

# %%
#Check EAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_EAS/EAS_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	4670	34	21	28568.2	0	0.401021

# %%
#Check MDE all_coding variant results
! cat {WORK_DIR}/TMEM175_MDE/MDE_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1230	47	30	17800.6	0	0.42309

# %%
#Check MDE nonsynonymous_lof  variant results
! cat {WORK_DIR}/TMEM175_MDE/MDE_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1230	24	19	18140.9	0	0.0663344

# %%
#Check SAS all_coding variant results
! cat {WORK_DIR}/TMEM175_SAS/SAS_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	689	25	13	4939.3	0	0.523074

# %%
#Check SAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_SAS/SAS_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	689	18	10	3602.35	1	0.546915

# %%
#Check CAH all_coding variant results
! cat {WORK_DIR}/TMEM175_CAH/CAH_TMEM175.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	900	47	35	12161	1	0.642748

# %%
#Check CAH nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_CAH/CAH_TMEM175.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	900	30	24	15084.2	0	0.433118

# %% [markdown]
# add GWA hits as covariates for TMEM175

# %%
## extract p.m393t using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release10_vwb \
    --chr 4 \
    --from-bp 958159 \
    --to-bp 958159 \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_M393T
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:06:54 2025
# 26046 MiB RAM detected, ~24890 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.psam.
# 4117743 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.bed ...
# done.
# End time: Fri Jul 25 14:06:56 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:06:57 2025
# 26046 MiB RAM detected, ~24866 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.psam.
# 1752681 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.bed ...
# done.
# End time: Fri Jul 25 14:06:58 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:06:59 2025
# 26046 MiB RAM detected, ~24861 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.psam.
# 7745089 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:00 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:02 2025
# 26046 MiB RAM detected, ~24852 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.psam.
# 4434664 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:03 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:04 2025
# 26046 MiB RAM detected, ~24860 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.psam.
# 2741528 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:05 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:06 2025
# 26046 MiB RAM detected, ~24858 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.psam.
# 3379769 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:07 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:08 2025
# 26046 MiB RAM detected, ~24864 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.psam.
# 939049 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:09 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:10 2025
# 26046 MiB RAM detected, ~24865 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.psam.
# 5095310 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:11 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:12 2025
# 26046 MiB RAM detected, ~24863 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.psam.
# 3023064 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:13 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:15 2025
# 26046 MiB RAM detected, ~24869 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.psam.
# 4063160 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:16 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.log.
# Options in effect:
#   --chr 4
#   --from-bp 958159
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb
#   --to-bp 958159
#
# Start time: Fri Jul 25 14:07:17 2025
# 26046 MiB RAM detected, ~24867 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.psam.
# 2227587 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.bed ...
# done.
# End time: Fri Jul 25 14:07:18 2025

# %%
## recode p.m393t using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    # !/home/jupyter/tools/plink2 \
        --bfile {WORK_DIR}/{ancestry}_M393T \
        --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
        --recode A \
        --out {WORK_DIR}/{ancestry}_M393T
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T
#
# Start time: Fri Jul 25 14:12:58 2025
# 26046 MiB RAM detected, ~24880 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.bim.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_M393T.raw
# written.
# End time: Fri Jul 25 14:12:59 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T
#
# Start time: Fri Jul 25 14:13:00 2025
# 26046 MiB RAM detected, ~24846 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.bim.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_M393T.raw
# written.
# End time: Fri Jul 25 14:13:00 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T
#
# Start time: Fri Jul 25 14:13:02 2025
# 26046 MiB RAM detected, ~24841 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_M393T.raw
# written.
# End time: Fri Jul 25 14:13:02 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T
#
# Start time: Fri Jul 25 14:13:04 2025
# 26046 MiB RAM detected, ~24852 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_M393T.raw
# written.
# End time: Fri Jul 25 14:13:04 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T
#
# Start time: Fri Jul 25 14:13:05 2025
# 26046 MiB RAM detected, ~24863 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.bim.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_M393T.raw
# written.
# End time: Fri Jul 25 14:13:06 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T
#
# Start time: Fri Jul 25 14:13:07 2025
# 26046 MiB RAM detected, ~24849 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.bim.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_M393T.raw
# written.
# End time: Fri Jul 25 14:13:07 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T
#
# Start time: Fri Jul 25 14:13:09 2025
# 26046 MiB RAM detected, ~24848 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.bim.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_M393T.raw
# written.
# End time: Fri Jul 25 14:13:09 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T
#
# Start time: Fri Jul 25 14:13:11 2025
# 26046 MiB RAM detected, ~24862 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.bim.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_M393T.raw
# written.
# End time: Fri Jul 25 14:13:11 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T
#
# Start time: Fri Jul 25 14:13:12 2025
# 26046 MiB RAM detected, ~24848 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.bim.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_M393T.raw
# written.
# End time: Fri Jul 25 14:13:13 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T
#
# Start time: Fri Jul 25 14:13:14 2025
# 26046 MiB RAM detected, ~24842 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.bim.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_M393T.raw
# written.
# End time: Fri Jul 25 14:13:14 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T
#   --export A
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T
#
# Start time: Fri Jul 25 14:13:16 2025
# 26046 MiB RAM detected, ~24841 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.bim.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_M393T.raw
# written.
# End time: Fri Jul 25 14:13:16 2025

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','FIN','MDE','SAS','CAH', 'EUR'}

for ancestry in ancestries:
    # read cov file
    cov = pd.read_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt', sep = '\t')
    M393T = pd.read_csv(f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}/{ancestry}_M393T.raw', sep = '\t')
    cov_M393T = cov.merge(M393T[['IID', 'chr4:958159:T:C_T']], on='IID', how='left')
    cov_M393T = cov_M393T.rename(columns={'chr4:958159:T:C_T': 'M393T'})
    cov_M393T = cov_M393T.dropna()

    ## save files 
    cov_M393T.to_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}.cov_M393T.txt', sep = '\t', index=False)

# %%
## extract p.Q65P using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release10_vwb \
    --chr 4 \
    --from-bp 950422 \
    --to-bp 950422 \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_Q65P
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:21 2025
# 26046 MiB RAM detected, ~24828 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.psam.
# 4117743 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr4_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:22 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:24 2025
# 26046 MiB RAM detected, ~24829 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.psam.
# 1752681 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr4_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:24 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:26 2025
# 26046 MiB RAM detected, ~24829 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.psam.
# 7745089 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr4_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:27 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:28 2025
# 26046 MiB RAM detected, ~24810 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.psam.
# 4434664 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr4_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:29 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:31 2025
# 26046 MiB RAM detected, ~24821 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.psam.
# 2741528 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr4_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:32 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:33 2025
# 26046 MiB RAM detected, ~24822 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.psam.
# 3379769 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr4_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:34 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:35 2025
# 26046 MiB RAM detected, ~24821 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.psam.
# 939049 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr4_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:36 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:37 2025
# 26046 MiB RAM detected, ~24819 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.psam.
# 5095310 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr4_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:38 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:39 2025
# 26046 MiB RAM detected, ~24820 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.psam.
# 3023064 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr4_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:40 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:41 2025
# 26046 MiB RAM detected, ~24824 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.psam.
# 4063160 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr4_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:42 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.log.
# Options in effect:
#   --chr 4
#   --from-bp 950422
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb
#   --to-bp 950422
#
# Start time: Fri Jul 25 14:23:44 2025
# 26046 MiB RAM detected, ~24823 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.psam.
# 2227587 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr4_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# 1 variant remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.bed ...
# done.
# End time: Fri Jul 25 14:23:44 2025

# %%
## recode p.m393t using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    # !/home/jupyter/tools/plink2 \
        --bfile {WORK_DIR}/{ancestry}_Q65P \
        --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
        --recode A \
        --out {WORK_DIR}/{ancestry}_Q65P
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P
#
# Start time: Fri Jul 25 14:24:08 2025
# 26046 MiB RAM detected, ~24811 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.bim.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:08 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P
#
# Start time: Fri Jul 25 14:24:09 2025
# 26046 MiB RAM detected, ~24804 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.bim.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:10 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P
#
# Start time: Fri Jul 25 14:24:11 2025
# 26046 MiB RAM detected, ~24800 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# --export A pass 1/1: writindone.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:11 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P
#
# Start time: Fri Jul 25 14:24:13 2025
# 26046 MiB RAM detected, ~24822 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:13 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P
#
# Start time: Fri Jul 25 14:24:14 2025
# 26046 MiB RAM detected, ~24817 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.bim.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:14 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P
#
# Start time: Fri Jul 25 14:24:16 2025
# 26046 MiB RAM detected, ~24824 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.bim.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:16 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P
#
# Start time: Fri Jul 25 14:24:17 2025
# 26046 MiB RAM detected, ~24831 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.bim.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:18 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P
#
# Start time: Fri Jul 25 14:24:19 2025
# 26046 MiB RAM detected, ~24822 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.bim.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:19 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P
#
# Start time: Fri Jul 25 14:24:20 2025
# 26046 MiB RAM detected, ~24813 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.bim.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:21 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P
#
# Start time: Fri Jul 25 14:24:22 2025
# 26046 MiB RAM detected, ~24807 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.bim.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:22 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P
#   --export A
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P
#
# Start time: Fri Jul 25 14:24:24 2025
# 26046 MiB RAM detected, ~24801 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.fam.
# 1 variant loaded from
# /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.bim.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# --export A pass 1/1: writing.done.
# --export A: /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_Q65P.raw
# written.
# End time: Fri Jul 25 14:24:24 2025

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','FIN','MDE','SAS','CAH', 'EUR'}

for ancestry in ancestries:
    # read cov file
    cov_M393T = pd.read_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}.cov_M393T.txt', sep = '\t')
    Q65P = pd.read_csv(f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}/{ancestry}_Q65P.raw', sep = '\t')
    cov_Q65P = cov_M393T.merge(Q65P[['IID', 'chr4:950422:A:C_A']], on='IID', how='left')
    cov_Q65P = cov_Q65P.rename(columns={'chr4:950422:A:C_A': 'Q65P'})
    cov_Q65P = cov_Q65P.dropna()

    ## save files 
    cov_Q65P.to_csv(f'~/workspace/ws_files/{ancestry}/{ancestry}.cov_M393T_Q65P.txt', sep = '\t', index=False)

# %% [markdown]
# Run RVtest with GWAS hits

# %%
#Run RVtests
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running RVtests for {variant_class} variants for ancestry: {ancestry}')
        
        ## RVtests with covariates 
        #Make sure the pheno and covariate file starts with the first 5 columsn: fid, iid, fatid, matid, sex
        #The pheno-name flag only works when the pheno/covar file is structured properly
        ! /home/jupyter/tools/rvtests/executable/rvtest --noweb --hide-covar \
        --out {WORK_DIR}/{ancestry}_TMEM175.GWAhits.{variant_class} \
        --kernel skato \
        --inVcf {WORK_DIR}/{ancestry}_TMEM175.{variant_class}.vcf.gz \
        --pheno /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.cov_M393T_Q65P.txt \
        --pheno-name PHENO \
        --gene TMEM175 \
        --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt \
        --covar /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.cov_M393T_Q65P.txt \
        --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P \
        --freqUpper 0.01
# --burden cmc,zeggini,mb,fp,cmcWald --kernel skat,skato \
# Out:
# Running RVtests for exonic variants for ancestry: AAC
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:29:59 2025
# [INFO]	Loaded [ 1207 ] samples from genotype files
# [INFO]	Loaded [ 1014 ] sample phenotypes
# [WARN]	Total [ 193 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BBDP_001037 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001042 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000142 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000150 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000204 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000215 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000270 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000375 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000418 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000470 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 183 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 429 male, 585 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
# [INFO]	Loaded 306 cases, 708 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 1014 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 59 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:00 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: AAC
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:01 2025
# [INFO]	Loaded [ 1207 ] samples from genotype files
# [INFO]	Loaded [ 1014 ] sample phenotypes
# [WARN]	Total [ 193 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BBDP_001037 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001042 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000142 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000150 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000204 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000215 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000270 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000375 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000418 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000470 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 183 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 429 male, 585 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AAC/AAC.cov_M393T_Q65P.txt
# [INFO]	Loaded 306 cases, 708 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 1014 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 38 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:02 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for exonic variants for ancestry: AFR
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:03 2025
# [INFO]	Loaded [ 3581 ] samples from genotype files
# [INFO]	Loaded [ 2547 ] sample phenotypes
# [WARN]	Total [ 1034 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BCM_000096 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000173 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000224 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000277 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000286 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000287 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000315 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000402 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000415 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000424 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 1024 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 1328 male, 1219 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
# [INFO]	Loaded 997 cases, 1550 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 2547 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 76 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:04 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: AFR
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:05 2025
# [INFO]	Loaded [ 3581 ] samples from genotype files
# [INFO]	Loaded [ 2547 ] sample phenotypes
# [WARN]	Total [ 1034 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BCM_000096 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000173 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000224 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000277 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000286 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000287 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000315 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000402 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000415 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000424 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 1024 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 1328 male, 1219 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AFR/AFR.cov_M393T_Q65P.txt
# [INFO]	Loaded 997 cases, 1550 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 2547 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 47 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:06 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for exonic variants for ancestry: AJ
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:08 2025
# [INFO]	Loaded [ 2716 ] samples from genotype files
# [INFO]	Loaded [ 1421 ] sample phenotypes
# [WARN]	Total [ 1295 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ APGS_001477 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000014 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000024 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000047 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000059 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000076 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000161 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000242 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000402 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000468 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 1285 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 925 male, 496 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
# [INFO]	Loaded 1203 cases, 218 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 1421 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 24 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:08 2025
# [INFO]	Analysis took 0 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: AJ
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:10 2025
# [INFO]	Loaded [ 2716 ] samples from genotype files
# [INFO]	Loaded [ 1421 ] sample phenotypes
# [WARN]	Total [ 1295 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ APGS_001477 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000014 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000024 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000047 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000059 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000076 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000161 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000242 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000402 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000468 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 1285 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 925 male, 496 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AJ/AJ.cov_M393T_Q65P.txt
# [INFO]	Loaded 1203 cases, 218 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 1421 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 15 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:11 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for exonic variants for ancestry: AMR
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:12 2025
# [INFO]	Loaded [ 3471 ] samples from genotype files
# [INFO]	Loaded [ 3104 ] sample phenotypes
# [WARN]	Total [ 367 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BBDP_000167 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000219 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000446 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000452 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000595 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000639 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000807 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001035 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001057 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001064 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 357 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 1461 male, 1643 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
# [INFO]	Loaded 1772 cases, 1332 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 3104 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 72 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:13 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: AMR
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:14 2025
# [INFO]	Loaded [ 3471 ] samples from genotype files
# [INFO]	Loaded [ 3104 ] sample phenotypes
# [WARN]	Total [ 367 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BBDP_000167 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000219 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000446 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000452 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000595 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000639 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000807 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001035 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001057 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001064 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 357 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 1461 male, 1643 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/AMR/AMR.cov_M393T_Q65P.txt
# [INFO]	Loaded 1772 cases, 1332 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 3104 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 42 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:15 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for exonic variants for ancestry: CAS
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:16 2025
# [INFO]	Loaded [ 1518 ] samples from genotype files
# [INFO]	Loaded [ 861 ] sample phenotypes
# [WARN]	Total [ 657 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ BCM_000079 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000141 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000271 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000483 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000557 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BRFAA_000002 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BRFAA_000048 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ CATPD_000020 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ CATPD_000081 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ CATPD_000087 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 647 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 348 male, 513 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt
# [INFO]	Loaded 501 cases, 360 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 861 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 39 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:17 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: CAS
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/CAS/CAS.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
# ...
# [INFO]	Loaded 247 male, 158 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt
# [INFO]	Loaded 248 cases, 157 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 405 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 25 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:45 2025
# [INFO]	Analysis took 2 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: SAS
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:47 2025
# [INFO]	Loaded [ 870 ] samples from genotype files
# [INFO]	Loaded [ 405 ] sample phenotypes
# [WARN]	Total [ 465 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ APGS_001174 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_001310 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_001558 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_001714 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_001778 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_002119 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_003845 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ APGS_004105 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_000539 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001159 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 455 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 247 male, 158 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/SAS/SAS.cov_M393T_Q65P.txt
# [INFO]	Loaded 248 cases, 157 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 405 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 18 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:48 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for exonic variants for ancestry: CAH
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.GWAhits.exonic]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.exonic.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.GWAhits.exonic
#     --covar /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:50 2025
# [INFO]	Loaded [ 1039 ] samples from genotype files
# [INFO]	Loaded [ 845 ] sample phenotypes
# [WARN]	Total [ 194 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ APGS_003594 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001043 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000127 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000230 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000444 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000733 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000798 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BIOFIND_000151 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BLAACPD-KPM_000001 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BLAACPD-RUSH_000020 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 184 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 443 male, 402 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
# [INFO]	Loaded 553 cases, 292 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 845 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 47 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:51 2025
# [INFO]	Analysis took 1 seconds
# RVTESTS finished successfully
# Running RVtests for nonsynonymous_lof variants for ancestry: CAH
# Thank you for using rvtests (version: 20190205, git: c86e589efef15382603300dc7f4c3394c82d69b8)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, plase send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# The following parameters are available.  Ones with "[]" are in effect:
#
# Available Options
#       Basic Input/Output:
#                           --inVcf [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof.vcf.gz]
#                           --inBgen [], --inBgenSample [], --inKgg []
#                           --out [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.GWAhits.nonsynonymous_lof]
#                           --outputRaw
#        Specify Covariate:
#                           --covar [/home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt]
#                           --covar-name [SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P]
#                           --sex
#        Specify Phenotype:
#                           --pheno [/home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt]
#                           --inverseNormal, --useResidualAsPhenotype, --mpheno []
#                           --pheno-name [PHENO], --qtl, --multiplePheno []
#         Specify Genotype: --dosage [], --multipleAllele
#     Chromosome X Options: --xLabel [], --xParRegion []
#            People Filter: --peopleIncludeID [], --peopleIncludeFile []
#                           --peopleExcludeID [], --peopleExcludeFile []
#              Site Filter: --rangeList [], --rangeFile [], --siteFile []
#                           --siteDepthMin [], --siteDepthMax [], --siteMACMin []
#                           --annoType []
#          Genotype Filter: --indvDepthMin [], --indvDepthMax [], --indvQualMin []
#        Association Model: --single [], --burden [], --vt [], --kernel [skato]
#                           --meta []
#      Family-based Models: --kinship [], --xHemiKinship [], --kinshipEigen []
#                           --xHemiKinshipEigen [], --boltPlink []
#                           --boltPlinkNoCheck
#           Grouping Unit :
#                           --geneFile [/home/jupyter/workspace/ws_files/refFlat_HG38.txt]
#                           --gene [TMEM175], --setList [], --setFile [], --set []
#         Frequency Cutoff: --freqUpper [0.01], --freqLower []
#             Missing Data: --impute [], --imputePheno, --imputeCov
#     Conditional Analysis: --condition []
#      Auxiliary Functions: --noweb [true], --hide-covar [true], --numThread []
#                           --outputID, --help
#
# Effective Options
#     --inVcf /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.nonsynonymous_lof.vcf.gz
#     --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.GWAhits.nonsynonymous_lof
#     --covar /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
#     --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5,M393T,Q65P
#     --pheno /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
#     --pheno-name PHENO
#     --kernel skato
#     --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt
#     --gene TMEM175
#     --freqUpper 0.01
#     --noweb
#     --hide-covar
#
# [INFO]	Program version: 20190205
# [INFO]	Analysis started at: Fri Jul 25 14:30:52 2025
# [INFO]	Loaded [ 1039 ] samples from genotype files
# [INFO]	Loaded [ 845 ] sample phenotypes
# [WARN]	Total [ 194 ] samples are dropped from VCF file due to missing phenotype.
# [WARN]	Drop sample [ APGS_003594 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BBDP_001043 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000127 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000230 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000444 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000733 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BCM_000798 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BIOFIND_000151 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BLAACPD-KPM_000001 ] from VCF file due to missing phenotype
# [WARN]	Drop sample [ BLAACPD-RUSH_000020 ] from VCF file due to missing phenotype
# [WARN]	Skip outputting additional [ 184 ] samples due to missing phenotype.
# [INFO]	Begin to read covariate file
# [INFO]	Loaded 443 male, 402 female and 0 sex-unknown samples from /home/jupyter/workspace/ws_files/CAH/CAH.cov_M393T_Q65P.txt
# [INFO]	Loaded 553 cases, 292 controls, and 0 missing phenotypes
# [WARN]	-- Enabling binary phenotype mode --
# [INFO]	Analysis begins with [ 845 ] samples...
# [INFO]	SKAT-O test significance will be evaluated using weight = Beta[beta1 = 1.00, beta2 = 25.00]
# [INFO]	Loaded [ 1 ] genes.
# [INFO]	Impute missing genotype to mean (by default)
# [INFO]	Set upper minor allele frequency limit to 0.01
# [INFO]	Analysis started
# [INFO]	Analyzed [ 30 ] variants from [ 1 ] genes/regions
# [INFO]	Analysis ends at: Fri Jul 25 14:30:52 2025
# [INFO]	Analysis took 0 seconds
# RVTESTS finished successfully

# %%
WORK_DIR = "~/workspace/ws_files/TMEM175"

# %%
#Check AAC all_coding variant results
! cat {WORK_DIR}/TMEM175_AAC/AAC_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1014	59	45	7107.84	0	0.424299

# %%
#Check AAC nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_AAC/AAC_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1014	38	31	3376.87	0	0.622341

# %%
#Check AFR all_coding variant results
! cat {WORK_DIR}/TMEM175_AFR/AFR_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2547	76	60	2155.27	1	0.873784

# %%
#Check AFR nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_AFR/AFR_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	2547	47	37	5176.09	1	0.703047

# %%
#Check AJ all_coding variant results
! cat {WORK_DIR}/TMEM175_AJ/AJ_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1421	24	16	4023.79	0	0.212791

# %%
#Check AJ nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_AJ/AJ_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1421	15	10	3156.23	0	0.240471

# %%
#Check AMR all_coding variant results
! cat {WORK_DIR}/TMEM175_AMR/AMR_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3104	72	51	7510.5	0	0.5333

# %%
#Check AMR nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_AMR/AMR_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3104	42	29	11430.4	1	0.143274

# %%
#Check CAS all_coding variant results
! cat {WORK_DIR}/TMEM175_CAS/CAS_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	861	39	18	480.407	1	0.688999

# %%
#Check CAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_CAS/CAS_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	861	26	9	NA	NA	NA

# %%
#Check EAS all_coding variant results
! cat {WORK_DIR}/TMEM175_EAS/EAS_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3364	52	32	11949.2	1	0.255894

# %%
#Check EAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_EAS/EAS_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	3364	34	19	20875.8	1	0.0442927

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/TMEM175_EUR/EUR_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	25226	128	95	153490	0	0.062384

# %%
#Check EUR nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_EUR/EUR_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	25226	69	55	83041.7	0	0.141847

# %%
#Check MDE all_coding variant results
! cat {WORK_DIR}/TMEM175_MDE/MDE_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1070	47	28	3884.07	0	0.358024

# %%
#Check MDE nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_MDE/MDE_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	1070	24	17	1097.97	0	0.608166

# %%
#Check SAS all_coding variant results
! cat {WORK_DIR}/TMEM175_SAS/SAS_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	405	25	10	528.451	0	0.465113

# %%
#Check SAS nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_SAS/SAS_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	405	18	8	208.184	0	0.610274

# %%
#Check CAH all_coding variant results
! cat {WORK_DIR}/TMEM175_CAH/CAH_TMEM175.GWAhits.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	845	47	34	10121.7	1	0.273611

# %%
#Check CAH nonsynonymous_lof variant results
! cat {WORK_DIR}/TMEM175_CAH/CAH_TMEM175.GWAhits.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# TMEM175	4:932459-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655,4:932386-958655	845	30	23	14266.3	1	0.00597753

# %% [markdown]
# LD pruning(in EUR)

# %%
WORK_DIR = "~/workspace/ws_files/"

# %%
# Make sure to use high-quality SNPs
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/TMEM175/TMEM175_EUR/EUR_TMEM175 \
--maf 0.01 \
--geno 0.05 \
--hwe 1e-5 0.001 \
--make-bed \
--keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep \
--exclude {WORK_DIR}/exclusion_regions_hg38.txt \
--out {WORK_DIR}/TMEM175/TMEM175_UNIMPUTED
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//TMEM175/TMEM175_UNIMPUTED.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175
#   --exclude /home/jupyter/workspace/ws_files//exclusion_regions_hg38.txt
#   --geno 0.05
#   --hwe 1e-3
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --make-bed
#   --out /home/jupyter/workspace/ws_files//TMEM175/TMEM175_UNIMPUTED
#
# Start time: Fri Jul 25 15:20:54 2025
# 26046 MiB RAM detected, ~24770 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175.fam.
# 7209 variants loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --exclude: 7209 variants remaining.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# done.lating allele frequencies... 0%
# --geno: 3538 variants removed due to missing genotype data.
# Error: --hwe filter is suspiciously strict for the sample size; you may be
# filtering out many variants with association signals.
# If you are performing routine QC, consider using --hwe with a sample-size term
# (e.g. "--hwe 1e-5 0.001" results in a threshold of 1e-6 with 1000 observations,
# 1e-7 with 2000 observations, etc.), and/or specifying 'keep-fewhet' to remove
# only variants with heterozygosity excess.
# Alternatively, if the strictness is intentional (e.g. you are preparing data
# for a method that requires variants to be near Hardy-Weinberg equilibrium),
# explicitly specify a sample-size term of 0.
# End time: Fri Jul 25 15:20:54 2025

# %%
# Prune out unnecessary SNPs (only need to do this to generate PCs)
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/TMEM175/TMEM175_UNIMPUTED \
--indep-pairwise 50 5 0.5 \
--out {WORK_DIR}/TMEM175/prune_TMEM175
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//TMEM175/prune_TMEM175.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//TMEM175/TMEM175_UNIMPUTED
#   --indep-pairwise 50 5 0.5
#   --out /home/jupyter/workspace/ws_files//TMEM175/prune_TMEM175
#
# Start time: Fri Jul 25 15:24:04 2025
# 26046 MiB RAM detected, ~24800 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53641 samples (23385 females, 30256 males; 53641 founders) loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_UNIMPUTED.fam.
# 366 variants loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_UNIMPUTED.bim.
# 1 binary phenotype loaded (24208 cases, 9662 controls).
# Calculating allele frequencies... done.
# --indep-pairwise (1 compute thread): 259/366 variants removed.
# Variant lists written to
# /home/jupyter/workspace/ws_files//TMEM175/prune_TMEM175.prune.in and
# /home/jupyter/workspace/ws_files//TMEM175/prune_TMEM175.prune.out .
# End time: Fri Jul 25 15:24:05 2025

# %%
# !wc -l {WORK_DIR}/TMEM175/prune_TMEM175.prune.in
# Out:
# 107 /home/jupyter/workspace/ws_files//TMEM175/prune_TMEM175.prune.in

# %%
# 4.67E-4

# %% [markdown]
# zoom locus plot

# %%
## locus zoom format
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    df = pd.read_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
    df['b'] = np.log(df['OR'])
    export_ldassoc = df[['#CHROM', 'POS', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P']].copy()
    export_ldassoc = export_ldassoc.rename(columns = {'#CHROM': 'CHROM', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p'})
    # save to files
    export_ldassoc.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.formatted.tab', sep = '\t', index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# GCTA cojo analysis

# %%
## cojo format
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'

    sumstats = pd.read_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
    #Format summary statistics for GCTA-COJO
    #First get the log odds ratio - this is required for COJO
    #1) For a case-control study, the effect size should be log(odds ratio) with its corresponding standard error.
    sumstats_formatted = sumstats.copy()
    sumstats_formatted['b'] = np.log(sumstats_formatted['OR'])

    #Now select just the necessary columns for COJO
    sumstats_export = sumstats_formatted[['ID', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P', 'OBS_CT']].copy()

    #Rename columns following COJO format
    sumstats_export = sumstats_export.rename(columns = {'ID':'SNP', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p', 'OBS_CT':'N'})

    #Export
    sumstats_export.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.sumstats.ma', sep = '\t', index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log

# %%
# install GCTA-COJO run in terminal
! wget https://yanglab.westlake.edu.cn/software/gcta/bin/gcta-1.94.1-linux-kernel-3-x86_64.zip
! unzip gcta-1.95.0-linux-kernel-3-x86_64.zip

# %%
! /home/jupyter/tools/gcta-1.95.0-linux-kernel-3-x86_64/gcta64 --version
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:39:09 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Warning: Warning: No output file specified. Using default output file 'output'.
# Accepted options:
# Error:
#   invalid option "--version".
#
# An error occurs, please check the options or data

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/TMEM175/TMEM175_{ancestry}'
    
    #Select multiple associated SNPs based on LD pruning p-value 4.67e-4
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.95.0-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_TMEM175 \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 4.67e-4 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.ldprune.COJO
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:28 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.fam].
# 1215 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bim].
# 3520 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bed] in SNP-major format ...
# Genotype data for 1215 individuals and 3520 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 607 SNPs (2913 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC.all_adj.sumstats.ma] ...
# GWAS summary statistics of 604 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AAC/AAC.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 604 SNPs: 5.96293 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 603 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 603 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:29 UTC on Fri Jul 25 2025
# Overall computational time: 0.59 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:30 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.fam].
# 3472 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bim].
# 1378 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bed] in SNP-major format ...
# Genotype data for 3472 individuals and 1378 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 414 SNPs (964 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.sumstats.ma] ...
# GWAS summary statistics of 414 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 414 SNPs: 8.21794 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 412 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 412 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 411 remaining SNPs to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AJ/AJ.all_adj.ldprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 15:43:31 UTC on Fri Jul 25 2025
# Overall computational time: 0.94 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:32 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.fam].
# 58823 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bim].
# 7209 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bed] in SNP-major format ...
# Genotype data for 58823 individuals and 7209 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 396 SNPs (6813 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 397 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 397 SNPs: 5.96265 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 395 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 395 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 394 remaining SNPs to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EUR/EUR.all_adj.ldprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 15:43:40 UTC on Fri Jul 25 2025
# Overall computational time: 7.87 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:42 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.fam].
# 3608 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bim].
# 3883 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bed] in SNP-major format ...
# Genotype data for 3608 individuals and 3883 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 377 SNPs (3506 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 374 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AMR/AMR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 374 SNPs: 5.73422 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 373 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 373 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:42 UTC on Fri Jul 25 2025
# Overall computational time: 0.73 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:43 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.fam].
# 1691 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bim].
# 2501 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bed] in SNP-major format ...
# Genotype data for 1691 individuals and 2501 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 423 SNPs (2078 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 392 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAS/CAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 392 SNPs: 4.36192 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 389 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 389 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:44 UTC on Fri Jul 25 2025
# Overall computational time: 0.57 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:45 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.fam].
# 6662 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bim].
# 3374 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bed] in SNP-major format ...
# Genotype data for 6662 individuals and 3374 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 368 SNPs (3006 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 368 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 368 SNPs: 5.15033 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 368 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 368 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 367 remaining SNPs to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_EAS/EAS.all_adj.ldprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 15:43:47 UTC on Fri Jul 25 2025
# Overall computational time: 1.31 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:48 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.fam].
# 144 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bim].
# 645 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bed] in SNP-major format ...
# Genotype data for 144 individuals and 645 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 422 SNPs (223 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.sumstats.ma] ...
# GWAS summary statistics of 405 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 405 SNPs: 18.454 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 405 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 405 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 3 associated SNPs are selected.
# Performing joint analysis on all the 3 selected signals ...
# Saving the 3 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 3 independent signals to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 355 remaining SNPs to [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_FIN/FIN.all_adj.ldprune.COJO.cma.cojo] ...
# (47 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 15:43:49 UTC on Fri Jul 25 2025
# Overall computational time: 0.99 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:50 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.fam].
# 3780 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bim].
# 4429 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bed] in SNP-major format ...
# Genotype data for 3780 individuals and 4429 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 598 SNPs (3831 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 596 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_AFR/AFR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 596 SNPs: 4.94626 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 594 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 594 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:51 UTC on Fri Jul 25 2025
# Overall computational time: 0.88 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:52 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.fam].
# 1493 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bim].
# 2741 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bed] in SNP-major format ...
# Genotype data for 1493 individuals and 2741 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 400 SNPs (2341 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE.all_adj.sumstats.ma] ...
# GWAS summary statistics of 397 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_MDE/MDE.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 397 SNPs: 5.04974 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 396 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 396 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:53 UTC on Fri Jul 25 2025
# Overall computational time: 0.57 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:54 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.fam].
# 1111 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bim].
# 3430 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bed] in SNP-major format ...
# Genotype data for 1111 individuals and 3430 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 520 SNPs (2910 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH.all_adj.sumstats.ma] ...
# GWAS summary statistics of 533 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_CAH/CAH.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 533 SNPs: 5.52068 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 519 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 519 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:55 UTC on Fri Jul 25 2025
# Overall computational time: 0.56 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 15:43:56 UTC on Fri Jul 25 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS.all_adj.sumstats.ma
# --cojo-p 0.000467
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.fam].
# 945 individuals to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bim].
# 2103 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bed] in SNP-major format ...
# Genotype data for 945 individuals and 2103 SNPs to be included from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS_TMEM175.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 474 SNPs (1629 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 473 SNPs read from [/home/jupyter/workspace/ws_files/TMEM175/TMEM175_SAS/SAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 473 SNPs: 5.66068 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 471 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 471 SNPs to select association signals ... (p cutoff = 0.000467; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 15:43:56 UTC on Fri Jul 25 2025
# Overall computational time: 0.48 sec.
