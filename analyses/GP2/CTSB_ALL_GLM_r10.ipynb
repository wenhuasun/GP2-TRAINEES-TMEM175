# %% [markdown]
# CTSB - Single gene analysis in GP2 Neurobooster genotyping data (all ancestries)
#
# Project: GP2 CTSB
#
# Version: Python/3.10.15, R/4.3.3
#
# Notebook Overview
#
# Description Loading Python libraries Set paths Make working directory
#
# Installing packages
#
# Create a covariate file with GP2 data
#
# Annotation of the gene CTSB
#
# Association analysis to compare allele frequencies between cases and controls
#
# GLM analysis adjusting for gender, age, PC1-5
#
# Burden test(SkatO, Skat, cmc,zeggini,mb,fp,cmcWald)
#
# Conditional analysis

# %% [markdown]
# Loading Python libraries

# %%
# Use pathlib for file path manipulation
import pathlib

# Install numpy
import numpy as np

# Install Pandas for tabular data
import pandas as pd

# Install plotnine: a ggplot2-compatible Python plotting package
from plotnine import *

# Always show all columns in a Pandas DataFrame
pd.set_option('display.max_columns', None)

# %% [markdown]
# Set paths

# %%
REL10_PATH = pathlib.Path(pathlib.Path.home(), 'workspace/gp2_tier2_eu_release10')
# !ls -hal {REL10_PATH}
# Out:
# total 100K
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 clinical_data
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 imputed_genotypes
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 meta_data
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 raw_genotypes
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 raw_genotypes_flipped
# -r--r--r--. 1 jupyter users 100K Jun 30 20:07 README_release10_01072025.txt
# dr-xr-xr-x. 1 jupyter users    0 Jul 26 10:56 wgs

# %% [markdown]
# Make working directory

# %%
! mkdir ~/workspace/ws_files/CTSB

# %%
WORK_DIR = "~/workspace/ws_files/CTSB/"

# %%
# make sure all tools installed
! ls /home/jupyter/tools
# Out:
# annovar				       plink2
# annovar.latest.tar.gz		       plink2_linux_x86_64_latest.zip
# gcta-1.95.0-linux-kernel-3-x86_64      plink_linux_x86_64_20190304.zip
# gcta-1.95.0-linux-kernel-3-x86_64.zip  prettify
# intel-simplified-software-license.txt  rvtests
# LICENSE				       toy.map
# __MACOSX			       toy.ped
# plink				       vcf_subset

# %%
# give permission

# chmod to make sure you have permission to run the program
! chmod u+x /home/jupyter/tools/plink
! chmod u+x /home/jupyter/tools/plink2
! chmod 777 /home/jupyter/tools/rvtests/executable/rvtest

# %%
# %%bash
# # making working directory
# #Loop over all the ancestries
# for ancestry in {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'} ;
# do
#
# #Make a folder for each ancestry
# mkdir ~/workspace/ws_files/CTSB/CTSB_"$ancestry"
#
# done

# %%
# covariate file has been created in another notebook without GBA carriers

# %% [markdown]
# Annotation of the gene
#
# Extract the region using PLINK
#
# Extract CTSB gene
#
# CTSB coordinates: Chromosome 8: 11,842,524-11,869,533(GRCh38/hg38)

# %%
## extract region using plink
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr8_{ancestry}_release10_vwb \
    --chr 8 \
    --from-bp 11792524 \
    --to-bp 11919533 \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_CTSB
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:32 2025
# 26046 MiB RAM detected, ~24671 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.psam.
# 715411 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# 1057 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bed ... done.
# End time: Sat Jul 26 12:49:33 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:34 2025
# 26046 MiB RAM detected, ~24665 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.psam.
# 3550811 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# 5507 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bed ... 0%
# End time: Sat Jul 26 12:49:38 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:39 2025
# 26046 MiB RAM detected, ~24635 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.psam.
# 2403439 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# 3639 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bed ... 0%
# End time: Sat Jul 26 12:49:42 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:43 2025
# 26046 MiB RAM detected, ~24633 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.psam.
# 3293679 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# 5526 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bed ... done.
# End time: Sat Jul 26 12:49:47 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:48 2025
# 26046 MiB RAM detected, ~24626 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.psam.
# 6200464 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# 10388 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bed ... 0%
# End time: Sat Jul 26 12:49:54 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:55 2025
# 26046 MiB RAM detected, ~24617 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.psam.
# 3231362 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# 5508 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bed ... 0%
# End time: Sat Jul 26 12:49:58 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:49:59 2025
# 26046 MiB RAM detected, ~24626 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.psam.
# 2184117 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# 3249 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bed ... done.
# End time: Sat Jul 26 12:50:01 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:50:02 2025
# 26046 MiB RAM detected, ~24629 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.psam.
# 1376363 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# 2256 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bed ... done.
# End time: Sat Jul 26 12:50:04 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:50:05 2025
# 26046 MiB RAM detected, ~24630 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.psam.
# 1753806 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# 2801 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bed ... done.
# End time: Sat Jul 26 12:50:07 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:50:08 2025
# 26046 MiB RAM detected, ~24629 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.psam.
# 2703578 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# 4213 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim ...
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bed ... done.
# End time: Sat Jul 26 12:50:11 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.log.
# Options in effect:
#   --chr 8
#   --from-bp 11792524
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb
#   --to-bp 11919533
#
# Start time: Sat Jul 26 12:50:12 2025
# 26046 MiB RAM detected, ~24614 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.psam.
# 4081203 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# 7164 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bed ... 0%
# End time: Sat Jul 26 12:50:15 2025

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}/'
    
    ! head -n 1 {WORK_DIR}/{ancestry}_CTSB.fam > {WORK_DIR}/{ancestry}_s1.txt

# %%
! head /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_s1.txt

# %% [markdown]
# Turn binary files into VCF

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep {WORK_DIR}/{ancestry}_s1.txt \
    --make-bed \
    --out {WORK_DIR}/{ancestry}_CTSB_v1
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#
# Start time: Sat Jul 26 12:51:59 2025
# 26046 MiB RAM detected, ~24625 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam.
# 1057 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:51:59 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:00 2025
# 26046 MiB RAM detected, ~24609 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam.
# 5507 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:01 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#
# Start time: Sat Jul 26 12:52:02 2025
# 26046 MiB RAM detected, ~24623 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam.
# 3639 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --keep: 1 sample remaining.
# 1 sample (1 female, 0 males; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:03 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#
# Start time: Sat Jul 26 12:52:04 2025
# 26046 MiB RAM detected, ~24614 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam.
# 5526 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --keep: 1 sample remaining.
# 1 sample (1 female, 0 males; 1 founder) remaining after main filters.
# 0 cases and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:05 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:06 2025
# 26046 MiB RAM detected, ~24631 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam.
# 10388 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 0 cases and 1 control remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:06 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#
# Start time: Sat Jul 26 12:52:07 2025
# 26046 MiB RAM detected, ~24639 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam.
# 5508 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:08 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:09 2025
# 26046 MiB RAM detected, ~24625 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam.
# 3249 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:10 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#
# Start time: Sat Jul 26 12:52:11 2025
# 26046 MiB RAM detected, ~24622 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam.
# 2256 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.fam ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bim ...
# done.ng /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bed ... 0%
# End time: Sat Jul 26 12:52:12 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:13 2025
# 26046 MiB RAM detected, ~24614 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam.
# 2801 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:13 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:14 2025
# 26046 MiB RAM detected, ~24609 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam.
# 4213 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:15 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --keep /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:16 2025
# 26046 MiB RAM detected, ~24633 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam.
# 7164 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bed ...
# done.
# End time: Sat Jul 26 12:52:17 2025

# %%
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB_v1 \
    --recode vcf-fid \
    --out {WORK_DIR}/{ancestry}_CTSB_v1
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1
#
# Start time: Sat Jul 26 12:52:42 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24629 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.fam.
# 1057 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:43 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:44 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24618 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.fam.
# 5507 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:44 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1
#
# Start time: Sat Jul 26 12:52:45 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24635 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (1 female, 0 males; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.fam.
# 3639 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:46 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1
#
# Start time: Sat Jul 26 12:52:47 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24623 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (1 female, 0 males; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.fam.
# 5526 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.bim.
# Note: No phenotype data present.
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:47 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:48 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24617 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.fam.
# 10388 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.bim.
# 1 binary phenotype loaded (0 cases, 1 control).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.vcf
# done.
# End time: Sat Jul 26 12:52:48 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1
#
# Start time: Sat Jul 26 12:52:50 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24640 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.fam.
# 5508 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:50 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:51 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24632 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.fam.
# 3249 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:51 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1
#
# Start time: Sat Jul 26 12:52:52 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24627 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.fam.
# 2256 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:53 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:54 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24626 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.fam.
# 2801 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:54 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1
#
# Start time: Sat Jul 26 12:52:55 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24625 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.fam.
# 4213 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:56 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1
#
# Start time: Sat Jul 26 12:52:57 2025
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 26046 MiB RAM detected, ~24621 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.fam.
# 7164 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.vcf
# .done.
# End time: Sat Jul 26 12:52:57 2025

# %%
### Bgzip and Tabix (zip and index the file)
for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    ! bgzip -f {WORK_DIR}/{ancestry}_CTSB_v1.vcf
    ! tabix -f -p vcf {WORK_DIR}/{ancestry}_CTSB_v1.vcf.gz

# %% [markdown]
# Annotate using ANNOVAR

# %%
## annotate using ANNOVAR

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ! perl /home/jupyter/tools/annovar/table_annovar.pl {WORK_DIR}/{ancestry}_CTSB_v1.vcf.gz /home/jupyter/tools/annovar/humandb/ -buildver hg38 \
    -out {WORK_DIR}/{ancestry}_CTSB.annovar \
    -remove -protocol refGene,clinvar_20140902 \
    -operation g,f \
    --nopolish \
    -nastring . \
    -vcfinput
# Out:
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput>
# NOTICE: Finished reading 1064 lines from VCF file
# NOTICE: A total of 1057 locus in VCF file passed QC threshold, representing 1008 SNPs (625 transitions and 383 transversions) and 49 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1008 SNP genotypes (625 transitions and 383 transversions) and 49 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 1057 unique variants in 1057 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 1057 unique variants in 1057 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.annovar.hg38_multianno.vcf
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput>
# NOTICE: Finished reading 5514 lines from VCF file
# NOTICE: A total of 5507 locus in VCF file passed QC threshold, representing 5214 SNPs (3092 transitions and 2122 transversions) and 293 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 5214 SNP genotypes (3092 transitions and 2122 transversions) and 293 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 5507 unique variants in 5507 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 5507 unique variants in 5507 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput>
# NOTICE: Finished reading 3646 lines from VCF file
# NOTICE: A total of 3639 locus in VCF file passed QC threshold, representing 3446 SNPs (2017 transitions and 1429 transversions) and 193 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3446 SNP genotypes (2017 transitions and 1429 transversions) and 193 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.refGene.exonic_variant_function
# Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3639 unique variants in 3639 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3639 unique variants in 3639 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput>
# NOTICE: Finished reading 5533 lines from VCF file
# NOTICE: A total of 5526 locus in VCF file passed QC threshold, representing 5217 SNPs (2981 transitions and 2236 transversions) and 309 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 5217 SNP genotypes (2981 transitions and 2236 transversions) and 309 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 5526 unique variants in 5526 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 5526 unique variants in 5526 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput>
# NOTICE: Finished reading 10395 lines from VCF file
# NOTICE: A total of 10388 locus in VCF file passed QC threshold, representing 9808 SNPs (5901 transitions and 3907 transversions) and 580 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 9808 SNP genotypes (5901 transitions and 3907 transversions) and 580 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 10388 unique variants in 10388 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 10388 unique variants in 10388 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput>
# NOTICE: Finished reading 5515 lines from VCF file
# NOTICE: A total of 5508 locus in VCF file passed QC threshold, representing 5198 SNPs (3012 transitions and 2186 transversions) and 310 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 5198 SNP genotypes (3012 transitions and 2186 transversions) and 310 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 5508 unique variants in 5508 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 5508 unique variants in 5508 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 3256 lines from VCF file
# NOTICE: A total of 3249 locus in VCF file passed QC threshold, representing 3069 SNPs (1814 transitions and 1255 transversions) and 180 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3069 SNP genotypes (1814 transitions and 1255 transversions) and 180 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3249 unique variants in 3249 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3249 unique variants in 3249 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput>
# NOTICE: Finished reading 2263 lines from VCF file
# NOTICE: A total of 2256 locus in VCF file passed QC threshold, representing 2141 SNPs (1254 transitions and 887 transversions) and 115 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2141 SNP genotypes (1254 transitions and 887 transversions) and 115 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2256 unique variants in 2256 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2256 unique variants in 2256 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 2808 lines from VCF file
# NOTICE: A total of 2801 locus in VCF file passed QC threshold, representing 2644 SNPs (1602 transitions and 1042 transversions) and 157 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2644 SNP genotypes (1602 transitions and 1042 transversions) and 157 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2801 unique variants in 2801 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2801 unique variants in 2801 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput>
# NOTICE: Finished reading 4220 lines from VCF file
# NOTICE: A total of 4213 locus in VCF file passed QC threshold, representing 3976 SNPs (2382 transitions and 1594 transversions) and 237 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3976 SNP genotypes (2382 transitions and 1594 transversions) and 237 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 4213 unique variants in 4213 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 4213 unique variants in 4213 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB_v1.vcf.gz > /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput>
# NOTICE: Finished reading 7171 lines from VCF file
# NOTICE: A total of 7164 locus in VCF file passed QC threshold, representing 6769 SNPs (3901 transitions and 2868 transversions) and 395 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 6769 SNP genotypes (3901 transitions and 2868 transversions) and 395 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 7164 unique variants in 7164 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 24 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 7164 unique variants in 7164 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 0
# DoneCE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe

# %%
WORK_DIR = f'~/workspace/ws_files/CTSB/'

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/CTSB_SAS/SAS_CTSB.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       8  11792575  11792575   T   C   intergenic   NEIL2,FDFT1
# 1       8  11792593  11792593   T   G   intergenic   NEIL2,FDFT1
# 2       8  11792765  11792765   T   A   intergenic   NEIL2,FDFT1
# 3       8  11792784  11792784   G   A   intergenic   NEIL2,FDFT1
# 4       8  11792794  11792794   T   C   intergenic   NEIL2,FDFT1
# ...   ...       ...       ...  ..  ..          ...           ...
# 2796    8  11919376  11919376   A   T   intergenic  CTSB,DEFB136
# 2797    8  11919450  11919450   G   C   intergenic  CTSB,DEFB136
# 2798    8  11919469  11919469   T   C   intergenic  CTSB,DEFB136
# 2799    8  11919475  11919475   T   C   intergenic  CTSB,DEFB136
# 2800    8  11919532  11919532   T   C   intergenic  CTSB,DEFB136
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0       dist=5230;dist=2998                  .                .
# 1       dist=5248;dist=2980                  .                .
# 2       dist=5420;dist=2808                  .                .
# 3       dist=5439;dist=2789                  .                .
# 4       dist=5449;dist=2779                  .                .
# ...                     ...                ...              ...
# 2796  dist=51289;dist=54561                  .                .
# 2797  dist=51363;dist=54487                  .                .
# 2798  dist=51382;dist=54468                  .                .
# 2799  dist=51388;dist=54462                  .                .
# 2800  dist=51445;dist=54405                  .                .
#
#      clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  \
# 0                   .          0          .          .           8
# 1                   .          0          .          .           8
# 2                   .          0          .          .           8
# 3                   .        0.5          .          .           8
# 4                   .          0          .          .           8
# ...               ...        ...        ...        ...         ...
# 2796                .          0          .          .           8
# 2797                .          0          .          .           8
# 2798                .          0          .          .           8
# 2799                .          0          .          .           8
# 2800                .          0          .          .           8
#
#       Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9  \
# 0       11792575  chr8:11792575:T:C          T          C          .
# 1       11792593  chr8:11792593:T:G          T          G          .
# 2       11792765  chr8:11792765:T:A          T          A          .
# 3       11792784  chr8:11792784:G:A          G          A          .
# 4       11792794  chr8:11792794:T:C          T          C          .
# ...          ...                ...        ...        ...        ...
# 2796    11919376  chr8:11919376:A:T          A          T          .
# 2797    11919450  chr8:11919450:G:C          G          C          .
# 2798    11919469  chr8:11919469:T:C          T          C          .
# 2799    11919475  chr8:11919475:T:C          T          C          .
# 2800    11919532  chr8:11919532:T:C          T          C          .
#
#      Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0              .          PR          GT         0/0
# 1              .          PR          GT         0/0
# 2              .          PR          GT         0/0
# 3              .          PR          GT         0/1
# 4              .          PR          GT         0/0
# ...          ...         ...         ...         ...
# 2796           .          PR          GT         0/0
# 2797           .          PR          GT         0/0
# 2798           .          PR          GT         0/0
# 2799           .          PR          GT         0/0
# 2800           .          PR          GT         0/0
#
# [2801 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1436
# intergenic    1002
# UTR5           109
# UTR3            97
# upstream        58
# exonic          56
# downstream      43
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV         38
# synonymous SNV            17
# nonframeshift deletion     1
# Name: count, dtype: int64

# %%
#Make lists of variants to keep - all coding, coding nonsynonymous (missense - as they are coded in ANNOVAR), deleterious (CADD_phred > 20)

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')

    # Read in ANNOVAR multianno file
    gene = pd.read_csv(f'{WORK_DIR}/{ancestry}_CTSB.annovar.hg38_multianno.txt', sep = '\t')
    
    #Print number of variants in the different categories
    results = [] 

    utr5 = gene[gene['Func.refGene']== 'UTR5']
    intronic = gene[gene['Func.refGene']== 'intronic']
    exonic = gene[gene['Func.refGene']== 'exonic']
    utr3 = gene[gene['Func.refGene']== 'UTR3']
    coding_nonsynonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] == 'nonsynonymous SNV')]
    coding_synonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] != 'nonsynonymous SNV')]
    lof = exonic[(exonic['ExonicFunc.refGene'] == 'stopgain') | (exonic['ExonicFunc.refGene'] == 'stoploss') | (exonic['ExonicFunc.refGene'] == 'frameshift deletion') | (exonic['ExonicFunc.refGene'] == 'frameshift insertion')]
    nonsynonymous_lof = pd.concat([coding_nonsynonymous, lof])

    print({ancestry})
    print('Total variants: ', len(gene))
    print("Intronic: ", len(intronic))
    print('UTR3: ', len(utr3))
    print('UTR5: ', len(utr5))
    print("Total exonic: ", len(exonic))
    print('  Synonymous: ', len(coding_synonymous))
    print("  Nonsynonymous: ", len(coding_nonsynonymous))
    print("nonsynonymous_lof: ", len(nonsynonymous_lof))
    results.append((gene, intronic, utr3, utr5, exonic, coding_synonymous, coding_nonsynonymous, nonsynonymous_lof))
    print('\n')

    # Save in PLINK format - coding nonsynonymous 
    # These are missense variants - other types of nonsynonymous variants (e.g stopgain/loss, or frameshift variants are coded differently in the ExonicFunc.refGene 
    variants_toKeep = nonsynonymous_lof[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep.to_csv(f'{WORK_DIR}/{ancestry}_CTSB.nonsynonymous_lof.variantstoKeep.txt', sep="\t", index=False, header=False)


    # Save in PLINK format - all coding variants
    variants_toKeep2 = exonic[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep2.to_csv(f'{WORK_DIR}/{ancestry}_CTSB.exonic.variantstoKeep.txt', sep="\t", index=False, header=False)
# Out:
# WORKING ON: FIN
# {'FIN'}
# Total variants:  1057
# Intronic:  556
# UTR3:  37
# UTR5:  43
# Total exonic:  16
#   Synonymous:  7
#   Nonsynonymous:  9
# nonsynonymous_lof:  9
#
#
# WORKING ON: AMR
# {'AMR'}
# Total variants:  5507
# Intronic:  2903
# UTR3:  184
# UTR5:  224
# Total exonic:  90
#   Synonymous:  38
#   Nonsynonymous:  52
# nonsynonymous_lof:  53
#
#
# WORKING ON: MDE
# {'MDE'}
# Total variants:  3639
# Intronic:  1928
# UTR3:  107
# UTR5:  129
# Total exonic:  58
#   Synonymous:  22
#   Nonsynonymous:  36
# nonsynonymous_lof:  36
#
#
# WORKING ON: AAC
# {'AAC'}
# Total variants:  5526
# Intronic:  2972
# UTR3:  182
# UTR5:  197
# Total exonic:  75
#   Synonymous:  36
#   Nonsynonymous:  39
# nonsynonymous_lof:  39
#
#
# WORKING ON: EUR
# {'EUR'}
# Total variants:  10388
# Intronic:  5374
# UTR3:  352
# UTR5:  415
# Total exonic:  211
#   Synonymous:  78
#   Nonsynonymous:  133
# nonsynonymous_lof:  137
#
#
# WORKING ON: CAH
# {'CAH'}
# Total variants:  5508
# Intronic:  2957
# UTR3:  177
# UTR5:  203
# Total exonic:  83
#   Synonymous:  39
#   Nonsynonymous:  44
# nonsynonymous_lof:  45
#
#
# WORKING ON: CAS
# {'CAS'}
# Total variants:  3249
# Intronic:  1722
# UTR3:  115
# UTR5:  141
# Total exonic:  61
#   Synonymous:  23
#   Nonsynonymous:  38
# nonsynonymous_lof:  38
#
#
# WORKING ON: AJ
# {'AJ'}
# Total variants:  2256
# Intronic:  1191
# UTR3:  68
# UTR5:  96
# Total exonic:  33
#   Synonymous:  10
#   Nonsynonymous:  23
# nonsynonymous_lof:  23
#
#
# WORKING ON: SAS
# {'SAS'}
# Total variants:  2801
# Intronic:  1436
# UTR3:  97
# UTR5:  109
# Total exonic:  56
#   Synonymous:  18
#   Nonsynonymous:  38
# nonsynonymous_lof:  38
#
#
# WORKING ON: EAS
# {'EAS'}
# Total variants:  4213
# Intronic:  2219
# UTR3:  150
# UTR5:  178
# Total exonic:  89
#   Synonymous:  33
#   Nonsynonymous:  56
# nonsynonymous_lof:  58
#
#
# WORKING ON: AFR
# {'AFR'}
# Total variants:  7164
# Intronic:  3823
# UTR3:  233
# UTR5:  276
# Total exonic:  113
#   Synonymous:  51
#   Nonsynonymous:  62
# nonsynonymous_lof:  63

# %% [markdown]
# ALL variants
#
# assoc
#
# glm
#
# ASSOC

# %%
#Run case-control analysis using plink assoc for all variants, not adjusting for any covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    ! /home/jupyter/tools/plink \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
    --assoc \
    --allow-no-sex \
    --ci 0.95 \
    --maf 0.01 \
    --out {WORK_DIR}/{ancestry}_CTSB.all
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 5526 variants loaded from .bim file.
# 1215 people (532 males, 683 females) loaded from .fam.
# 1133 phenotype values loaded from .fam.
# --keep: 1207 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1207 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.997149.
# 4315 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1211 variants and 1207 people pass filters and QC.
# Among remaining phenotypes, 369 are cases and 756 are controls.  (82 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 7164 variants loaded from .bim file.
# 3780 people (2087 males, 1693 females) loaded from .fam.
# 3498 phenotype values loaded from .fam.
# --keep: 3581 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3581 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.995253.
# 5946 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1218 variants and 3581 people pass filters and QC.
# Among remaining phenotypes, 1147 are cases and 2169 are controls.  (265
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 2256 variants loaded from .bim file.
# 3472 people (2146 males, 1326 females) loaded from .fam.
# 1966 phenotype values loaded from .fam.
# --keep: 2716 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2716 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.994882.
# 1514 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 742 variants and 2716 people pass filters and QC.
# Among remaining phenotypes, 1285 are cases and 408 are controls.  (1023
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 5507 variants loaded from .bim file.
# 3608 people (1735 males, 1873 females) loaded from .fam.
# 3434 phenotype values loaded from .fam.
# --keep: 3471 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3471 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.990937.
# 4827 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 680 variants and 3471 people pass filters and QC.
# Among remaining phenotypes, 1917 are cases and 1402 are controls.  (152
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3249 variants loaded from .bim file.
# 1691 people (737 males, 954 females) loaded from .fam.
# 1408 phenotype values loaded from .fam.
# --keep: 1518 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1518 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.989357.
# 2564 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 685 variants and 1518 people pass filters and QC.
# Among remaining phenotypes, 734 are cases and 578 are controls.  (206
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 4213 variants loaded from .bim file.
# 6662 people (4001 males, 2661 females) loaded from .fam.
# 5116 phenotype values loaded from .fam.
# --keep: 6414 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 6414 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.983892.
# 3736 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 477 variants and 6414 people pass filters and QC.
# Among remaining phenotypes, 2377 are cases and 2598 are controls.  (1439
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 10388 variants loaded from .bim file.
# 58823 people (33074 males, 25749 females) loaded from .fam.
# 37150 phenotype values loaded from .fam.
# --keep: 53641 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 53641 founders and 0 nonfounders present.
# Calculating allele frequenc done.
# Total genotyping rate in remaining samples is 0.738162.
# 9703 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 685 variants and 53641 people pass filters and QC.
# Among remaining phenotypes, 24208 are cases and 9662 are controls.  (19771
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 1057 variants loaded from .bim file.
# 144 people (62 males, 82 females) loaded from .fam.
# 118 phenotype values loaded from .fam.
# --keep: 111 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 111 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.980397.
# 375 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 682 variants and 111 people pass filters and QC.
# Among remaining phenotypes, 80 are cases and 11 are controls.  (20 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 3639 variants loaded from .bim file.
# 1493 people (815 males, 678 females) loaded from .fam.
# 1311 phenotype values loaded from .fam.
# --keep: 1448 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1448 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.993178.
# 2949 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 690 variants and 1448 people pass filters and QC.
# Among remaining phenotypes, 724 are cases and 551 are controls.  (173
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 2801 variants loaded from .bim file.
# 945 people (606 males, 339 females) loaded from .fam.
# 586 phenotype values loaded from .fam.
# --keep: 870 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 870 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.992861.
# 2093 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 708 variants and 870 people pass filters and QC.
# Among remaining phenotypes, 309 are cases and 261 are controls.  (300
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all
#
# 26046 MB RAM detected; reserving 13023 MB for main workspace.
# 5508 variants loaded from .bim file.
# 1111 people (589 males, 522 females) loaded from .fam.
# 1040 phenotype values loaded from .fam.
# --keep: 1039 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1039 founders and 0 nonfounders present.
# Calculating allele frequencies... done.
# Total genotyping rate in remaining samples is 0.995908.
# 4534 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 974 variants and 1039 people pass filters and QC.
# Among remaining phenotypes, 663 are cases and 318 are controls.  (58 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all.assoc ...
# done.

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Look at assoc results, only variants with nominal p-value < 0.05
    freq = pd.read_csv(f'{WORK_DIR}/{ancestry}_CTSB.all.assoc', sep='\s+')
    sig_all_nonadj = freq[freq['P']<0.05]
    
    print(f'Variants with p-value < 0.05: {sig_all_nonadj.shape}')
    
    #Save FREQ to csv
    freq.to_csv(f'{WORK_DIR}/{ancestry}.all_nonadj.csv')
# Out:
# WORKING ON: AAC
# Variants with p-value < 0.05: (112, 13)
# WORKING ON: AFR
# Variants with p-value < 0.05: (81, 13)
# WORKING ON: AJ
# Variants with p-value < 0.05: (23, 13)
# WORKING ON: AMR
# Variants with p-value < 0.05: (433, 13)
# WORKING ON: CAS
# Variants with p-value < 0.05: (86, 13)
# WORKING ON: EAS
# Variants with p-value < 0.05: (129, 13)
# WORKING ON: EUR
# Variants with p-value < 0.05: (272, 13)
# WORKING ON: FIN
# Variants with p-value < 0.05: (6, 13)
# WORKING ON: MDE
# Variants with p-value < 0.05: (46, 13)
# WORKING ON: SAS
# Variants with p-value < 0.05: (7, 13)
# WORKING ON: CAH
# Variants with p-value < 0.05: (31, 13)

# %%
#Run case-control analysis with covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
    --allow-no-sex \
    --maf 0.01 \
    --ci 0.95 \
    --glm \
    --covar /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.noNA.txt \
    --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
    --covar-variance-standardize \
    --neg9-pheno-really-missing \
    --out {WORK_DIR}/{ancestry}_CTSB.all_adj
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:18 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24620 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam.
# 5526 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --keep: 1207 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.noNA.txt.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 4315 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1211 variants remaining after main filters.
# done. logistic-Firth hybrid regression on phenotype 'PHENO1': 0%
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:18 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:19 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24612 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam.
# 7164 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --keep: 3581 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.noNA.txt.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# done.lating allele frequencies... 0%
# 5946 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1218 variants remaining after main filters.
# done. logistic-Firth hybrid regression on phenotype 'PHENO1': 0%
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:20 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:21 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24605 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam.
# 2256 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --keep: 2716 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.noNA.txt.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1514 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 742 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:21 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:22 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24616 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam.
# 5507 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.noNA.txt.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 4827 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 680 variants remaining after main filters.
# Error: Cannot proceed with --glm regression on phenotype 'PHENO1', since
# variance inflation factor for covariate 'PC2' is too high (VIF_TOO_HIGH). You
# may want to remove redundant covariates and try again.
# End time: Sat Jul 26 13:03:22 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:24 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24626 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam.
# 3249 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --keep: 1518 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.noNA.txt.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2564 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 685 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:24 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:25 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24604 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam.
# 4213 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --keep: 6414 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.noNA.txt.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 3736 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 477 variants remaining after main filters.
# done. logistic-Firth hybrid regression on phenotype 'PHENO1': 0%
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:25 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:27 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24603 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam.
# 10388 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --keep: 53641 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.noNA.txt.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# done.lating allele frequencies... 0%
# 9703 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 685 variants remaining after main filters.
# done. logistic-Firth hybrid regression on phenotype 'PHENO1': 0%
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:29 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:30 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24617 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam.
# 1057 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --keep: 111 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.noNA.txt.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 375 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 682 variants remaining after main filters.
# Warning: --glm remaining control count is less than 10x predictor count for
# phenotype 'PHENO1'.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:30 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:31 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24614 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam.
# 3639 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --keep: 1448 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.noNA.txt.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2949 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 690 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:31 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:33 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24624 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam.
# 2801 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --keep: 870 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.noNA.txt.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2093 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 708 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:33 2025
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.noNA.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj
#
# Start time: Sat Jul 26 13:03:34 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24610 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam.
# 5508 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --keep: 1039 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.noNA.txt.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 4534 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 974 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:03:34 2025

# %%
WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_AMR'

! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/AMR_CTSB \
--keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep \
--allow-no-sex \
--maf 0.01 \
--ci 0.95 \
--glm \
--covar /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt \
--covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
--covar-variance-standardize \
--neg9-pheno-really-missing \
--out {WORK_DIR}/AMR_CTSB.all_adj
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj
#
# Start time: Sat Jul 26 13:04:36 2025
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 26046 MiB RAM detected, ~24638 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam.
# 5507 variants loaded from
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --keep: 3471 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/AMR/AMR_covariate_file_noGBA.orthoPCs.txt.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 4827 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 680 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Sat Jul 26 13:04:37 2025

# %%
#Process results from plink glm analysis including covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Read in plink glm results
    assoc = pd.read_csv(f'{WORK_DIR}/{ancestry}_CTSB.all_adj.PHENO1.glm.logistic.hybrid', delim_whitespace=True)

    #Filter for additive test only - this is the variant results
    assoc_add = assoc[assoc['TEST']=="ADD"]
    
    #Check if there are any significant (p < 0.05) variants
    significant = assoc_add[assoc_add['P']<0.05]

    print(f'There are {len(significant)} variants with p-value < 0.05 in glm')
    
    #Check if there are any significant (p < 0.05) variants
    GWsignificant = assoc_add[assoc_add['P']<5e-8]

    print(f'There are {len(GWsignificant)} variants with p-value < 5e-8 in glm')
    
    #Save assoc_add to csv
    assoc_add.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
# Out:
# WORKING ON: AAC
# There are 51 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AFR
# There are 94 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AJ
# There are 34 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: AMR
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 96 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: CAS
# There are 19 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EAS
# There are 12 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: EUR
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 198 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: FIN
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 0 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: MDE
# There are 49 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: SAS
# There are 3 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAH
# There are 33 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /tmp/ipykernel_1691/829170199.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# format assoc file to do meta analysis(AFR/AJ/AMR/EAS/EUR)

# %%
# Define ancestry groups and their sample sizes
ancestry_sample_sizes = {
    'AFR': 3316,
    'AJ': 1693,
    'AMR': 3319,
    'EAS': 4975,
    'EUR': 33870
}

# Output container (optional)
cleaned_results = {}

# Loop over each ancestry
for ancestry, sample_size in ancestry_sample_sizes.items():
    # Load PLINK association result file
    file_path = f'/home/jupyter/workspace/ws_files/CTSB/CTSB_{ancestry}/{ancestry}.all_adj.csv'
    df = pd.read_csv(file_path)

    # Build MARKERNAME
    df['MARKERNAME'] = 'chr' + df['#CHROM'].astype(str) + ':' + df['POS'].astype(str)

    # Rename columns
    df.rename(columns={
        '#CHROM': 'CHROMOSOME',
        'POS': 'POSITION',
        'REF': 'NEA',
        'ALT': 'EA',
        'A1_FREQ': 'EAF',
        'LOG(OR)_SE': 'SE',
        'L95': 'OR_95L',
        'U95': 'OR_95U'
    }, inplace=True)

    # Add BETA = log(OR)
    df['BETA'] = np.log(df['OR'])

    # Add sample size
    df['N'] = sample_size

    # Keep desired columns
    final_cols = [
        'MARKERNAME', 'CHROMOSOME', 'POSITION', 'NEA', 'EA', 'EAF',
        'BETA', 'OR', 'SE', 'OR_95L', 'OR_95U', 'P', 'N'
    ]
    df_cleaned = df[final_cols]

    # Store or save
    cleaned_results[ancestry] = df_cleaned

    # Optional: save to file
    output_path = f'/home/jupyter/workspace/ws_files/CTSB/CTSB_{ancestry}/{ancestry}.cleaned_assoc.txt.gz'
    df_cleaned.to_csv(output_path, sep='\t', index=False)

# %%
df = pd.read_csv('/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.cleaned_assoc.txt.gz', sep='\t')
df
# Out:
#         MARKERNAME  CHROMOSOME  POSITION NEA EA       EAF      BETA        OR  \
# 0    chr8:11792575           8  11792575   T  C  0.019353  0.071269  1.073870
# 1    chr8:11792812           8  11792812   C  T  0.114708 -0.096086  0.908386
# 2    chr8:11792966           8  11792966   T  C  0.398739 -0.033624  0.966935
# 3    chr8:11793099           8  11793099   T  C  0.154628  0.170721  1.186160
# 4    chr8:11793200           8  11793200   G  C  0.129552  0.097363  1.102260
# ..             ...         ...       ...  .. ..       ...       ...       ...
# 737  chr8:11918618           8  11918618   T  C  0.064459 -0.002321  0.997682
# 738  chr8:11918643           8  11918643   T  G  0.015526 -0.228613  0.795636
# 739  chr8:11919062           8  11919062   A  G  0.019649 -0.845029  0.429545
# 740  chr8:11919200           8  11919200   G  A  0.083690 -0.260764  0.770463
# 741  chr8:11919450           8  11919450   G  C  0.063611 -0.018521  0.981649
#
#            SE    OR_95L    OR_95U         P     N
# 0    0.370647  0.519347  2.220490  0.847515  1693
# 1    0.159408  0.664633  1.241540  0.546664  1693
# 2    0.107804  0.782771  1.194430  0.755114  1693
# 3    0.154521  0.876222  1.605730  0.269231  1693
# 4    0.159246  0.806741  1.506030  0.540933  1693
# ..        ...       ...       ...       ...   ...
# 737  0.218229  0.650482  1.530200  0.991517  1693
# 738  0.410404  0.355941  1.778490  0.577496  1693
# 739  0.306669  0.235490  0.783512  0.005860  1693
# 740  0.177479  0.544103  1.090990  0.141761  1693
# 741  0.218267  0.639981  1.505730  0.932376  1693
#
# [742 rows x 13 columns]

# %% [markdown]
# Burden Analyses using RVTests

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

#Loop over all the ancestries and the 2 variant classes - run rvtests for all coding and missense variants
for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

        # Print the command to be executed (for debugging purposes)
        print(f'Running plink to extract {variant_class} variants for ancestry: {ancestry}')
        
        #Extract relevant variants
        ! /home/jupyter/tools/plink2 \
        --pfile {REL10_PATH}/imputed_genotypes/{ancestry}/chr8_{ancestry}_release10_vwb \
        --keep /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}.noGBA.samplestoKeep \
        --extract range {WORK_DIR}/{ancestry}_CTSB.{variant_class}.variantstoKeep.txt \
        --recode vcf-iid \
        --out {WORK_DIR}/{ancestry}_CTSB.{variant_class}
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running bgzip and tabix for {variant_class} variants for ancestry: {ancestry}')
        
        ## Bgzip and Tabix (zip and index the file)
        ! bgzip -f {WORK_DIR}/{ancestry}_CTSB.{variant_class}.vcf
        ! tabix -f -p vcf {WORK_DIR}/{ancestry}_CTSB.{variant_class}.vcf.gz
# Out:
# Running plink to extract exonic variants for ancestry: AAC
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb
#
# Start time: Sat Jul 26 13:08:44 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24623 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.psam.
# 3293679 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --extract bed1: 3293604 variants excluded.
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# 75 variants remaining after main filters.
# --export vcf to
# done.
# End time: Sat Jul 26 13:08:45 2025
# Running bgzip and tabix for exonic variants for ancestry: AAC
# Running plink to extract nonsynonymous_lof variants for ancestry: AAC
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AAC/AAC.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb
#
# Start time: Sat Jul 26 13:08:48 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24606 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1215 samples (683 females, 532 males; 1215 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.psam.
# 3293679 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AAC/chr8_AAC_release10_vwb.pvar.
# 1 binary phenotype loaded (370 cases, 763 controls).
# --extract bed1: 3293640 variants excluded.
# --keep: 1207 samples remaining.
# 1207 samples (680 females, 527 males; 1207 founders) remaining after main
# filters.
# 369 cases and 756 controls remaining after main filters.
# 39 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:08:49 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AAC
# Running plink to extract exonic variants for ancestry: AFR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb
#
# Start time: Sat Jul 26 13:08:52 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24605 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.psam.
# 4081203 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --extract bed1: 4081091 variants excluded.
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# 112 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:08:53 2025
# Running bgzip and tabix for exonic variants for ancestry: AFR
# Running plink to extract nonsynonymous_lof variants for ancestry: AFR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AFR/AFR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb
#
# Start time: Sat Jul 26 13:08:56 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24610 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3780 samples (1693 females, 2087 males; 3780 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.psam.
# 4081203 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AFR/chr8_AFR_release10_vwb.pvar.
# 1 binary phenotype loaded (1191 cases, 2307 controls).
# --extract bed1: 4081141 variants excluded.
# --keep: 3581 samples remaining.
# 3581 samples (1596 females, 1985 males; 3581 founders) remaining after main
# filters.
# 1147 cases and 2169 controls remaining after main filters.
# 62 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.nonsynonymous_lof.vcf
# done.
# End time: Sat Jul 26 13:08:57 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AFR
# Running plink to extract exonic variants for ancestry: AJ
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb
#
# Start time: Sat Jul 26 13:09:01 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24618 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.psam.
# 1376363 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --extract bed1: 1376330 variants excluded.
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# 33 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:09:01 2025
# Running bgzip and tabix for exonic variants for ancestry: AJ
# Running plink to extract nonsynonymous_lof variants for ancestry: AJ
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AJ/AJ.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb
#
# Start time: Sat Jul 26 13:09:04 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24624 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3472 samples (1326 females, 2146 males; 3472 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.psam.
# 1376363 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AJ/chr8_AJ_release10_vwb.pvar.
# 1 binary phenotype loaded (1531 cases, 435 controls).
# --extract bed1: 1376340 variants excluded.
# --keep: 2716 samples remaining.
# 2716 samples (975 females, 1741 males; 2716 founders) remaining after main
# filters.
# 1285 cases and 408 controls remaining after main filters.
# 23 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.nonsynonymous_lof.vcf ...
# done.
# End time: Sat Jul 26 13:09:05 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AJ
# Running plink to extract exonic variants for ancestry: AMR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb
#
# Start time: Sat Jul 26 13:09:08 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24626 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.psam.
# 3550811 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --extract bed1: 3550723 variants excluded.
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# 88 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:09:09 2025
# Running bgzip and tabix for exonic variants for ancestry: AMR
# Running plink to extract nonsynonymous_lof variants for ancestry: AMR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/AMR/AMR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb
#
# Start time: Sat Jul 26 13:09:12 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24634 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 3608 samples (1873 females, 1735 males; 3608 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.psam.
# 3550811 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/AMR/chr8_AMR_release10_vwb.pvar.
# 1 binary phenotype loaded (1995 cases, 1439 controls).
# --extract bed1: 3550759 variants excluded.
# --keep: 3471 samples remaining.
# 3471 samples (1801 females, 1670 males; 3471 founders) remaining after main
# filters.
# 1917 cases and 1402 controls remaining after main filters.
# 52 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:09:13 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AMR
# Running plink to extract exonic variants for ancestry: CAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb
#
# Start time: Sat Jul 26 13:09:17 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24643 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.psam.
# 2184117 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --extract bed1: 2184057 variants excluded.
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# 60 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.exonic.vcdone.
# End time: Sat Jul 26 13:09:17 2025
# Running bgzip and tabix for exonic variants for ancestry: CAS
# Running plink to extract nonsynonymous_lof variants for ancestry: CAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAS/CAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb
#
# Start time: Sat Jul 26 13:09:21 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24619 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1691 samples (954 females, 737 males; 1691 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.psam.
# 2184117 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAS/chr8_CAS_release10_vwb.pvar.
# 1 binary phenotype loaded (782 cases, 626 controls).
# --extract bed1: 2184079 variants excluded.
# --keep: 1518 samples remaining.
# 1518 samples (872 females, 646 males; 1518 founders) remaining after main
# filters.
# 734 cases and 578 controls remaining after main filters.
# 38 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:09:21 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAS
# Running plink to extract exonic variants for ancestry: EAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb
#
# Start time: Sat Jul 26 13:09:24 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24619 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.psam.
# 2703578 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --extract bed1: 2703491 variants excluded.
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# 87 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:09:25 2025
# Running bgzip and tabix for exonic variants for ancestry: EAS
# Running plink to extract nonsynonymous_lof variants for ancestry: EAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EAS/EAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb
#
# Start time: Sat Jul 26 13:09:29 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24610 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 6662 samples (2661 females, 4001 males; 6662 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.psam.
# 2703578 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EAS/chr8_EAS_release10_vwb.pvar.
# 1 binary phenotype loaded (2411 cases, 2705 controls).
# --extract bed1: 2703521 variants excluded.
# --keep: 6414 samples remaining.
# 6414 samples (2569 females, 3845 males; 6414 founders) remaining after main
# filters.
# 2377 cases and 2598 controls remaining after main filters.
# 57 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:09:29 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EAS
# Running plink to extract exonic variants for ancestry: EUR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb
#
# Start time: Sat Jul 26 13:09:33 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24609 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.psam.
# 6200464 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --extract bed1: 6200257 variants excluded.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# 207 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.exondone.
# End time: Sat Jul 26 13:09:34 2025
# Running bgzip and tabix for exonic variants for ancestry: EUR
# Running plink to extract nonsynonymous_lof variants for ancestry: EUR
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb
#
# Start time: Sat Jul 26 13:09:38 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24640 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.psam.
# 6200464 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/EUR/chr8_EUR_release10_vwb.pvar.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --extract bed1: 6200327 variants excluded.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# 137 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.nonsynonymous_lof.vcf
# done.
# End time: Sat Jul 26 13:09:39 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EUR
# Running plink to extract exonic variants for ancestry: FIN
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb
#
# Start time: Sat Jul 26 13:09:43 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24638 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.psam.
# 715411 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --extract bed1: 715395 variants excluded.
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# 16 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:09:44 2025
# Running bgzip and tabix for exonic variants for ancestry: FIN
# Running plink to extract nonsynonymous_lof variants for ancestry: FIN
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/FIN/FIN.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb
#
# Start time: Sat Jul 26 13:09:47 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24623 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 144 samples (82 females, 62 males; 144 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.psam.
# 715411 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/FIN/chr8_FIN_release10_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 12 controls).
# --extract bed1: 715402 variants excluded.
# --keep: 111 samples remaining.
# 111 samples (66 females, 45 males; 111 founders) remaining after main filters.
# 80 cases and 11 controls remaining after main filters.
# 9 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:09:47 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: FIN
# Running plink to extract exonic variants for ancestry: MDE
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb
#
# Start time: Sat Jul 26 13:09:51 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24623 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.psam.
# 2403439 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --extract bed1: 2403382 variants excluded.
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# 57 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:09:52 2025
# Running bgzip and tabix for exonic variants for ancestry: MDE
# Running plink to extract nonsynonymous_lof variants for ancestry: MDE
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/MDE/MDE.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb
#
# Start time: Sat Jul 26 13:09:55 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24612 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1493 samples (678 females, 815 males; 1493 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.psam.
# 2403439 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/MDE/chr8_MDE_release10_vwb.pvar.
# 1 binary phenotype loaded (752 cases, 559 controls).
# --extract bed1: 2403403 variants excluded.
# --keep: 1448 samples remaining.
# 1448 samples (659 females, 789 males; 1448 founders) remaining after main
# filters.
# 724 cases and 551 controls remaining after main filters.
# 36 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:09:56 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: MDE
# Running plink to extract exonic variants for ancestry: SAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb
#
# Start time: Sat Jul 26 13:09:59 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24607 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.psam.
# 1753806 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --extract bed1: 1753751 variants excluded.
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# 55 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:10:00 2025
# Running bgzip and tabix for exonic variants for ancestry: SAS
# Running plink to extract nonsynonymous_lof variants for ancestry: SAS
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SAS/SAS.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb
#
# Start time: Sat Jul 26 13:10:03 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24612 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 945 samples (339 females, 606 males; 945 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.psam.
# 1753806 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/SAS/chr8_SAS_release10_vwb.pvar.
# 1 binary phenotype loaded (317 cases, 269 controls).
# --extract bed1: 1753768 variants excluded.
# --keep: 870 samples remaining.
# 870 samples (309 females, 561 males; 870 founders) remaining after main
# filters.
# 309 cases and 261 controls remaining after main filters.
# 38 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:10:04 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: SAS
# Running plink to extract exonic variants for ancestry: CAH
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb
#
# Start time: Sat Jul 26 13:10:08 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24612 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.psam.
# 3231362 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --extract bed1: 3231280 variants excluded.
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# 82 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.exonic.vcf .done.
# End time: Sat Jul 26 13:10:08 2025
# Running bgzip and tabix for exonic variants for ancestry: CAH
# Running plink to extract nonsynonymous_lof variants for ancestry: CAH
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/CAH/CAH.noGBA.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb
#
# Start time: Sat Jul 26 13:10:12 2025
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 26046 MiB RAM detected, ~24617 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 1111 samples (522 females, 589 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.psam.
# 3231362 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release10/imputed_genotypes/CAH/chr8_CAH_release10_vwb.pvar.
# 1 binary phenotype loaded (706 cases, 334 controls).
# --extract bed1: 3231318 variants excluded.
# --keep: 1039 samples remaining.
# 1039 samples (485 females, 554 males; 1039 founders) remaining after main
# filters.
# 663 cases and 318 controls remaining after main filters.
# 44 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.nonsynonymous_lof.vcf
# .done.
# End time: Sat Jul 26 13:10:12 2025
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAH

# %%
#Run RVtests
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

        # Print the command to be executed (for debugging purposes)
        print(f'Running RVtests for {variant_class} variants for ancestry: {ancestry}')
        
        ## RVtests with covariates 
        #Make sure the pheno and covariate file starts with the first 5 columsn: fid, iid, fatid, matid, sex
        #The pheno-name flag only works when the pheno/covar file is structured properly
        ! /home/jupyter/tools/rvtests/executable/rvtest --noweb --hide-covar \
        --out {WORK_DIR}/{ancestry}_CTSB.burden.{variant_class} \
        --kernel skato \
        --inVcf {WORK_DIR}/{ancestry}_CTSB.{variant_class}.vcf.gz \
        --pheno /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt \
        --pheno-name PHENO \
        --gene CTSB \
        --geneFile /home/jupyter/workspace/ws_files/refFlat_HG38.txt \
        --covar /home/jupyter/workspace/ws_files/{ancestry}/{ancestry}_covariate_file_noGBA.txt \
        --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
        --freqUpper 0.01
# --burden cmc,zeggini,mb,fp,cmcWald --kernel skat,skato \

# %% [markdown]
# Look at RVtest results SKAT-O

# %%
# %load_ext rpy2.ipython
# Out:
# /opt/conda/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpZB9niY", R: "/tmp/RtmpWw6ESi"

# %%
WORK_DIR = "~/workspace/ws_files/CTSB"

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/CTSB_EUR/EUR_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	40128	93	81	230895	0	0.57025

# %%
#Check EUR nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_EUR/EUR_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	40128	59	55	145610	1	0.558984

# %%
#Check AAC all_coding variant results
! cat {WORK_DIR}/CTSB_AAC/AAC_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1061	28	26	17177.6	0	0.747416

# %%
#Check AAC nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_AAC/AAC_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1061	15	15	21269.3	0	0.27747

# %%
#Check AFR all_coding variant results
! cat {WORK_DIR}/CTSB_AFR/AFR_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	2738	46	29	15284.2	0	0.83222

# %%
#Check AFR nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_AFR/AFR_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	2738	25	18	44255	0.3	0.145056

# %%
# First, define your p-values in Python
pvalues = [0.83222, 0.145056]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.832220 0.290112

# %%
#Check AJ all_coding variant results
! cat {WORK_DIR}/CTSB_AJ/AJ_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	2174	13	11	4309.19	1	0.728951

# %%
#Check AJ nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_AJ/AJ_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	2174	11	9	1176.1	1	0.881028

# %%
# First, define your p-values in Python
pvalues = [0.728951, 0.881028]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.881028 0.881028

# %%
#Check AMR all_coding variant results
! cat {WORK_DIR}/CTSB_AMR/AMR_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	3265	39	26	17400.8	0	0.745868

# %%
#Check AMR nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_AMR/AMR_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	3265	27	19	17122.4	0	0.471545

# %%
# First, define your p-values in Python
pvalues = [0.745868, 0.471545]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.745868 0.745868

# %%
#Check CAS all_coding variant results
! cat {WORK_DIR}/CTSB_CAS/CAS_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1104	18	11	814.855	1	0.857092

# %%
#Check CAS nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_CAS/CAS_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1104	12	9	1996.05	1	0.756806

# %%
# First, define your p-values in Python
pvalues = [0.857092, 0.756806]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.857092 0.857092

# %%
#Check EAS all_coding variant results
! cat {WORK_DIR}/CTSB_EAS/EAS_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	4670	24	14	704.747	1	1

# %%
#Check EAS nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_EAS/EAS_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	4670	17	10	11348.2	1	0.539251

# %%
# First, define your p-values in Python
pvalues = [1, 0.539251]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 1 1

# %%
#Check FIN all_coding variant results
! cat {WORK_DIR}/CTSB_FIN/FIN_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	45	3	0	NA	NA	NA

# %%
#Check FIN nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_FIN/FIN_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	45	2	0	NA	NA	NA

# %%
#Check MDE all_coding variant results
! cat {WORK_DIR}/CTSB_MDE/MDE_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1230	24	14	11656.6	1	0.400443

# %%
#Check MDE nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_MDE/MDE_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	1230	15	7	2204.48	1	0.565363

# %%
# First, define your p-values in Python
pvalues = [0.400443, 0.565363]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.565363 0.565363

# %%
#Check SAS all_coding variant results
! cat {WORK_DIR}/CTSB_SAS/SAS_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	689	19	8	2239.37	1	0.419244

# %%
#Check SAS nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_SAS/SAS_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	689	12	5	774.291	0	0.639828

# %%
# First, define your p-values in Python
pvalues = [0.419244, 0.639828]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.639828 0.639828

# %%
#Check CAH all_coding variant results
! cat {WORK_DIR}/CTSB_CAH/CAH_CTSB.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	900	28	21	18155.3	0	0.730282

# %%
#Check CAH nonsynonymous_lof variant results
! cat {WORK_DIR}/CTSB_CAH/CAH_CTSB.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# CTSB	8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868150,8:11842524-11868087,8:11842524-11868150,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479971-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568,8_KZ208915v1_fix:1479908-1505568	900	14	12	3469.22	1	0.817762

# %%
# First, define your p-values in Python
pvalues = [0.730282, 0.817762]
# Send to R
import rpy2.robjects as ro
ro.globalenv['pvalues'] = ro.FloatVector(pvalues)

# %%
# %%R
# # Adjust using BH method
# fdrs <- p.adjust(pvalues, method = "BH")
# print(fdrs)
# Out:
# [1] 0.817762 0.817762

# %% [markdown]
# LD pruning(in EUR)

# %%
WORK_DIR = "~/workspace/ws_files/"

# %%
# Make sure to use high-quality SNPs
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/CTSB/CTSB_EUR/EUR_CTSB \
--maf 0.01 \
--geno 0.05 \
--hwe 1e-5 0.001 \
--make-bed \
--keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep \
--exclude {WORK_DIR}/exclusion_regions_hg38.txt \
--out {WORK_DIR}/CTSB/CTSB_UNIMPUTED
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//CTSB/CTSB_EUR/EUR_CTSB
#   --exclude /home/jupyter/workspace/ws_files//exclusion_regions_hg38.txt
#   --geno 0.05
#   --hwe 1e-5 0.001
#   --keep /home/jupyter/workspace/ws_files/EUR/EUR.noGBA.samplestoKeep
#   --maf 0.01
#   --make-bed
#   --out /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED
#
# Start time: Sat Jul 26 13:26:22 2025
# 26046 MiB RAM detected, ~24630 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 58823 samples (25749 females, 33074 males; 58823 founders) loaded from
# /home/jupyter/workspace/ws_files//CTSB/CTSB_EUR/EUR_CTSB.fam.
# 10388 variants loaded from
# /home/jupyter/workspace/ws_files//CTSB/CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (26778 cases, 10372 controls).
# --exclude: 10388 variants remaining.
# --keep: 53641 samples remaining.
# 53641 samples (23385 females, 30256 males; 53641 founders) remaining after main
# filters.
# 24208 cases and 9662 controls remaining after main filters.
# done.lating allele frequencies... 0%
# --geno: 5516 variants removed due to missing genotype data.
# --hwe: 0 variants removed due to Hardy-Weinberg exact test (founders only).
# 4273 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 599 variants remaining after main filters.
# done.ng /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.fam ...
# done.ng /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.bim ...
# done.ng /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.bed ... 0%
# End time: Sat Jul 26 13:26:23 2025

# %%
# Prune out unnecessary SNPs (only need to do this to generate PCs)
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/CTSB/CTSB_UNIMPUTED \
--indep-pairwise 50 5 0.5 \
--out {WORK_DIR}/CTSB/prune_CTSB
# Out:
# PLINK v2.0.0-a.7LM 64-bit Intel (7 Jul 2025)       cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//CTSB/prune_CTSB.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED
#   --indep-pairwise 50 5 0.5
#   --out /home/jupyter/workspace/ws_files//CTSB/prune_CTSB
#
# Start time: Sat Jul 26 13:26:47 2025
# 26046 MiB RAM detected, ~24571 available; reserving 13023 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53641 samples (23385 females, 30256 males; 53641 founders) loaded from
# /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.fam.
# 599 variants loaded from
# /home/jupyter/workspace/ws_files//CTSB/CTSB_UNIMPUTED.bim.
# 1 binary phenotype loaded (24208 cases, 9662 controls).
# Calculating allele frequencies... done.
# 483/599 variants removed.ead): 0%
# Variant lists written to
# /home/jupyter/workspace/ws_files//CTSB/prune_CTSB.prune.in and
# /home/jupyter/workspace/ws_files//CTSB/prune_CTSB.prune.out .
# End time: Sat Jul 26 13:26:47 2025

# %%
# !wc -l {WORK_DIR}/CTSB/prune_CTSB.prune.in
# Out:
# 116 /home/jupyter/workspace/ws_files//CTSB/prune_CTSB.prune.in

# %%
# 4.31E-4

# %% [markdown]
# zoom locus plot

# %%
## locus zoom format
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

    df = pd.read_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
    df['b'] = np.log(df['OR'])
    export_ldassoc = df[['#CHROM', 'POS', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P']].copy()
    export_ldassoc = export_ldassoc.rename(columns = {'#CHROM': 'CHROM', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p'})
    # save to files
    export_ldassoc.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.formatted.tab', sep = '\t', index=False)

# %% [markdown]
# GCTA cojo analysis

# %%
## cojo format
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'

    sumstats = pd.read_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
    #Format summary statistics for GCTA-COJO
    #First get the log odds ratio - this is required for COJO
    #1) For a case-control study, the effect size should be log(odds ratio) with its corresponding standard error.
    sumstats_formatted = sumstats.copy()
    sumstats_formatted['b'] = np.log(sumstats_formatted['OR'])

    #Now select just the necessary columns for COJO
    sumstats_export = sumstats_formatted[['ID', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P', 'OBS_CT']].copy()

    #Rename columns following COJO format
    sumstats_export = sumstats_export.rename(columns = {'ID':'SNP', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p', 'OBS_CT':'N'})

    #Export
    sumstats_export.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.sumstats.ma', sep = '\t', index=False)

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/CTSB/CTSB_{ancestry}'
    
    #Select multiple associated SNPs based on LD pruning p-value 4.67e-4
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.95.0-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_CTSB \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 4.31e-4 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.ldprune.COJO
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:35 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam].
# 144 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim].
# 1057 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bed] in SNP-major format ...
# Genotype data for 144 individuals and 1057 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 714 SNPs (343 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.all_adj.sumstats.ma] ...
# GWAS summary statistics of 682 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_FIN/FIN.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 682 SNPs: 20.8706 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 682 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 682 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:35 UTC on Sat Jul 26 2025
# Overall computational time: 0.18 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:36 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam].
# 3608 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim].
# 5507 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bed] in SNP-major format ...
# Genotype data for 3608 individuals and 5507 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 680 SNPs (4827 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 680 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 680 SNPs: 5.63884 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 680 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 680 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 679 remaining SNPs to [/home/jupyter/workspace/ws_files/CTSB/CTSB_AMR/AMR.all_adj.ldprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 13:29:37 UTC on Sat Jul 26 2025
# Overall computational time: 0.86 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:38 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam].
# 1493 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim].
# 3639 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bed] in SNP-major format ...
# Genotype data for 1493 individuals and 3639 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 687 SNPs (2952 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.all_adj.sumstats.ma] ...
# GWAS summary statistics of 690 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_MDE/MDE.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 690 SNPs: 5.08782 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 686 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 686 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:38 UTC on Sat Jul 26 2025
# Overall computational time: 0.31 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:39 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam].
# 1215 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim].
# 5526 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bed] in SNP-major format ...
# Genotype data for 1215 individuals and 5526 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1212 SNPs (4314 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1211 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AAC/AAC.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1211 SNPs: 6.13224 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1211 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1211 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:40 UTC on Sat Jul 26 2025
# Overall computational time: 0.33 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:41 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam].
# 58823 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim].
# 10388 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bed] in SNP-major format ...
# Genotype data for 58823 individuals and 10388 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 685 SNPs (9703 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 685 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 685 SNPs: 6.03122 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 685 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 685 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.ldprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.ldprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 684 remaining SNPs to [/home/jupyter/workspace/ws_files/CTSB/CTSB_EUR/EUR.all_adj.ldprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 13:29:51 UTC on Sat Jul 26 2025
# Overall computational time: 9.95 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:52 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam].
# 1111 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim].
# 5508 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bed] in SNP-major format ...
# Genotype data for 1111 individuals and 5508 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 964 SNPs (4544 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.all_adj.sumstats.ma] ...
# GWAS summary statistics of 974 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAH/CAH.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 974 SNPs: 5.5938 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 956 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 956 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:52 UTC on Sat Jul 26 2025
# Overall computational time: 0.37 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:53 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam].
# 1691 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim].
# 3249 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bed] in SNP-major format ...
# Genotype data for 1691 individuals and 3249 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 686 SNPs (2563 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 685 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_CAS/CAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 685 SNPs: 4.43461 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 684 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 684 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:54 UTC on Sat Jul 26 2025
# Overall computational time: 0.32 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:55 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam].
# 3472 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim].
# 2256 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bed] in SNP-major format ...
# Genotype data for 3472 individuals and 2256 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 743 SNPs (1513 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.all_adj.sumstats.ma] ...
# GWAS summary statistics of 742 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AJ/AJ.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 742 SNPs: 7.9694 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 740 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 740 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:55 UTC on Sat Jul 26 2025
# Overall computational time: 0.32 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:56 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam].
# 945 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim].
# 2801 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bed] in SNP-major format ...
# Genotype data for 945 individuals and 2801 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 709 SNPs (2092 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 708 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_SAS/SAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 708 SNPs: 5.6986 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 707 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 707 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:57 UTC on Sat Jul 26 2025
# Overall computational time: 0.27 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:29:58 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam].
# 6662 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim].
# 4213 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bed] in SNP-major format ...
# Genotype data for 6662 individuals and 4213 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 477 SNPs (3736 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 477 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_EAS/EAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 477 SNPs: 5.30119 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 477 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 477 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:29:59 UTC on Sat Jul 26 2025
# Overall computational time: 0.67 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.95.0 Linux
# * Built at Jul 21 2025 17:30:18, by GCC 8.4
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 13:30:00 UTC on Sat Jul 26 2025.
# Hostname: 4b8bf4fabeb0
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.all_adj.sumstats.ma
# --cojo-p 0.000431
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.all_adj.ldprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam].
# 3780 individuals to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim].
# 7164 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bed] in SNP-major format ...
# Genotype data for 3780 individuals and 7164 SNPs to be included from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR_CTSB.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1216 SNPs (5948 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1218 SNPs read from [/home/jupyter/workspace/ws_files/CTSB/CTSB_AFR/AFR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1218 SNPs: 4.96202 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1212 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1212 SNPs to select association signals ... (p cutoff = 0.000431; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 13:30:00 UTC on Sat Jul 26 2025
# Overall computational time: 0.68 sec.
