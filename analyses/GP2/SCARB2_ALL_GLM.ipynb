# %% [markdown]
# SCARB2 - Single gene analysis in GP2 Neurobooster genotyping data (all ancestries)

# %% [markdown]
# Project: GP2 SCARB2
#
# Version: Python/3.10.15, R/4.3.3

# %% [markdown]
# Notebook Overview
#
# 1. Description
# Loading Python libraries
# Set paths
# Make working directory
#
# 2. Installing packages
#
# 3. LD pruning(TMEM175/SCARB2/CTSB)
#
# 4. Create a covariate file with GP2 data
#
# 5. Annotation of the gene SCARB2
#
# 6. Association analysis to compare allele frequencies between cases and controls
#
# 7. GLM analysis adjusting for gender, age, PC1-5
#
# 8. Burden test(SkatO, Skat, cmc,zeggini,mb,fp,cmcWald)
#
# 9. Conditional analysis

# %% [markdown]
# Loading Python libraries

# %%
# Use pathlib for file path manipulation
import pathlib

# Install numpy
import numpy as np

# Install Pandas for tabular data
import pandas as pd

# Install plotnine: a ggplot2-compatible Python plotting package
from plotnine import *

# Always show all columns in a Pandas DataFrame
pd.set_option('display.max_columns', None)

# %% [markdown]
# Set paths

# %%
REL7_PATH = pathlib.Path(pathlib.Path.home(), 'workspace/gp2_tier2_eu_release7_30042024')
# !ls -hal {REL7_PATH}

# %% [markdown]
# Make working directory

# %%
! mkdir ~/workspace/ws_files/SCARB2
# Out:
# mkdir: cannot create directory ‘/home/jupyter/workspace/ws_files/SCARB2’: File exists

# %%
WORK_DIR = "~/workspace/ws_files/SCARB2/"

# %%
# make sure all tools installed
! ls /home/jupyter/tools
# Out:
# LICENSE				   plink			    prettify
# annovar				   plink2			    rvtests
# annovar.latest.tar.gz		   plink2_linux_x86_64_latest.zip   toy.map
# gcta-1.94.1-linux-kernel-3-x86_64  plink_linux_x86_64_20190304.zip  toy.ped

# %%
# give permission

# chmod to make sure you have permission to run the program
! chmod u+x /home/jupyter/tools/plink
! chmod u+x /home/jupyter/tools/plink2
! chmod 777 /home/jupyter/tools/rvtests/executable/rvtest

# %%
# %%bash
# # making working directory
# #Loop over all the ancestries
# for ancestry in {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'} ;
# do
#
# #Make a folder for each ancestry
# mkdir ~/workspace/ws_files/SCARB2/SCARB2_"$ancestry"
#
# done

# %% [markdown]
# LD pruning(in EUR)

# %%
WORK_DIR = "~/workspace/ws_files/"

# %%
# Make sure to use high-quality SNPs
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/TMEM175/TMEM175_EUR/EUR_TMEM175 \
--maf 0.01 \
--geno 0.05 \
--hwe 1E-6 \
--make-bed \
--exclude {WORK_DIR}/exclusion_regions_hg38.txt \
--out TMEM175_UNIMPUTED
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TMEM175_UNIMPUTED.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175
#   --exclude /home/jupyter/workspace/ws_files//exclusion_regions_hg38.txt
#   --geno 0.05
#   --hwe 1E-6
#   --maf 0.01
#   --make-bed
#   --out TMEM175_UNIMPUTED
#
# Start time: Tue Aug 20 12:38:19 2024
# 52223 MiB RAM detected, ~50840 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175.fam.
# 9504 variants loaded from
# /home/jupyter/workspace/ws_files//TMEM175/TMEM175_EUR/EUR_TMEM175.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --exclude: 9504 variants remaining.
# Calculating allele frequencies... done.
# --geno: 4576 variants removed due to missing genotype data.
# --hwe: 0 variants removed due to Hardy-Weinberg exact test (founders only).
# 4562 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 366 variants remaining after main filters.
# Writing TMEM175_UNIMPUTED.fam ... done.
# Writing TMEM175_UNIMPUTED.bim ... done.
# Writing TMEM175_UNIMPUTED.bed ... done.
# End time: Tue Aug 20 12:38:20 2024

# %%
# Prune out unnecessary SNPs (only need to do this to generate PCs)
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/LDpruning/TMEM175_UNIMPUTED \
--indep-pairwise 50 5 0.5 \
--out {WORK_DIR}/LDpruning/prune_TMEM175
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//LDpruning/prune_TMEM175.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//LDpruning/TMEM175_UNIMPUTED
#   --indep-pairwise 50 5 0.5
#   --out /home/jupyter/workspace/ws_files//LDpruning/prune_TMEM175
#
# Start time: Tue Aug 20 12:40:52 2024
# 52223 MiB RAM detected, ~50788 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//LDpruning/TMEM175_UNIMPUTED.fam.
# 366 variants loaded from
# /home/jupyter/workspace/ws_files//LDpruning/TMEM175_UNIMPUTED.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# Calculating allele frequencies... done.
# --indep-pairwise (1 compute thread): 50257/366 variants removed.
# Variant lists written to
# /home/jupyter/workspace/ws_files//LDpruning/prune_TMEM175.prune.in and
# /home/jupyter/workspace/ws_files//LDpruning/prune_TMEM175.prune.out .
# End time: Tue Aug 20 12:40:53 2024

# %%
# !wc -l {WORK_DIR}/LDpruning/prune_TMEM175.prune.in
# Out:
# 109 /home/jupyter/workspace/ws_files//LDpruning/prune_TMEM175.prune.in

# %%
# SCARB2 LD pruning
# Make sure to use high-quality SNPs
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/SCARB2/SCARB2_EUR/EUR_SCARB2 \
--maf 0.01 \
--geno 0.05 \
--hwe 1E-6 \
--make-bed \
--exclude {WORK_DIR}/LDpruning/exclusion_regions_hg38.txt \
--out {WORK_DIR}/LDpruning/SCARB2_UNIMPUTED
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//SCARB2/SCARB2_EUR/EUR_SCARB2
#   --exclude /home/jupyter/workspace/ws_files//LDpruning/exclusion_regions_hg38.txt
#   --geno 0.05
#   --hwe 1E-6
#   --maf 0.01
#   --make-bed
#   --out /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED
#
# Start time: Tue Aug 20 13:59:30 2024
# 52223 MiB RAM detected, ~50600 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//SCARB2/SCARB2_EUR/EUR_SCARB2.fam.
# 9570 variants loaded from
# /home/jupyter/workspace/ws_files//SCARB2/SCARB2_EUR/EUR_SCARB2.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --exclude: 9570 variants remaining.
# Calculating allele frequencies... done.
# --geno: 4070 variants removed due to missing genotype data.
# --hwe: 1 variant removed due to Hardy-Weinberg exact test (founders only).
# 4580 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 919 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.bed ...
# done.
# End time: Tue Aug 20 13:59:31 2024

# %%
# Prune out unnecessary SNPs (only need to do this to generate PCs)
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/LDpruning/SCARB2_UNIMPUTED \
--indep-pairwise 50 5 0.5 \
--out {WORK_DIR}/LDpruning/prune_SCARB2
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//LDpruning/prune_SCARB2.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED
#   --indep-pairwise 50 5 0.5
#   --out /home/jupyter/workspace/ws_files//LDpruning/prune_SCARB2
#
# Start time: Tue Aug 20 13:59:36 2024
# 52223 MiB RAM detected, ~50591 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.fam.
# 919 variants loaded from
# /home/jupyter/workspace/ws_files//LDpruning/SCARB2_UNIMPUTED.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# Calculating allele frequencies... done.
# --indep-pairwise (1 compute thread): 50776/919 variants removed.
# Variant lists written to
# /home/jupyter/workspace/ws_files//LDpruning/prune_SCARB2.prune.in and
# /home/jupyter/workspace/ws_files//LDpruning/prune_SCARB2.prune.out .
# End time: Tue Aug 20 13:59:36 2024

# %%
# !wc -l {WORK_DIR}/LDpruning/prune_SCARB2.prune.in
# Out:
# 143 /home/jupyter/workspace/ws_files//LDpruning/prune_SCARB2.prune.in

# %%
# CTSB LD pruning
# Make sure to use high-quality SNPs
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/CTSB_EUR/EUR_CTSB \
--maf 0.01 \
--geno 0.05 \
--hwe 1E-6 \
--make-bed \
--exclude {WORK_DIR}/LDpruning/exclusion_regions_hg38.txt \
--out {WORK_DIR}/LDpruning/CTSB_UNIMPUTED
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//CTSB_EUR/EUR_CTSB
#   --exclude /home/jupyter/workspace/ws_files//LDpruning/exclusion_regions_hg38.txt
#   --geno 0.05
#   --hwe 1E-6
#   --maf 0.01
#   --make-bed
#   --out /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED
#
# Start time: Tue Aug 20 14:02:15 2024
# 52223 MiB RAM detected, ~50614 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//CTSB_EUR/EUR_CTSB.fam.
# 13481 variants loaded from
# /home/jupyter/workspace/ws_files//CTSB_EUR/EUR_CTSB.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --exclude: 13481 variants remaining.
# Calculating allele frequencies... done.
# --geno: 6697 variants removed due to missing genotype data.
# --hwe: 0 variants removed due to Hardy-Weinberg exact test (founders only).
# 6190 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 594 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.bed ...
# done.
# End time: Tue Aug 20 14:02:17 2024

# %%
# Prune out unnecessary SNPs (only need to do this to generate PCs)
! /home/jupyter/tools/plink2 \
--bfile {WORK_DIR}/LDpruning/CTSB_UNIMPUTED \
--indep-pairwise 50 5 0.5 \
--out {WORK_DIR}/LDpruning/prune_CTSB
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files//LDpruning/prune_CTSB.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED
#   --indep-pairwise 50 5 0.5
#   --out /home/jupyter/workspace/ws_files//LDpruning/prune_CTSB
#
# Start time: Tue Aug 20 14:02:51 2024
# 52223 MiB RAM detected, ~50604 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.fam.
# 594 variants loaded from
# /home/jupyter/workspace/ws_files//LDpruning/CTSB_UNIMPUTED.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# Calculating allele frequencies... done.
# --indep-pairwise (1 compute thread): 50477/594 variants removed.
# Variant lists written to
# /home/jupyter/workspace/ws_files//LDpruning/prune_CTSB.prune.in and
# /home/jupyter/workspace/ws_files//LDpruning/prune_CTSB.prune.out .
# End time: Tue Aug 20 14:02:52 2024

# %%
# !wc -l {WORK_DIR}/LDpruning/prune_CTSB.prune.in
# Out:
# 117 /home/jupyter/workspace/ws_files//LDpruning/prune_CTSB.prune.in

# %% [markdown]
# Create a covariate file with GP2 data

# %%
CLINICAL_DATA_PATH = pathlib.Path(REL7_PATH, 'clinical_data/master_key_release7_final_vwb.csv')

# %%
# Let's load the master key
key = pd.read_csv(CLINICAL_DATA_PATH, low_memory=False)
print(key.shape)
key.head()

# %%
# Subsetting to keep only a few columns 
key = key[['GP2sampleID', 'baseline_GP2_phenotype_for_qc', 'biological_sex_for_qc', 'age_at_sample_collection', 'age_of_onset', 'label']]
# Renaming the columns
key.rename(columns = {'GP2sampleID':'IID',
                                     'baseline_GP2_phenotype_for_qc':'phenotype',
                                     'biological_sex_for_qc':'SEX', 
                                     'age_at_sample_collection':'AGE', 
                                     'age_of_onset':'AAO'}, inplace = True)
key

# %%
! pwd
# Out:
# /home/jupyter/workspace/ws_files

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    ## Subset to keep ancestry of interest 
    ancestry_key = key[key['label']==ancestry].copy()
    ancestry_key.reset_index(drop=True)
    
    # Load information about related individuals in the ancestry analyzed
    related_df = pd.read_csv(f'{REL7_PATH}/meta_data/related_samples/{ancestry}_release7_vwb.related')
    print(f'Related individuals: {related_df.shape}')
    
    # Make a list of just one set of related people
    related_list = list(related_df['IID1'])
    
    # Check value counts of related and remove only one related individual
    ancestry_key = ancestry_key[~ancestry_key["IID"].isin(related_list)]
    
    # Check size
    print(f'Unrelated individuals: {ancestry_key.shape}')
    
    # Convert phenotype to binary (1/2)
    ## Assign conditions so case=2 and controls=1, and -9 otherwise (matching PLINK convention)
    # PD = 2; control = 1
    pheno_mapping = {"PD": 2, "Control": 1}
    ancestry_key['PHENO'] = ancestry_key['phenotype'].map(pheno_mapping).astype('Int64')
    
    # Check value counts of pheno
    ancestry_key['PHENO'].value_counts(dropna=False)
    
    ## Get the PCs
    pcs = pd.read_csv(f'{REL7_PATH}/meta_data/qc_metrics/projected_pcs_vwb.csv')
    
     #Select just first 5 PCs
    selected_columns = ['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5']
    pcs = pd.DataFrame(data=pcs.iloc[:, 1:7].values, columns=selected_columns)
    
     # Drop the first row (since it's now the column names)
    pcs = pcs.drop(0)
    
    # Reset the index to remove any potential issues
    pcs = pcs.reset_index(drop=True)
    
    # Check size
    print(f'PCs: {pcs.shape}')
    
     # Check value counts of SEX
    sex_og_values = ancestry_key['SEX'].value_counts(dropna=False)
    print(f'Sex value counts - original:\n {sex_og_values.to_string()}')
    
     # Convert sex to binary (1/2)
    ## Assign conditions so female=2 and men=1, and -9 otherwise (matching PLINK convention)
    # Female = 2; Male = 1
    sex_mapping = {"Female": 2, "Male": 1}
    ancestry_key['SEX'] = ancestry_key['SEX'].map(sex_mapping).astype('Int64')
    
    # Check value counts of SEX after recoding
    sex_recode_values = ancestry_key['SEX'].value_counts(dropna=False)
    print(f'Sex value counts - recoded:\n{sex_recode_values.to_string()}')
    
    ## Make covariate file
    df = pd.merge(pcs, ancestry_key, on='IID', how='left')
    print(f'Check columns for covariate file: {df.columns}')
    
    #Make additional columns - FID, fatid and matid - these are needed for RVtests!!
    #RVtests needs the first 5 columns to be fid, iid, fatid, matid and sex otherwise it does not run correctly
    #Uppercase column name is ok
    #See https://zhanxw.github.io/rvtests/#phenotype-file
    df['FID'] = 0
    df['FATID'] = 0
    df['MATID'] = 0
    
    ## Clean up and keep columns we need 
    final_df = df[['FID','IID', 'FATID', 'MATID', 'SEX', 'AGE', 'PHENO','PC1', 'PC2', 'PC3', 'PC4', 'PC5']].copy()
    
    ##DO NOT replace missing values with -9 as this is misinterpreted by RVtests - needs to be nonnumeric
    #Leave missing values as NA
    
    #Check number of PD cases missing age
    pd_missAge = final_df[(final_df['PHENO']==2)&(final_df['AGE'].isna())]
    print(f'Number of PD cases missing age: {pd_missAge.shape[0]}')
    
    #Check number of controls missing age
    control_missAge = final_df[(final_df['PHENO']==1)&(final_df['AGE'].isna())]
    print(f'Number of controls missing age: {control_missAge.shape[0]}')
    
    ## Make file of sample IDs to keep 
    samples_toKeep = final_df[['FID', 'IID']].copy()
    samples_toKeep.to_csv(f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}/{ancestry}.samplestoKeep', sep = '\t', index=False, header=None)
    
    ## Make your covariate file
    #Included na_rep to write out missing/NA values explicitly as string/text, not as blank otherwise they are misread in RVtests
    final_df.to_csv(f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}/{ancestry}_covariate_file.txt', sep = '\t', na_rep='NA', index=False)
# Out:
# WORKING ON: AJ
# Related individuals: (245, 9)
# Unrelated individuals: (2675, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          1655
# Female                        1009
# Other/Unknown/Not Reported      11
# Sex value counts - recoded:
# SEX
# 1       1655
# 2       1009
# <NA>      11
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 95
# Number of controls missing age: 195
# WORKING ON: EAS
# Related individuals: (350, 9)
# Unrelated individuals: (5303, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          3398
# Female                        1899
# Other/Unknown/Not Reported       6
# Sex value counts - recoded:
# SEX
# 1       3398
# 2       1899
# <NA>       6
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 1349
# Number of controls missing age: 1268
# WORKING ON: SAS
# Related individuals: (55, 9)
# Unrelated individuals: (624, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          397
# Female                        226
# Other/Unknown/Not Reported      1
# Sex value counts - recoded:
# SEX
# 1       397
# 2       226
# <NA>      1
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 203
# Number of controls missing age: 83
# WORKING ON: AMR
# Related individuals: (51, 9)
# Unrelated individuals: (672, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          374
# Female                        296
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 1       374
# 2       296
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 106
# Number of controls missing age: 55
# WORKING ON: MDE
# Related individuals: (19, 9)
# Unrelated individuals: (589, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          368
# Female                        219
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 1       368
# 2       219
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 140
# Number of controls missing age: 12
# WORKING ON: CAH
# Related individuals: (65, 9)
# Unrelated individuals: (1108, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          585
# Female                        498
# Other/Unknown/Not Reported     25
# Sex value counts - recoded:
# SEX
# 1       585
# 2       498
# <NA>     25
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 136
# Number of controls missing age: 52
# WORKING ON: FIN
# Related individuals: (7, 9)
# Unrelated individuals: (117, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female    63
# Male      54
# Sex value counts - recoded:
# SEX
# 2    63
# 1    54
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 62
# Number of controls missing age: 3
# WORKING ON: CAS
# Related individuals: (137, 9)
# Unrelated individuals: (933, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female    483
# Male      450
# Sex value counts - recoded:
# SEX
# 2    483
# 1    450
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 111
# Number of controls missing age: 88
# WORKING ON: AFR
# Related individuals: (228, 9)
# Unrelated individuals: (2752, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          1553
# Female                        1197
# Other/Unknown/Not Reported       2
# Sex value counts - recoded:
# SEX
# 1       1553
# 2       1197
# <NA>       2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 835
# Number of controls missing age: 809
# WORKING ON: EUR
# Related individuals: (3662, 9)
# Unrelated individuals: (39710, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Male                          23733
# Female                        15784
# Other/Unknown/Not Reported      193
# Sex value counts - recoded:
# SEX
# 1       23733
# 2       15784
# <NA>      193
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 5947
# Number of controls missing age: 3347
# WORKING ON: AAC
# Related individuals: (28, 9)
# Unrelated individuals: (1181, 6)
# PCs: (58209, 6)
# Sex value counts - original:
#  SEX
# Female                        690
# Male                          489
# Other/Unknown/Not Reported      2
# Sex value counts - recoded:
# SEX
# 2       690
# 1       489
# <NA>      2
# Check columns for covariate file: Index(['IID', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'phenotype', 'SEX', 'AGE',
#        'AAO', 'label', 'PHENO'],
#       dtype='object')
# Number of PD cases missing age: 91
# Number of controls missing age: 96

# %% [markdown]
# Annotation of the gene
#
# Extract the region using PLINK
#
# Extract SCARB2 gene
#
# SCARB2 coordinates: Chromosome 4: 76,158,737-76,234,536(GRCh38/hg38)

# %%
# generate binary file in eur ancestry

WORK_DIR = "~/workspace/ws_files/SCARB2/"

! /home/jupyter/tools/plink2 \
--pfile {REL7_PATH}/imputed_genotypes/EUR/chr4_EUR_release7_vwb \
--chr 4 \
--from-bp 76108737 \
--to-bp 76284536 \
--make-bed \
--out {WORK_DIR}/SCARB2_EUR/EUR_SCARB2
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 27 14:03:25 2024
# 52223 MiB RAM detected, ~50462 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.psam.
# 10419161 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.pvar.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# 9570 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.bed ...
# 54done.
# End time: Tue Aug 27 14:03:33 2024

# %%
## extract region using plink
for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"

    ! /home/jupyter/tools/plink2 \
    --pfile {REL7_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release7_vwb \
    --chr 4 \
    --from-bp 76108737 \
    --to-bp 76284536 \
    --make-bed \
    --out {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:27 2024
# 52223 MiB RAM detected, ~50313 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.psam.
# 1669760 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.pvar.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# 1849 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:29 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:30 2024
# 52223 MiB RAM detected, ~50291 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.psam.
# 3235052 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.pvar.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# 3094 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:32 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:33 2024
# 52223 MiB RAM detected, ~50272 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.psam.
# 1933318 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.pvar.
# 1 binary phenotype loaded (387 cases, 222 controls).
# 2058 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:34 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:35 2024
# 52223 MiB RAM detected, ~50265 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.psam.
# 2407746 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.pvar.
# 1 binary phenotype loaded (458 cases, 155 controls).
# 2516 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:37 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:37 2024
# 52223 MiB RAM detected, ~50251 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.psam.
# 2161336 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.pvar.
# 1 binary phenotype loaded (311 cases, 225 controls).
# 2380 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:39 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:39 2024
# 52223 MiB RAM detected, ~50246 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.psam.
# 3678288 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.pvar.
# 1 binary phenotype loaded (525 cases, 302 controls).
# 3550 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:42 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:42 2024
# 52223 MiB RAM detected, ~50245 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.psam.
# 891614 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.pvar.
# 1 binary phenotype loaded (98 cases, 8 controls).
# 1166 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:44 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:44 2024
# 52223 MiB RAM detected, ~50240 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.psam.
# 2200655 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.pvar.
# 1 binary phenotype loaded (552 cases, 343 controls).
# 2219 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:46 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:46 2024
# 52223 MiB RAM detected, ~50236 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.psam.
# 4555051 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.pvar.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# 4304 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:35:50 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:50 2024
# 52223 MiB RAM detected, ~50236 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.psam.
# 10419161 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.pvar.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# 9570 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.bed ...
# 54done.
# End time: Tue Aug 20 09:35:58 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.log.
# Options in effect:
#   --chr 4
#   --from-bp 76108737
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb
#   --to-bp 76284536
#
# Start time: Tue Aug 20 09:35:58 2024
# 52223 MiB RAM detected, ~50226 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.psam.
# 3986699 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.pvar.
# 1 binary phenotype loaded (285 cases, 801 controls).
# 3848 variants remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.bed ...
# done.
# End time: Tue Aug 20 09:36:01 2024

# %%
# Visualize bim file
! head {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.bim
# Out:
# 4	chr4:76108753:T:G	0	76108753	G	T
# 4	chr4:76108755:T:C	0	76108755	C	T
# 4	chr4:76108761:G:A	0	76108761	A	G
# 4	chr4:76108794:G:A	0	76108794	A	G
# 4	chr4:76108804:T:A	0	76108804	A	T
# 4	chr4:76108804:T:C	0	76108804	C	T
# 4	chr4:76108807:A:C	0	76108807	C	A
# 4	chr4:76108828:G:T	0	76108828	T	G
# 4	chr4:76108844:G:A	0	76108844	A	G
# 4	chr4:76108848:C:T	0	76108848	T	C

# %%
# Visualize bim file
! head {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.fam

# %%
for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    
    ! head -n 1 {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2.fam > {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_s1.txt

# %%
! head {WORK_DIR}/SCARB2_EUR/EUR_s1.txt

# %% [markdown]
# Turn binary files into VCF

# %%
for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2 \
    --keep {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_s1.txt \
    --make-bed \
    --out {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:51 2024
# 52223 MiB RAM detected, ~50233 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.fam.
# 1849 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.bim.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.fam ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.bim ...
# done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.bed ...
# done.
# End time: Tue Aug 20 09:38:52 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:52 2024
# 52223 MiB RAM detected, ~50243 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.fam.
# 3094 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.bim.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:52 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:52 2024
# 52223 MiB RAM detected, ~50244 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.fam.
# 2058 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.bim.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:53 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:53 2024
# 52223 MiB RAM detected, ~50228 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.fam.
# 2516 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.bim.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:54 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:54 2024
# 52223 MiB RAM detected, ~50229 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.fam.
# 2380 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.bim.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:54 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:55 2024
# 52223 MiB RAM detected, ~50229 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.fam.
# 3550 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.bim.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:55 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:55 2024
# 52223 MiB RAM detected, ~50230 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.fam.
# 1166 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.bim.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:56 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:56 2024
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.fam.
# 2219 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.bim.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:57 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:57 2024
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.fam.
# 4304 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.bim.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:57 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:57 2024
# 52223 MiB RAM detected, ~50232 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.fam.
# 9570 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:58 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2
#   --keep /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_s1.txt
#   --make-bed
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1
#
# Start time: Tue Aug 20 09:38:58 2024
# 52223 MiB RAM detected, ~50232 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.fam.
# 3848 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.bim.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --keep: 1 sample remaining.
# 1 sample (0 females, 1 male; 1 founder) remaining after main filters.
# 1 case and 0 controls remaining after main filters.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.fam
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.bim
# ... done.
# Writing /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.bed
# ... done.
# End time: Tue Aug 20 09:38:58 2024

# %%
for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    
    ## Turn binary files into VCF
    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1 \
    --recode vcf-fid \
    --out {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:45 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50245 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.fam.
# 1849 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:45 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:46 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50245 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.fam.
# 3094 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:46 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:46 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.fam.
# 2058 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:46 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:47 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50232 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.fam.
# 2516 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:47 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:47 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50233 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.fam.
# 2380 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:47 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:48 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.fam.
# 3550 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:48 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:48 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.fam.
# 1166 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:48 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:49 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50231 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.fam.
# 2219 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:49 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:49 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50232 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.fam.
# 4304 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:49 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:50 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50233 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.fam.
# 9570 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:50 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.log.
# Options in effect:
#   --bfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1
#   --export vcf-fid
#   --out /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1
#
# Start time: Tue Aug 20 09:39:50 2024
# Note: --export 'vcf-fid' modifier is deprecated.  Use 'vcf' + 'id-paste=fid'.
# 52223 MiB RAM detected, ~50233 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1 sample (0 females, 1 male; 1 founder) loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.fam.
# 3848 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.bim.
# 1 binary phenotype loaded (1 case, 0 controls).
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.vcf ... .
# End time: Tue Aug 20 09:39:50 2024

# %%
### Bgzip and Tabix (zip and index the file)
for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    ! bgzip -f {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1.vcf
    ! tabix -f -p vcf {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1.vcf.gz

# %% [markdown]
# Annotate using ANNOVAR

# %%
## annotate using ANNOVAR

for ancestry in ancestries:
    
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    
    ! perl /home/jupyter/tools/annovar/table_annovar.pl {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2_v1.vcf.gz /home/jupyter/tools/annovar/humandb/ -buildver hg38 \
    -out {WORK_DIR}/SCARB2_{ancestry}/{ancestry}_SCARB2.annovar \
    -remove -protocol refGene,clinvar_20140902 \
    -operation g,f \
    --nopolish \
    -nastring . \
    -vcfinput
# Out:
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.avinput>
# NOTICE: Finished reading 1856 lines from VCF file
# NOTICE: A total of 1849 locus in VCF file passed QC threshold, representing 1707 SNPs (1174 transitions and 533 transversions) and 142 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1707 SNP genotypes (1174 transitions and 533 transversions) and 142 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 1849 unique variants in 1849 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 1849 unique variants in 1849 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AJ/AJ_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.avinput>
# NOTICE: Finished reading 3101 lines from VCF file
# NOTICE: A total of 3094 locus in VCF file passed QC threshold, representing 2838 SNPs (2001 transitions and 837 transversions) and 256 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2838 SNP genotypes (2001 transitions and 837 transversions) and 256 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3094 unique variants in 3094 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3094 unique variants in 3094 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EAS/EAS_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.avinput>
# NOTICE: Finished reading 2065 lines from VCF file
# NOTICE: A total of 2058 locus in VCF file passed QC threshold, representing 1908 SNPs (1329 transitions and 579 transversions) and 150 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1908 SNP genotypes (1329 transitions and 579 transversions) and 150 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2058 unique variants in 2058 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2058 unique variants in 2058 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_SAS/SAS_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.avinput>
# NOTICE: Finished reading 2523 lines from VCF file
# NOTICE: A total of 2516 locus in VCF file passed QC threshold, representing 2313 SNPs (1613 transitions and 700 transversions) and 203 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2313 SNP genotypes (1613 transitions and 700 transversions) and 203 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2516 unique variants in 2516 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2516 unique variants in 2516 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AMR/AMR_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.avinput>
# NOTICE: Finished reading 2387 lines from VCF file
# NOTICE: A total of 2380 locus in VCF file passed QC threshold, representing 2192 SNPs (1535 transitions and 657 transversions) and 188 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2192 SNP genotypes (1535 transitions and 657 transversions) and 188 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2380 unique variants in 2380 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2380 unique variants in 2380 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_MDE/MDE_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.avinput>
# NOTICE: Finished reading 3557 lines from VCF file
# NOTICE: A total of 3550 locus in VCF file passed QC threshold, representing 3252 SNPs (2279 transitions and 973 transversions) and 298 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3252 SNP genotypes (2279 transitions and 973 transversions) and 298 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3550 unique variants in 3550 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3550 unique variants in 3550 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAH/CAH_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.avinput>
# NOTICE: Finished reading 1173 lines from VCF file
# NOTICE: A total of 1166 locus in VCF file passed QC threshold, representing 1080 SNPs (735 transitions and 345 transversions) and 86 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 1080 SNP genotypes (735 transitions and 345 transversions) and 86 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 1166 unique variants in 1166 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 1166 unique variants in 1166 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_FIN/FIN_SCARB2.annovar.hg38_multianno.vcf
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.avinput>
# NOTICE: Finished reading 2226 lines from VCF file
# NOTICE: A total of 2219 locus in VCF file passed QC threshold, representing 2036 SNPs (1417 transitions and 619 transversions) and 183 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 2036 SNP genotypes (1417 transitions and 619 transversions) and 183 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 2219 unique variants in 2219 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 2219 unique variants in 2219 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_CAS/CAS_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.avinput>
# NOTICE: Finished reading 4311 lines from VCF file
# NOTICE: A total of 4304 locus in VCF file passed QC threshold, representing 3886 SNPs (2705 transitions and 1181 transversions) and 418 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3886 SNP genotypes (2705 transitions and 1181 transversions) and 418 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 4304 unique variants in 4304 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 4304 unique variants in 4304 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AFR/AFR_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.avinput>
# NOTICE: Finished reading 9577 lines from VCF file
# NOTICE: A total of 9570 locus in VCF file passed QC threshold, representing 8744 SNPs (6039 transitions and 2705 transversions) and 826 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 8744 SNP genotypes (6039 transitions and 2705 transversions) and 826 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 9570 unique variants in 9570 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 9570 unique variants in 9570 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_EUR/EUR_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe
#
# NOTICE: Running with system command <convert2annovar.pl  -includeinfo -allsample -withfreq -format vcf4 /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2_v1.vcf.gz > /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.avinput>
# NOTICE: Finished reading 3855 lines from VCF file
# NOTICE: A total of 3848 locus in VCF file passed QC threshold, representing 3499 SNPs (2424 transitions and 1075 transversions) and 349 indels/substitutions
# NOTICE: Finished writing allele frequencies based on 3499 SNP genotypes (2424 transitions and 1075 transversions) and 349 indels/substitutions for 1 samples
#
# NOTICE: Running with system command </home/jupyter/tools/annovar/table_annovar.pl /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/ -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar -remove -protocol refGene,clinvar_20140902 -operation g,f --nopolish -nastring . -otherinfo>
# -----------------------------------------------------------------
# NOTICE: Processing operation=g protocol=refGene
#
# NOTICE: Running with system command <annotate_variation.pl -geneanno -buildver hg38 -dbtype refGene -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.refGene -exonsort -nofirstcodondel /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: Output files are written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.refGene.variant_function, /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.refGene.exonic_variant_function
# NOTICE: Reading gene annotation from /home/jupyter/tools/annovar/humandb/hg38_refGene.txt ... Done with 88819 transcripts (including 21511 without coding sequence annotation) for 28307 unique genes
# NOTICE: Processing next batch with 3848 unique variants in 3848 input lines
# NOTICE: Reading FASTA sequences from /home/jupyter/tools/annovar/humandb/hg38_refGeneMrna.fa ... Done with 23 sequences
# WARNING: A total of 606 sequences will be ignored due to lack of correct ORF annotation
# -----------------------------------------------------------------
# NOTICE: Processing operation=f protocol=clinvar_20140902
#
# NOTICE: Running system command <annotate_variation.pl -filter -dbtype clinvar_20140902 -buildver hg38 -outfile /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.avinput /home/jupyter/tools/annovar/humandb/>
# NOTICE: the --dbtype clinvar_20140902 is assumed to be in generic ANNOVAR database format
# NOTICE: Output file with variants matching filtering criteria is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.hg38_clinvar_20140902_dropped, and output file with other variants is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.hg38_clinvar_20140902_filtered
# NOTICE: Processing next batch with 3848 unique variants in 3848 input lines
# NOTICE: Database index loaded. Total number of bins is 44781 and the number of bins to be scanned is 3
# NOTICE: Scanning filter database /home/jupyter/tools/annovar/humandb/hg38_clinvar_20140902.txt...Done
# -----------------------------------------------------------------
# NOTICE: Multianno output file is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.hg38_multianno.txt
# NOTICE: Reading from /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.hg38_multianno.txt
# -----------------------------------------------------------------
# NOTICE: VCF output is written to /home/jupyter/workspace/ws_files/SCARB2//SCARB2_AAC/AAC_SCARB2.annovar.hg38_multianno.vcf
#
# gzip: stdout: Broken pipe

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_AAC/AAC_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108753  76108753   T   C     intronic          ART3
# 1       4  76108755  76108755   T   C     intronic          ART3
# 2       4  76108761  76108761   G   A     intronic          ART3
# 3       4  76108804  76108804   T   C     intronic          ART3
# 4       4  76108828  76108828   G   T     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 3843    4  76284266  76284266   G   A     intronic  FAM47E-STBD1
# 3844    4  76284298  76284298   C   T     intronic  FAM47E-STBD1
# 3845    4  76284397  76284397   A   G     intronic  FAM47E-STBD1
# 3846    4  76284490  76284490   A   G     intronic  FAM47E-STBD1
# 3847    4  76284509  76284509   G   A     intronic  FAM47E-STBD1
#
#      GeneDetail.refGene ExonicFunc.refGene AAChange.refGene clinvar_20140902  \
# 0                     .                  .                .                .
# 1                     .                  .                .                .
# 2                     .                  .                .                .
# 3                     .                  .                .                .
# 4                     .                  .                .                .
# ...                 ...                ...              ...              ...
# 3843                  .                  .                .                .
# 3844                  .                  .                .                .
# 3845                  .                  .                .                .
# 3846                  .                  .                .                .
# 3847                  .                  .                .                .
#
#       Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0            0.0          .          .           4    76108753
# 1            0.0          .          .           4    76108755
# 2            0.0          .          .           4    76108761
# 3            0.0          .          .           4    76108804
# 4            0.5          .          .           4    76108828
# ...          ...        ...        ...         ...         ...
# 3843         0.0          .          .           4    76284266
# 3844         0.0          .          .           4    76284298
# 3845         0.0          .          .           4    76284397
# 3846         0.0          .          .           4    76284490
# 3847         0.0          .          .           4    76284509
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108753:T:C          T          C          .           .
# 1     chr4:76108755:T:C          T          C          .           .
# 2     chr4:76108761:G:A          G          A          .           .
# 3     chr4:76108804:T:C          T          C          .           .
# 4     chr4:76108828:G:T          G          T          .           .
# ...                 ...        ...        ...        ...         ...
# 3843  chr4:76284266:G:A          G          A          .           .
# 3844  chr4:76284298:C:T          C          T          .           .
# 3845  chr4:76284397:A:G          A          G          .           .
# 3846  chr4:76284490:A:G          A          G          .           .
# 3847  chr4:76284509:G:A          G          A          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         0/0
# 1             PR          GT         0/0
# 2             PR          GT         0/0
# 3             PR          GT         0/0
# 4             PR          GT         0/1
# ...          ...         ...         ...
# 3843          PR          GT         0/0
# 3844          PR          GT         0/0
# 3845          PR          GT         0/0
# 3846          PR          GT         0/0
# 3847          PR          GT         0/0
#
# [3848 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      3385
# intergenic     186
# UTR3            89
# downstream      71
# exonic          59
# upstream        33
# UTR5            22
# splicing         3
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    32
# synonymous SNV       25
# stopgain              1
# stoploss              1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_AFR/AFR_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108750  76108750   T   C     intronic          ART3
# 1       4  76108755  76108755   T   C     intronic          ART3
# 2       4  76108804  76108804   T   C     intronic          ART3
# 3       4  76108828  76108828   G   T     intronic          ART3
# 4       4  76108858  76108858   G   A     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 4299    4  76284274  76284274   T   C     intronic  FAM47E-STBD1
# 4300    4  76284298  76284298   C   T     intronic  FAM47E-STBD1
# 4301    4  76284438  76284438   C   T     intronic  FAM47E-STBD1
# 4302    4  76284476  76284476   C   G     intronic  FAM47E-STBD1
# 4303    4  76284490  76284490   A   G     intronic  FAM47E-STBD1
#
#      GeneDetail.refGene ExonicFunc.refGene AAChange.refGene clinvar_20140902  \
# 0                     .                  .                .                .
# 1                     .                  .                .                .
# 2                     .                  .                .                .
# 3                     .                  .                .                .
# 4                     .                  .                .                .
# ...                 ...                ...              ...              ...
# 4299                  .                  .                .                .
# 4300                  .                  .                .                .
# 4301                  .                  .                .                .
# 4302                  .                  .                .                .
# 4303                  .                  .                .                .
#
#       Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0            0.0          .          .           4    76108750
# 1            0.0          .          .           4    76108755
# 2            0.0          .          .           4    76108804
# 3            0.5          .          .           4    76108828
# 4            1.0          .          .           4    76108858
# ...          ...        ...        ...         ...         ...
# 4299         0.0          .          .           4    76284274
# 4300         0.0          .          .           4    76284298
# 4301         0.0          .          .           4    76284438
# 4302         1.0          .          .           4    76284476
# 4303         0.0          .          .           4    76284490
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108750:T:C          T          C          .           .
# 1     chr4:76108755:T:C          T          C          .           .
# 2     chr4:76108804:T:C          T          C          .           .
# 3     chr4:76108828:G:T          G          T          .           .
# 4     chr4:76108858:G:A          G          A          .           .
# ...                 ...        ...        ...        ...         ...
# 4299  chr4:76284274:T:C          T          C          .           .
# 4300  chr4:76284298:C:T          C          T          .           .
# 4301  chr4:76284438:C:T          C          T          .           .
# 4302  chr4:76284476:C:G          C          G          .           .
# 4303  chr4:76284490:A:G          A          G          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         0/0
# 1             PR          GT         0/0
# 2             PR          GT         0/0
# 3             PR          GT         0/1
# 4             PR          GT         1/1
# ...          ...         ...         ...
# 4299          PR          GT         0/0
# 4300          PR          GT         0/0
# 4301          PR          GT         0/0
# 4302          PR          GT         1/1
# 4303          PR          GT         0/0
#
# [4304 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      3759
# intergenic     242
# UTR3            95
# downstream      81
# exonic          64
# upstream        34
# UTR5            26
# splicing         3
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV      36
# synonymous SNV         26
# frameshift deletion     1
# stoploss                1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_AJ/AJ_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108753  76108753   T   G     intronic          ART3
# 1       4  76108828  76108828   G   T     intronic          ART3
# 2       4  76108858  76108858   G   A     intronic          ART3
# 3       4  76108994  76108994   G   A     intronic          ART3
# 4       4  76109007  76109007   G   A     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 1844    4  76283418  76283418   G   A       exonic        FAM47E
# 1845    4  76283566  76283566   A   T         UTR3        FAM47E
# 1846    4  76284014  76284014   A   G     intronic  FAM47E-STBD1
# 1847    4  76284108  76284108   G   C     intronic  FAM47E-STBD1
# 1848    4  76284318  76284318   G   T     intronic  FAM47E-STBD1
#
#                                  GeneDetail.refGene ExonicFunc.refGene  \
# 0                                                 .                  .
# 1                                                 .                  .
# 2                                                 .                  .
# 3                                                 .                  .
# 4                                                 .                  .
# ...                                             ...                ...
# 1844                                              .  nonsynonymous SNV
# 1845  NM_001242936:c.*108A>T;NM_001136570:c.*108A>T                  .
# 1846                                              .                  .
# 1847                                              .                  .
# 1848                                              .                  .
#
#                                        AAChange.refGene clinvar_20140902  \
# 0                                                     .                .
# 1                                                     .                .
# 2                                                     .                .
# 3                                                     .                .
# 4                                                     .                .
# ...                                                 ...              ...
# 1844  FAM47E:NM_001136570:exon8:c.G1142A:p.R381H,FAM...                .
# 1845                                                  .                .
# 1846                                                  .                .
# 1847                                                  .                .
# 1848                                                  .                .
#
#       Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0            0.0          .          .           4    76108753
# 1            0.5          .          .           4    76108828
# 2            0.5          .          .           4    76108858
# 3            0.5          .          .           4    76108994
# 4            0.5          .          .           4    76109007
# ...          ...        ...        ...         ...         ...
# 1844         0.0          .          .           4    76283418
# 1845         0.0          .          .           4    76283566
# 1846         0.0          .          .           4    76284014
# 1847         0.0          .          .           4    76284108
# 1848         0.0          .          .           4    76284318
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108753:T:G          T          G          .           .
# 1     chr4:76108828:G:T          G          T          .           .
# 2     chr4:76108858:G:A          G          A          .           .
# 3     chr4:76108994:G:A          G          A          .           .
# 4     chr4:76109007:G:A          G          A          .           .
# ...                 ...        ...        ...        ...         ...
# 1844  chr4:76283418:G:A          G          A          .           .
# 1845  chr4:76283566:A:T          A          T          .           .
# 1846  chr4:76284014:A:G          A          G          .           .
# 1847  chr4:76284108:G:C          G          C          .           .
# 1848  chr4:76284318:G:T          G          T          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         0/0
# 1             PR          GT         0/1
# 2             PR          GT         0/1
# 3             PR          GT         0/1
# 4             PR          GT         0/1
# ...          ...         ...         ...
# 1844          PR          GT         0/0
# 1845          PR          GT         0/0
# 1846          PR          GT         0/0
# 1847          PR          GT         0/0
# 1848          PR          GT         0/0
#
# [1849 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1605
# intergenic     111
# UTR3            42
# downstream      33
# exonic          31
# upstream        21
# UTR5             5
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    19
# synonymous SNV       12
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_AMR/AMR_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108753  76108753   T   G     intronic          ART3
# 1       4  76108755  76108755   T   C     intronic          ART3
# 2       4  76108804  76108804   T   C     intronic          ART3
# 3       4  76108828  76108828   G   T     intronic          ART3
# 4       4  76108858  76108858   G   A     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 2511    4  76283751  76283751   G   A         UTR3        FAM47E
# 2512    4  76283911  76283911   C   T     intronic  FAM47E-STBD1
# 2513    4  76284105  76284105   A   -     intronic  FAM47E-STBD1
# 2514    4  76284108  76284108   G   C     intronic  FAM47E-STBD1
# 2515    4  76284509  76284509   G   A     intronic  FAM47E-STBD1
#
#                                  GeneDetail.refGene ExonicFunc.refGene  \
# 0                                                 .                  .
# 1                                                 .                  .
# 2                                                 .                  .
# 3                                                 .                  .
# 4                                                 .                  .
# ...                                             ...                ...
# 2511  NM_001242936:c.*293G>A;NM_001136570:c.*293G>A                  .
# 2512                                              .                  .
# 2513                                              .                  .
# 2514                                              .                  .
# 2515                                              .                  .
#
#      AAChange.refGene clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  \
# 0                   .                .          0          .          .
# 1                   .                .          0          .          .
# 2                   .                .          0          .          .
# 3                   .                .        0.5          .          .
# 4                   .                .        0.5          .          .
# ...               ...              ...        ...        ...        ...
# 2511                .                .          0          .          .
# 2512                .                .          0          .          .
# 2513                .                .          0          .          .
# 2514                .                .          0          .          .
# 2515                .                .          0          .          .
#
#       Otherinfo4  Otherinfo5          Otherinfo6 Otherinfo7 Otherinfo8  \
# 0              4    76108753   chr4:76108753:T:G          T          G
# 1              4    76108755   chr4:76108755:T:C          T          C
# 2              4    76108804   chr4:76108804:T:C          T          C
# 3              4    76108828   chr4:76108828:G:T          G          T
# 4              4    76108858   chr4:76108858:G:A          G          A
# ...          ...         ...                 ...        ...        ...
# 2511           4    76283751   chr4:76283751:G:A          G          A
# 2512           4    76283911   chr4:76283911:C:T          C          T
# 2513           4    76284104  chr4:76284104:TA:T         TA          T
# 2514           4    76284108   chr4:76284108:G:C          G          C
# 2515           4    76284509   chr4:76284509:G:A          G          A
#
#      Otherinfo9 Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0             .           .          PR          GT         0/0
# 1             .           .          PR          GT         0/0
# 2             .           .          PR          GT         0/0
# 3             .           .          PR          GT         0/1
# 4             .           .          PR          GT         0/1
# ...         ...         ...         ...         ...         ...
# 2511          .           .          PR          GT         0/0
# 2512          .           .          PR          GT         0/0
# 2513          .           .          PR          GT         0/0
# 2514          .           .          PR          GT         0/0
# 2515          .           .          PR          GT         0/0
#
# [2516 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2212
# intergenic     137
# UTR3            47
# downstream      44
# exonic          43
# upstream        22
# UTR5             9
# splicing         2
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    29
# synonymous SNV       14
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_CAH/CAH_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108753  76108753   T   C     intronic          ART3
# 1       4  76108755  76108755   T   C     intronic          ART3
# 2       4  76108804  76108804   T   C     intronic          ART3
# 3       4  76108828  76108828   G   T     intronic          ART3
# 4       4  76108848  76108848   C   T     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 3545    4  76284241  76284241   C   T     intronic  FAM47E-STBD1
# 3546    4  76284281  76284281   C   A     intronic  FAM47E-STBD1
# 3547    4  76284298  76284298   C   T     intronic  FAM47E-STBD1
# 3548    4  76284303  76284303   C   A     intronic  FAM47E-STBD1
# 3549    4  76284397  76284397   A   G     intronic  FAM47E-STBD1
#
#      GeneDetail.refGene ExonicFunc.refGene AAChange.refGene clinvar_20140902  \
# 0                     .                  .                .                .
# 1                     .                  .                .                .
# 2                     .                  .                .                .
# 3                     .                  .                .                .
# 4                     .                  .                .                .
# ...                 ...                ...              ...              ...
# 3545                  .                  .                .                .
# 3546                  .                  .                .                .
# 3547                  .                  .                .                .
# 3548                  .                  .                .                .
# 3549                  .                  .                .                .
#
#       Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0            0.0          .          .           4    76108753
# 1            0.0          .          .           4    76108755
# 2            0.0          .          .           4    76108804
# 3            0.0          .          .           4    76108828
# 4            0.0          .          .           4    76108848
# ...          ...        ...        ...         ...         ...
# 3545         0.0          .          .           4    76284241
# 3546         0.0          .          .           4    76284281
# 3547         0.0          .          .           4    76284298
# 3548         0.0          .          .           4    76284303
# 3549         0.0          .          .           4    76284397
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108753:T:C          T          C          .           .
# 1     chr4:76108755:T:C          T          C          .           .
# 2     chr4:76108804:T:C          T          C          .           .
# 3     chr4:76108828:G:T          G          T          .           .
# 4     chr4:76108848:C:T          C          T          .           .
# ...                 ...        ...        ...        ...         ...
# 3545  chr4:76284241:C:T          C          T          .           .
# 3546  chr4:76284281:C:A          C          A          .           .
# 3547  chr4:76284298:C:T          C          T          .           .
# 3548  chr4:76284303:C:A          C          A          .           .
# 3549  chr4:76284397:A:G          A          G          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         0/0
# 1             PR          GT         0/0
# 2             PR          GT         0/0
# 3             PR          GT         0/0
# 4             PR          GT         0/0
# ...          ...         ...         ...
# 3545          PR          GT         0/0
# 3546          PR          GT         0/0
# 3547          PR          GT         0/0
# 3548          PR          GT         0/0
# 3549          PR          GT         0/0
#
# [3550 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      3125
# intergenic     189
# UTR3            71
# downstream      66
# exonic          52
# upstream        25
# UTR5            19
# splicing         3
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    29
# synonymous SNV       22
# stopgain              1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_CAS/CAS_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End   Ref Alt Func.refGene         Gene.refGene  \
# 0       4  76108828  76108828     G   T     intronic                 ART3
# 1       4  76108858  76108858     G   A     intronic                 ART3
# 2       4  76108861  76108864  GTAA   -     intronic                 ART3
# 3       4  76108994  76108994     G   A     intronic                 ART3
# 4       4  76109007  76109007     G   A     intronic                 ART3
# ...   ...       ...       ...   ...  ..          ...                  ...
# 2214    4  76283347  76283347     C   T     intronic  FAM47E;FAM47E-STBD1
# 2215    4  76283509  76283509     A   G         UTR3               FAM47E
# 2216    4  76284107  76284107     A   G     intronic         FAM47E-STBD1
# 2217    4  76284122  76284122     C   G     intronic         FAM47E-STBD1
# 2218    4  76284241  76284241     C   T     intronic         FAM47E-STBD1
#
#                                GeneDetail.refGene ExonicFunc.refGene  \
# 0                                               .                  .
# 1                                               .                  .
# 2                                               .                  .
# 3                                               .                  .
# 4                                               .                  .
# ...                                           ...                ...
# 2214                                            .                  .
# 2215  NM_001242936:c.*51A>G;NM_001136570:c.*51A>G                  .
# 2216                                            .                  .
# 2217                                            .                  .
# 2218                                            .                  .
#
#      AAChange.refGene clinvar_20140902  Otherinfo1 Otherinfo2 Otherinfo3  \
# 0                   .                .         0.5          .          .
# 1                   .                .         0.5          .          .
# 2                   .                .         0.0          .          .
# 3                   .                .         0.0          .          .
# 4                   .                .         0.0          .          .
# ...               ...              ...         ...        ...        ...
# 2214                .                .         0.0          .          .
# 2215                .                .         0.0          .          .
# 2216                .                .         0.0          .          .
# 2217                .                .         0.0          .          .
# 2218                .                .         0.0          .          .
#
#       Otherinfo4  Otherinfo5             Otherinfo6 Otherinfo7 Otherinfo8  \
# 0              4    76108828      chr4:76108828:G:T          G          T
# 1              4    76108858      chr4:76108858:G:A          G          A
# 2              4    76108860  chr4:76108860:GGTAA:G      GGTAA          G
# 3              4    76108994      chr4:76108994:G:A          G          A
# 4              4    76109007      chr4:76109007:G:A          G          A
# ...          ...         ...                    ...        ...        ...
# 2214           4    76283347      chr4:76283347:C:T          C          T
# 2215           4    76283509      chr4:76283509:A:G          A          G
# 2216           4    76284107      chr4:76284107:A:G          A          G
# 2217           4    76284122      chr4:76284122:C:G          C          G
# 2218           4    76284241      chr4:76284241:C:T          C          T
#
#      Otherinfo9 Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0             .           .          PR          GT         0/1
# 1             .           .          PR          GT         0/1
# 2             .           .          PR          GT         0/0
# 3             .           .          PR          GT         0/0
# 4             .           .          PR          GT         0/0
# ...         ...         ...         ...         ...         ...
# 2214          .           .          PR          GT         0/0
# 2215          .           .          PR          GT         0/0
# 2216          .           .          PR          GT         0/0
# 2217          .           .          PR          GT         0/0
# 2218          .           .          PR          GT         0/0
#
# [2219 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1945
# intergenic     120
# UTR3            51
# downstream      37
# exonic          36
# upstream        19
# UTR5            10
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    21
# synonymous SNV       14
# stopgain              1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_EAS/EAS_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108828  76108828   G   T     intronic          ART3
# 1       4  76108858  76108858   G   A     intronic          ART3
# 2       4  76108994  76108994   G   A     intronic          ART3
# 3       4  76109007  76109007   G   A     intronic          ART3
# 4       4  76109074  76109074   A   G     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 3089    4  76284241  76284241   C   T     intronic  FAM47E-STBD1
# 3090    4  76284298  76284298   C   T     intronic  FAM47E-STBD1
# 3091    4  76284478  76284478   C   T     intronic  FAM47E-STBD1
# 3092    4  76284489  76284489   C   T     intronic  FAM47E-STBD1
# 3093    4  76284493  76284493   C   T     intronic  FAM47E-STBD1
#
#      GeneDetail.refGene ExonicFunc.refGene AAChange.refGene clinvar_20140902  \
# 0                     .                  .                .                .
# 1                     .                  .                .                .
# 2                     .                  .                .                .
# 3                     .                  .                .                .
# 4                     .                  .                .                .
# ...                 ...                ...              ...              ...
# 3089                  .                  .                .                .
# 3090                  .                  .                .                .
# 3091                  .                  .                .                .
# 3092                  .                  .                .                .
# 3093                  .                  .                .                .
#
#      Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0             0          .          .           4    76108828
# 1             0          .          .           4    76108858
# 2             1          .          .           4    76108994
# 3             1          .          .           4    76109007
# 4             0          .          .           4    76109074
# ...         ...        ...        ...         ...         ...
# 3089          0          .          .           4    76284241
# 3090          0          .          .           4    76284298
# 3091          0          .          .           4    76284478
# 3092          0          .          .           4    76284489
# 3093          0          .          .           4    76284493
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108828:G:T          G          T          .           .
# 1     chr4:76108858:G:A          G          A          .           .
# 2     chr4:76108994:G:A          G          A          .           .
# 3     chr4:76109007:G:A          G          A          .           .
# 4     chr4:76109074:A:G          A          G          .           .
# ...                 ...        ...        ...        ...         ...
# 3089  chr4:76284241:C:T          C          T          .           .
# 3090  chr4:76284298:C:T          C          T          .           .
# 3091  chr4:76284478:C:T          C          T          .           .
# 3092  chr4:76284489:C:T          C          T          .           .
# 3093  chr4:76284493:C:T          C          T          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         0/0
# 1             PR          GT         0/0
# 2             PR          GT         1/1
# 3             PR          GT         1/1
# 4             PR          GT         0/0
# ...          ...         ...         ...
# 3089          PR          GT         0/0
# 3090          PR          GT         0/0
# 3091          PR          GT         0/0
# 3092          PR          GT         0/0
# 3093          PR          GT         0/0
#
# [3094 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2670
# intergenic     170
# UTR3            84
# downstream      59
# exonic          58
# UTR5            26
# upstream        25
# splicing         2
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV      35
# synonymous SNV         21
# stopgain                1
# frameshift deletion     1
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_MDE/MDE_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108755  76108755   T   C     intronic          ART3
# 1       4  76108804  76108804   T   C     intronic          ART3
# 2       4  76108820  76108820   A   G     intronic          ART3
# 3       4  76108828  76108828   G   T     intronic          ART3
# 4       4  76108858  76108858   G   A     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 2375    4  76283774  76283774   T   G         UTR3        FAM47E
# 2376    4  76284107  76284107   A   G     intronic  FAM47E-STBD1
# 2377    4  76284108  76284108   G   C     intronic  FAM47E-STBD1
# 2378    4  76284127  76284127   C   T     intronic  FAM47E-STBD1
# 2379    4  76284298  76284298   C   T     intronic  FAM47E-STBD1
#
#                                  GeneDetail.refGene ExonicFunc.refGene  \
# 0                                                 .                  .
# 1                                                 .                  .
# 2                                                 .                  .
# 3                                                 .                  .
# 4                                                 .                  .
# ...                                             ...                ...
# 2375  NM_001242936:c.*316T>G;NM_001136570:c.*316T>G                  .
# 2376                                              .                  .
# 2377                                              .                  .
# 2378                                              .                  .
# 2379                                              .                  .
#
#      AAChange.refGene clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  \
# 0                   .                .          0          .          .
# 1                   .                .          0          .          .
# 2                   .                .          0          .          .
# 3                   .                .        0.5          .          .
# 4                   .                .        0.5          .          .
# ...               ...              ...        ...        ...        ...
# 2375                .                .          0          .          .
# 2376                .                .          0          .          .
# 2377                .                .          0          .          .
# 2378                .                .          0          .          .
# 2379                .                .          0          .          .
#
#       Otherinfo4  Otherinfo5         Otherinfo6 Otherinfo7 Otherinfo8  \
# 0              4    76108755  chr4:76108755:T:C          T          C
# 1              4    76108804  chr4:76108804:T:C          T          C
# 2              4    76108820  chr4:76108820:A:G          A          G
# 3              4    76108828  chr4:76108828:G:T          G          T
# 4              4    76108858  chr4:76108858:G:A          G          A
# ...          ...         ...                ...        ...        ...
# 2375           4    76283774  chr4:76283774:T:G          T          G
# 2376           4    76284107  chr4:76284107:A:G          A          G
# 2377           4    76284108  chr4:76284108:G:C          G          C
# 2378           4    76284127  chr4:76284127:C:T          C          T
# 2379           4    76284298  chr4:76284298:C:T          C          T
#
#      Otherinfo9 Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0             .           .          PR          GT         0/0
# 1             .           .          PR          GT         0/0
# 2             .           .          PR          GT         0/0
# 3             .           .          PR          GT         0/1
# 4             .           .          PR          GT         0/1
# ...         ...         ...         ...         ...         ...
# 2375          .           .          PR          GT         0/0
# 2376          .           .          PR          GT         0/0
# 2377          .           .          PR          GT         0/0
# 2378          .           .          PR          GT         0/0
# 2379          .           .          PR          GT         0/0
#
# [2380 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      2116
# intergenic     116
# UTR3            42
# downstream      37
# exonic          36
# upstream        20
# UTR5            11
# splicing         2
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    26
# synonymous SNV       10
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_SAS/SAS_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End   Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108828  76108828     G   T     intronic          ART3
# 1       4  76108858  76108858     G   A     intronic          ART3
# 2       4  76108861  76108864  GTAA   -     intronic          ART3
# 3       4  76108972  76108972     T   -     intronic          ART3
# 4       4  76108974  76108974     G   A     intronic          ART3
# ...   ...       ...       ...   ...  ..          ...           ...
# 2053    4  76283677  76283677     T   G         UTR3        FAM47E
# 2054    4  76283721  76283721     G   A         UTR3        FAM47E
# 2055    4  76284022  76284022     G   A     intronic  FAM47E-STBD1
# 2056    4  76284108  76284108     G   C     intronic  FAM47E-STBD1
# 2057    4  76284298  76284298     C   T     intronic  FAM47E-STBD1
#
#                                  GeneDetail.refGene ExonicFunc.refGene  \
# 0                                                 .                  .
# 1                                                 .                  .
# 2                                                 .                  .
# 3                                                 .                  .
# 4                                                 .                  .
# ...                                             ...                ...
# 2053  NM_001242936:c.*219T>G;NM_001136570:c.*219T>G                  .
# 2054  NM_001242936:c.*263G>A;NM_001136570:c.*263G>A                  .
# 2055                                              .                  .
# 2056                                              .                  .
# 2057                                              .                  .
#
#      AAChange.refGene clinvar_20140902 Otherinfo1 Otherinfo2 Otherinfo3  \
# 0                   .                .        0.5          .          .
# 1                   .                .        0.5          .          .
# 2                   .                .          0          .          .
# 3                   .                .          0          .          .
# 4                   .                .          0          .          .
# ...               ...              ...        ...        ...        ...
# 2053                .                .          0          .          .
# 2054                .                .          0          .          .
# 2055                .                .          0          .          .
# 2056                .                .          0          .          .
# 2057                .                .          0          .          .
#
#       Otherinfo4  Otherinfo5             Otherinfo6 Otherinfo7 Otherinfo8  \
# 0              4    76108828      chr4:76108828:G:T          G          T
# 1              4    76108858      chr4:76108858:G:A          G          A
# 2              4    76108860  chr4:76108860:GGTAA:G      GGTAA          G
# 3              4    76108971     chr4:76108971:GT:G         GT          G
# 4              4    76108974      chr4:76108974:G:A          G          A
# ...          ...         ...                    ...        ...        ...
# 2053           4    76283677      chr4:76283677:T:G          T          G
# 2054           4    76283721      chr4:76283721:G:A          G          A
# 2055           4    76284022      chr4:76284022:G:A          G          A
# 2056           4    76284108      chr4:76284108:G:C          G          C
# 2057           4    76284298      chr4:76284298:C:T          C          T
#
#      Otherinfo9 Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0             .           .          PR          GT         0/1
# 1             .           .          PR          GT         0/1
# 2             .           .          PR          GT         0/0
# 3             .           .          PR          GT         0/0
# 4             .           .          PR          GT         0/0
# ...         ...         ...         ...         ...         ...
# 2053          .           .          PR          GT         0/0
# 2054          .           .          PR          GT         0/0
# 2055          .           .          PR          GT         0/0
# 2056          .           .          PR          GT         0/0
# 2057          .           .          PR          GT         0/0
#
# [2058 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      1794
# intergenic     105
# UTR3            53
# downstream      40
# exonic          34
# upstream        22
# UTR5             9
# splicing         1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    19
# synonymous SNV       15
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_FIN/FIN_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene         Gene.refGene  \
# 0       4  76108828  76108828   G   T     intronic                 ART3
# 1       4  76108858  76108858   G   A     intronic                 ART3
# 2       4  76108994  76108994   G   A     intronic                 ART3
# 3       4  76109007  76109007   G   A     intronic                 ART3
# 4       4  76109102  76109102   C   T     intronic                 ART3
# ...   ...       ...       ...  ..  ..          ...                  ...
# 1161    4  76283246  76283247  AT   -     intronic  FAM47E;FAM47E-STBD1
# 1162    4  76283278  76283279  AG   -     intronic  FAM47E;FAM47E-STBD1
# 1163    4  76283347  76283347   C   T     intronic  FAM47E;FAM47E-STBD1
# 1164    4  76283587  76283587   A   G         UTR3               FAM47E
# 1165    4  76284108  76284108   G   C     intronic         FAM47E-STBD1
#
#                                  GeneDetail.refGene ExonicFunc.refGene  \
# 0                                                 .                  .
# 1                                                 .                  .
# 2                                                 .                  .
# 3                                                 .                  .
# 4                                                 .                  .
# ...                                             ...                ...
# 1161                                              .                  .
# 1162                                              .                  .
# 1163                                              .                  .
# 1164  NM_001242936:c.*129A>G;NM_001136570:c.*129A>G                  .
# 1165                                              .                  .
#
#      AAChange.refGene clinvar_20140902  Otherinfo1 Otherinfo2 Otherinfo3  \
# 0                   .                .         0.0          .          .
# 1                   .                .         0.0          .          .
# 2                   .                .         0.5          .          .
# 3                   .                .         0.5          .          .
# 4                   .                .         0.5          .          .
# ...               ...              ...         ...        ...        ...
# 1161                .                .         0.5          .          .
# 1162                .                .         0.0          .          .
# 1163                .                .         0.5          .          .
# 1164                .                .         0.0          .          .
# 1165                .                .         0.0          .          .
#
#       Otherinfo4  Otherinfo5           Otherinfo6 Otherinfo7 Otherinfo8  \
# 0              4    76108828    chr4:76108828:G:T          G          T
# 1              4    76108858    chr4:76108858:G:A          G          A
# 2              4    76108994    chr4:76108994:G:A          G          A
# 3              4    76109007    chr4:76109007:G:A          G          A
# 4              4    76109102    chr4:76109102:C:T          C          T
# ...          ...         ...                  ...        ...        ...
# 1161           4    76283245  chr4:76283245:CAT:C        CAT          C
# 1162           4    76283277  chr4:76283277:TAG:T        TAG          T
# 1163           4    76283347    chr4:76283347:C:T          C          T
# 1164           4    76283587    chr4:76283587:A:G          A          G
# 1165           4    76284108    chr4:76284108:G:C          G          C
#
#      Otherinfo9 Otherinfo10 Otherinfo11 Otherinfo12 Otherinfo13
# 0             .           .          PR          GT         0/0
# 1             .           .          PR          GT         0/0
# 2             .           .          PR          GT         0/1
# 3             .           .          PR          GT         0/1
# 4             .           .          PR          GT         0/1
# ...         ...         ...         ...         ...         ...
# 1161          .           .          PR          GT         0/1
# 1162          .           .          PR          GT         0/0
# 1163          .           .          PR          GT         0/1
# 1164          .           .          PR          GT         0/0
# 1165          .           .          PR          GT         0/0
#
# [1166 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      999
# intergenic     84
# downstream     24
# UTR3           23
# exonic         16
# upstream       15
# UTR5            4
# splicing        1
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']
coding.count()

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV    10
# synonymous SNV        6
# Name: count, dtype: int64

# %%
# Read in ANNOVAR multianno file
gene = pd.read_csv(f'{WORK_DIR}/SCARB2_EUR/EUR_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
display(gene)
# Out:
#       Chr     Start       End Ref Alt Func.refGene  Gene.refGene  \
# 0       4  76108753  76108753   T   G     intronic          ART3
# 1       4  76108755  76108755   T   C     intronic          ART3
# 2       4  76108761  76108761   G   A     intronic          ART3
# 3       4  76108794  76108794   G   A     intronic          ART3
# 4       4  76108804  76108804   T   A     intronic          ART3
# ...   ...       ...       ...  ..  ..          ...           ...
# 9565    4  76284318  76284318   G   T     intronic  FAM47E-STBD1
# 9566    4  76284341  76284341   C   T     intronic  FAM47E-STBD1
# 9567    4  76284385  76284385   G   A     intronic  FAM47E-STBD1
# 9568    4  76284405  76284405   A   G     intronic  FAM47E-STBD1
# 9569    4  76284509  76284509   G   A     intronic  FAM47E-STBD1
#
#      GeneDetail.refGene ExonicFunc.refGene AAChange.refGene clinvar_20140902  \
# 0                     .                  .                .                .
# 1                     .                  .                .                .
# 2                     .                  .                .                .
# 3                     .                  .                .                .
# 4                     .                  .                .                .
# ...                 ...                ...              ...              ...
# 9565                  .                  .                .                .
# 9566                  .                  .                .                .
# 9567                  .                  .                .                .
# 9568                  .                  .                .                .
# 9569                  .                  .                .                .
#
#      Otherinfo1 Otherinfo2 Otherinfo3  Otherinfo4  Otherinfo5  \
# 0             .          .          .           4    76108753
# 1             0          .          .           4    76108755
# 2             0          .          .           4    76108761
# 3             0          .          .           4    76108794
# 4             0          .          .           4    76108804
# ...         ...        ...        ...         ...         ...
# 9565          0          .          .           4    76284318
# 9566          0          .          .           4    76284341
# 9567          0          .          .           4    76284385
# 9568          0          .          .           4    76284405
# 9569          .          .          .           4    76284509
#
#              Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 0     chr4:76108753:T:G          T          G          .           .
# 1     chr4:76108755:T:C          T          C          .           .
# 2     chr4:76108761:G:A          G          A          .           .
# 3     chr4:76108794:G:A          G          A          .           .
# 4     chr4:76108804:T:A          T          A          .           .
# ...                 ...        ...        ...        ...         ...
# 9565  chr4:76284318:G:T          G          T          .           .
# 9566  chr4:76284341:C:T          C          T          .           .
# 9567  chr4:76284385:G:A          G          A          .           .
# 9568  chr4:76284405:A:G          A          G          .           .
# 9569  chr4:76284509:G:A          G          A          .           .
#
#      Otherinfo11 Otherinfo12 Otherinfo13
# 0             PR          GT         ./.
# 1             PR          GT         0/0
# 2             PR          GT         0/0
# 3             PR          GT         0/0
# 4             PR          GT         0/0
# ...          ...         ...         ...
# 9565          PR          GT         0/0
# 9566          PR          GT         0/0
# 9567          PR          GT         0/0
# 9568          PR          GT         0/0
# 9569          PR          GT         ./.
#
# [9570 rows x 24 columns]

# %%
gene["Func.refGene"].value_counts()
# Out:
# Func.refGene
# intronic      8370
# intergenic     473
# UTR3           225
# exonic         194
# downstream     156
# upstream        83
# UTR5            66
# splicing         3
# Name: count, dtype: int64

# %%
# Filter exonic variants
coding = gene[gene['Func.refGene'] == 'exonic']

# %%
coding["ExonicFunc.refGene"].value_counts()
# Out:
# ExonicFunc.refGene
# nonsynonymous SNV         128
# synonymous SNV             58
# stopgain                    4
# nonframeshift deletion      1
# frameshift insertion        1
# frameshift deletion         1
# stoploss                    1
# Name: count, dtype: int64

# %%
#Make lists of variants to keep - all coding, coding nonsynonymous (missense - as they are coded in ANNOVAR), deleterious (CADD_phred > 20)

for ancestry in ancestries:
        
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    # Read in ANNOVAR multianno file
    gene = pd.read_csv(f'{WORK_DIR}/{ancestry}_SCARB2.annovar.hg38_multianno.txt', sep = '\t')
    
    #Print number of variants in the different categories
    results = [] 
    
    utr5 = gene[gene['Func.refGene']== 'UTR5']
    intronic = gene[gene['Func.refGene']== 'intronic']
    exonic = gene[gene['Func.refGene']== 'exonic']
    utr3 = gene[gene['Func.refGene']== 'UTR3']
    coding_nonsynonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] == 'nonsynonymous SNV')]
    coding_synonymous = gene[(gene['Func.refGene'] == 'exonic') & (gene['ExonicFunc.refGene'] != 'nonsynonymous SNV')]
    lof = exonic[(exonic['ExonicFunc.refGene'] == 'stopgain') | (exonic['ExonicFunc.refGene'] == 'stoploss') | (exonic['ExonicFunc.refGene'] == 'frameshift deletion') | (exonic['ExonicFunc.refGene'] == 'frameshift insertion')]
    nonsynonymous_lof = pd.concat([coding_nonsynonymous, lof])
    
    print({ancestry})
    print('Total variants: ', len(gene))
    print("Intronic: ", len(intronic))
    print('UTR3: ', len(utr3))
    print('UTR5: ', len(utr5))
    print("Total exonic: ", len(exonic))
    print('  Synonymous: ', len(coding_synonymous))
    print("  Nonsynonymous: ", len(coding_nonsynonymous))
    print("nonsynonymous_lof: ", len(nonsynonymous_lof))
    results.append((gene, intronic, utr3, utr5, exonic, coding_synonymous, coding_nonsynonymous, nonsynonymous_lof))
    print('\n')
    
    # Save in PLINK format - coding nonsynonymous 
    # These are missense variants - other types of nonsynonymous variants (e.g stopgain/loss, or frameshift variants are coded differently in the ExonicFunc.refGene 
    variants_toKeep = nonsynonymous_lof[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep.to_csv(f'{WORK_DIR}/{ancestry}_SCARB2.nonsynonymous_lof.variantstoKeep.txt', sep="\t", index=False, header=False)
    
    # Save in PLINK format - all coding variants
    variants_toKeep2 = exonic[['Chr', 'Start', 'End', 'Gene.refGene']].copy()
    variants_toKeep2.to_csv(f'{WORK_DIR}/{ancestry}_SCARB2.exonic.variantstoKeep.txt', sep="\t", index=False, header=False)
# Out:
# WORKING ON: AJ
# {'AJ'}
# Total variants:  1849
# Intronic:  1605
# UTR3:  42
# UTR5:  5
# Total exonic:  31
#   Synonymous:  12
#   Nonsynonymous:  19
# nonsynonymous_lof:  19
#
#
# WORKING ON: EAS
# {'EAS'}
# Total variants:  3094
# Intronic:  2670
# UTR3:  84
# UTR5:  26
# Total exonic:  58
#   Synonymous:  23
#   Nonsynonymous:  35
# nonsynonymous_lof:  37
#
#
# WORKING ON: SAS
# {'SAS'}
# Total variants:  2058
# Intronic:  1794
# UTR3:  53
# UTR5:  9
# Total exonic:  34
#   Synonymous:  15
#   Nonsynonymous:  19
# nonsynonymous_lof:  19
#
#
# WORKING ON: AMR
# {'AMR'}
# Total variants:  2516
# Intronic:  2212
# UTR3:  47
# UTR5:  9
# Total exonic:  43
#   Synonymous:  14
#   Nonsynonymous:  29
# nonsynonymous_lof:  29
#
#
# WORKING ON: MDE
# {'MDE'}
# Total variants:  2380
# Intronic:  2116
# UTR3:  42
# UTR5:  11
# Total exonic:  36
#   Synonymous:  10
#   Nonsynonymous:  26
# nonsynonymous_lof:  26
#
#
# WORKING ON: CAH
# {'CAH'}
# Total variants:  3550
# Intronic:  3125
# UTR3:  71
# UTR5:  19
# Total exonic:  52
#   Synonymous:  23
#   Nonsynonymous:  29
# nonsynonymous_lof:  30
#
#
# WORKING ON: FIN
# {'FIN'}
# Total variants:  1166
# Intronic:  999
# UTR3:  23
# UTR5:  4
# Total exonic:  16
#   Synonymous:  6
#   Nonsynonymous:  10
# nonsynonymous_lof:  10
#
#
# WORKING ON: CAS
# {'CAS'}
# Total variants:  2219
# Intronic:  1945
# UTR3:  51
# UTR5:  10
# Total exonic:  36
#   Synonymous:  15
#   Nonsynonymous:  21
# nonsynonymous_lof:  22
#
#
# WORKING ON: AFR
# {'AFR'}
# Total variants:  4304
# Intronic:  3759
# UTR3:  95
# UTR5:  26
# Total exonic:  64
#   Synonymous:  28
#   Nonsynonymous:  36
# nonsynonymous_lof:  38
#
#
# WORKING ON: EUR
# {'EUR'}
# Total variants:  9570
# Intronic:  8370
# UTR3:  225
# UTR5:  66
# Total exonic:  194
#   Synonymous:  66
#   Nonsynonymous:  128
# nonsynonymous_lof:  135
#
#
# WORKING ON: AAC
# {'AAC'}
# Total variants:  3848
# Intronic:  3385
# UTR3:  89
# UTR5:  22
# Total exonic:  59
#   Synonymous:  27
#   Nonsynonymous:  32
# nonsynonymous_lof:  34

# %% [markdown]
# ALL variants
#
# assoc
#
# glm

# %% [markdown]
# ASSOC

# %%
#Run case-control analysis using plink assoc for all variants, not adjusting for any covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    
    ! /home/jupyter/tools/plink \
    --bfile {WORK_DIR}/{ancestry}_SCARB2 \
    --keep {WORK_DIR}/{ancestry}.samplestoKeep \
    --assoc \
    --allow-no-sex \
    --ci 0.95 \
    --maf 0.01 \
    --out {WORK_DIR}/{ancestry}_SCARB2.all
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 3848 variants loaded from .bim file.
# 1111 people (455 males, 656 females) loaded from .fam.
# 1086 phenotype values loaded from .fam.
# --keep: 1111 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1111 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99922.
# 2388 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1460 variants and 1111 people pass filters and QC.
# Among remaining phenotypes, 285 are cases and 801 are controls.  (25 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all.assoc ...
# 70done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 4304 variants loaded from .bim file.
# 2643 people (1480 males, 1163 females) loaded from .fam.
# 2621 phenotype values loaded from .fam.
# --keep: 2643 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2643 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.998648.
# 2791 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1513 variants and 2643 people pass filters and QC.
# Among remaining phenotypes, 942 are cases and 1679 are controls.  (22
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all.assoc ...
# 67done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 1849 variants loaded from .bim file.
# 2655 people (1648 males, 1007 females) loaded from .fam.
# 1703 phenotype values loaded from .fam.
# --keep: 2655 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2655 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99951.
# 816 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1033 variants and 2655 people pass filters and QC.
# Among remaining phenotypes, 1292 are cases and 411 are controls.  (952
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all.assoc ...
# 99done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 2516 variants loaded from .bim file.
# 646 people (363 males, 283 females) loaded from .fam.
# 613 phenotype values loaded from .fam.
# --keep: 646 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 646 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99861.
# 1569 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 947 variants and 646 people pass filters and QC.
# Among remaining phenotypes, 458 are cases and 155 are controls.  (33 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 2219 variants loaded from .bim file.
# 903 people (439 males, 464 females) loaded from .fam.
# 895 phenotype values loaded from .fam.
# --keep: 903 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 903 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996859.
# 1248 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 971 variants and 903 people pass filters and QC.
# Among remaining phenotypes, 552 are cases and 343 are controls.  (8 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 3094 variants loaded from .bim file.
# 5167 people (3278 males, 1889 females) loaded from .fam.
# 5123 phenotype values loaded from .fam.
# --keep: 5167 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 5167 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995158.
# 2143 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 951 variants and 5167 people pass filters and QC.
# Among remaining phenotypes, 2662 are cases and 2461 are controls.  (44
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 9570 variants loaded from .bim file.
# 38839 people (23296 males, 15543 females) loaded from .fam.
# 30412 phenotype values loaded from .fam.
# --keep: 38838 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 38838 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.787043.
# 8651 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 919 variants and 38838 people pass filters and QC.
# Among remaining phenotypes, 21197 are cases and 9214 are controls.  (8427
# phenotypes are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 1166 variants loaded from .bim file.
# 114 people (53 males, 61 females) loaded from .fam.
# 106 phenotype values loaded from .fam.
# --keep: 114 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 114 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99827.
# 226 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 940 variants and 114 people pass filters and QC.
# Among remaining phenotypes, 98 are cases and 8 are controls.  (8 phenotypes are
# missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 2380 variants loaded from .bim file.
# 581 people (369 males, 212 females) loaded from .fam.
# 536 phenotype values loaded from .fam.
# --keep: 581 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 581 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997371.
# 1367 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1013 variants and 581 people pass filters and QC.
# Among remaining phenotypes, 311 are cases and 225 are controls.  (45 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 2058 variants loaded from .bim file.
# 635 people (408 males, 227 females) loaded from .fam.
# 609 phenotype values loaded from .fam.
# --keep: 635 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 635 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997379.
# 1147 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 911 variants and 635 people pass filters and QC.
# Among remaining phenotypes, 387 are cases and 222 are controls.  (26 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all.assoc ...
# done.
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all.log.
# Options in effect:
#   --allow-no-sex
#   --assoc
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2
#   --ci 0.95
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.samplestoKeep
#   --maf 0.01
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all
#
# 52223 MB RAM detected; reserving 26111 MB for main workspace.
# 3550 variants loaded from .bim file.
# 851 people (446 males, 405 females) loaded from .fam.
# 827 phenotype values loaded from .fam.
# --keep: 851 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 851 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.998183.
# 2257 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1293 variants and 851 people pass filters and QC.
# Among remaining phenotypes, 525 are cases and 302 are controls.  (24 phenotypes
# are missing.)
# Writing C/C --assoc report to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all.assoc ...
# 79done.

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Look at assoc results, only variants with nominal p-value < 0.05
    freq = pd.read_csv(f'{WORK_DIR}/{ancestry}_SCARB2.all.assoc', delim_whitespace=True)
    sig_all_nonadj = freq[freq['P']<0.05]
    
    print(f'Variants with p-value < 0.05: {sig_all_nonadj.shape}')
    
    #Save FREQ to csv
    freq.to_csv(f'{WORK_DIR}/{ancestry}.all_nonadj.csv')
# Out:
# WORKING ON: AAC
# Variants with p-value < 0.05: (106, 13)
# WORKING ON: AFR
# Variants with p-value < 0.05: (368, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AJ
# Variants with p-value < 0.05: (56, 13)
# WORKING ON: AMR
# Variants with p-value < 0.05: (10, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAS
# Variants with p-value < 0.05: (96, 13)
# WORKING ON: EAS
# Variants with p-value < 0.05: (403, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: EUR
# Variants with p-value < 0.05: (277, 13)
# WORKING ON: FIN
# Variants with p-value < 0.05: (41, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: MDE
# Variants with p-value < 0.05: (132, 13)
# WORKING ON: SAS
# Variants with p-value < 0.05: (20, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: CAH
# Variants with p-value < 0.05: (72, 13)
# /var/tmp/ipykernel_5192/3754789743.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# GLM

# %%
#Run case-control analysis with covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:

    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'

    ! /home/jupyter/tools/plink2 \
    --bfile {WORK_DIR}/{ancestry}_SCARB2 \
    --keep {WORK_DIR}/{ancestry}.samplestoKeep \
    --allow-no-sex \
    --maf 0.01 \
    --ci 0.95 \
    --glm \
    --covar {WORK_DIR}/{ancestry}_covariate_file.txt \
    --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
    --covar-variance-standardize \
    --neg9-pheno-really-missing \
    --out {WORK_DIR}/{ancestry}_SCARB2.all_adj
# Out:
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:42 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50235 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam.
# 3848 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --keep: 1111 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_covariate_file.txt.
# 1111 samples (656 females, 455 males; 1111 founders) remaining after main
# filters.
# 285 cases and 801 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2388 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1460 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:43 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:43 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50236 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam.
# 4304 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --keep: 2643 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_covariate_file.txt.
# 2643 samples (1163 females, 1480 males; 2643 founders) remaining after main
# filters.
# 942 cases and 1679 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2791 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1513 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:43 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:43 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50235 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam.
# 1849 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --keep: 2655 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_covariate_file.txt.
# 2655 samples (1007 females, 1648 males; 2655 founders) remaining after main
# filters.
# 1292 cases and 411 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 816 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1033 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:44 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:44 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50237 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam.
# 2516 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --keep: 646 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_covariate_file.txt.
# 646 samples (283 females, 363 males; 646 founders) remaining after main
# filters.
# 458 cases and 155 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1569 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 947 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:44 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:44 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50236 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam.
# 2219 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --keep: 903 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_covariate_file.txt.
# 903 samples (464 females, 439 males; 903 founders) remaining after main
# filters.
# 552 cases and 343 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1248 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 971 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:44 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:45 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50236 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam.
# 3094 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --keep: 5167 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_covariate_file.txt.
# 5167 samples (1889 females, 3278 males; 5167 founders) remaining after main
# filters.
# 2662 cases and 2461 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2143 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 951 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:45 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:45 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50254 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam.
# 9570 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --keep: 38838 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_covariate_file.txt.
# 38838 samples (15543 females, 23295 males; 38838 founders) remaining after main
# filters.
# 21197 cases and 9214 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 8651 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 919 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:46 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:47 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50237 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam.
# 1166 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --keep: 114 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_covariate_file.txt.
# 114 samples (61 females, 53 males; 114 founders) remaining after main filters.
# 98 cases and 8 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 226 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 940 variants remaining after main filters.
# Warning: --glm remaining control count is less than 10x predictor count for
# phenotype 'PHENO1'.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:47 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:47 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50237 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam.
# 2380 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --keep: 581 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_covariate_file.txt.
# 581 samples (212 females, 369 males; 581 founders) remaining after main
# filters.
# 311 cases and 225 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1367 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1013 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:47 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:48 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50235 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam.
# 2058 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --keep: 635 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_covariate_file.txt.
# 635 samples (227 females, 408 males; 635 founders) remaining after main
# filters.
# 387 cases and 222 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 1147 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 911 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:48 2024
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all_adj.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2
#   --ci 0.95
#   --covar /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_covariate_file.txt
#   --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5
#   --covar-variance-standardize
#   --glm
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.samplestoKeep
#   --maf 0.01
#   --neg9-pheno-really-missing
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all_adj
#
# Start time: Tue Aug 20 09:48:48 2024
# Note: --allow-no-sex no longer has any effect.  (Missing-sex samples are
# automatically excluded from association analysis when sex is a covariate, and
# treated normally otherwise.)
# 52223 MiB RAM detected, ~50237 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam.
# 3550 variants loaded from
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --keep: 851 samples remaining.
# 7 covariates loaded from /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_covariate_file.txt.
# 851 samples (405 females, 446 males; 851 founders) remaining after main
# filters.
# 525 cases and 302 controls remaining after main filters.
# --covar-variance-standardize: 7 covariates transformed.
# Calculating allele frequencies... done.
# 2257 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1293 variants remaining after main filters.
# --glm logistic-Firth hybrid regression on phenotype 'PHENO1': done.
# Results written to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.all_adj.PHENO1.glm.logistic.hybrid .
# End time: Tue Aug 20 09:48:48 2024

# %%
#Process results from plink glm analysis including covariates
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    print(f'WORKING ON: {ancestry}')
    
    #Read in plink glm results
    assoc = pd.read_csv(f'{WORK_DIR}/{ancestry}_SCARB2.all_adj.PHENO1.glm.logistic.hybrid', delim_whitespace=True)
    
    #Filter for additive test only - this is the variant results
    assoc_add = assoc[assoc['TEST']=="ADD"]
    
    #Check if there are any significant (p < 0.05) variants
    significant = assoc_add[assoc_add['P']<0.05]

    print(f'There are {len(significant)} variants with p-value < 0.05 in glm')
    
    #Check if there are any significant (p < 0.05) variants
    GWsignificant = assoc_add[assoc_add['P']<5e-8]

    print(f'There are {len(GWsignificant)} variants with p-value < 5e-8 in glm')
    
    #Save assoc_add to csv
    assoc_add.to_csv(f'{WORK_DIR}/{ancestry}.all_adj.csv')
# Out:
# WORKING ON: AAC
# There are 82 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: AFR
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 62 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: AJ
# There are 52 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: AMR
# There are 19 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: CAS
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 1 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: EAS
# There are 123 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: EUR
# There are 279 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: FIN
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# There are 21 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: MDE
# There are 58 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# WORKING ON: SAS
# There are 8 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# WORKING ON: CAH
# There are 104 variants with p-value < 0.05 in glm
# There are 0 variants with p-value < 5e-8 in glm
# /var/tmp/ipykernel_5192/882271930.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# change format of association file in EUR

# %%
WORK_DIR = "~/workspace/ws_files/SCARB2/"

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    WORK_DIR = "~/workspace/ws_files/SCARB2/"
    print(f'WORKING ON: {ancestry}')
    
    df = pd.read_csv(f'{WORK_DIR}/SCARB2_{ancestry}/{ancestry}.all_adj.csv')
    
    #First just select relevant columns: chromosome, bp position and p-value
    export_ldassoc = df[['#CHROM', 'POS', 'P']].copy()
    
    #Rename the #CHROM column to remove the hashtag as I think this might be confusing LDassoc
    export_ldassoc = export_ldassoc.rename(columns={'#CHROM': 'CHROM'}) 
    
    #Then export as a tab-separated, not comma-separated file

    export_ldassoc.to_csv(f'{WORK_DIR}/SCARB2_{ancestry}/{ancestry}.all_adj.formatted.tab', sep = '\t', index=False)
# Out:
# WORKING ON: AJ
# WORKING ON: EAS
# WORKING ON: SAS
# WORKING ON: AMR
# WORKING ON: MDE
# WORKING ON: CAH
# WORKING ON: FIN
# WORKING ON: CAS
# WORKING ON: AFR
# WORKING ON: EUR
# WORKING ON: AAC

# %% [markdown]
# GCTA conditional analysis

# %%
# prepare file for COJO
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    #Read in summary statistics
    sumstats = pd.read_csv(f'{WORK_DIR}/SCARB2_{ancestry}/{ancestry}.all_adj.csv')
    
    #Format summary statistics for GCTA-COJO
    #First get the log odds ratio - this is required for COJO
    #1) For a case-control study, the effect size should be log(odds ratio) with its corresponding standard error.
    sumstats_formatted = sumstats.copy()
    sumstats_formatted['b'] = np.log(sumstats_formatted['OR'])
    
    #Now select just the necessary columns for COJO
    sumstats_export = sumstats_formatted[['ID', 'A1', 'OMITTED', 'A1_FREQ', 'b', 'LOG(OR)_SE', 'P', 'OBS_CT']].copy()
    
    #Rename columns following COJO format
    sumstats_export = sumstats_export.rename(columns = {'ID':'SNP', 'OMITTED':'A2', 'A1_FREQ':'freq', 'LOG(OR)_SE':'se', 'P':'p', 'OBS_CT':'N'})
    
    #Export
    sumstats_export.to_csv(f'{WORK_DIR}/SCARB2_{ancestry}/{ancestry}.all_adj.sumstats.ma', sep = '\t', index=False)

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_SCARB2 \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 5e-8 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.COJO
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:43 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# 2655 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed] in SNP-major format ...
# Genotype data for 2655 individuals and 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1032 SNPs (817 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1033 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1033 SNPs: 7.65083 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1032 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1032 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:43 UTC on Tue Aug 20 2024
# Overall computational time: 0.34 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:43 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# 5167 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 5167 individuals and 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 951 SNPs (2143 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 951 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 951 SNPs: 5.17038 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 951 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 951 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:44 UTC on Tue Aug 20 2024
# Overall computational time: 0.51 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:44 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# 635 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 635 individuals and 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 911 SNPs (1147 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 911 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 911 SNPs: 5.52256 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 911 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 911 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:44 UTC on Tue Aug 20 2024
# Overall computational time: 0.22 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:44 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# 646 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed] in SNP-major format ...
# Genotype data for 646 individuals and 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 947 SNPs (1569 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 947 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 947 SNPs: 6.27 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 947 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 947 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:45 UTC on Tue Aug 20 2024
# Overall computational time: 0.19 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:45 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# 581 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed] in SNP-major format ...
# Genotype data for 581 individuals and 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1013 SNPs (1367 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1013 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1013 SNPs: 5.2279 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1013 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1013 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:45 UTC on Tue Aug 20 2024
# Overall computational time: 0.19 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:45 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# 851 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed] in SNP-major format ...
# Genotype data for 851 individuals and 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1289 SNPs (2261 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1293 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1293 SNPs: 5.49246 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1289 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1289 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:46 UTC on Tue Aug 20 2024
# Overall computational time: 0.24 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:46 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# 114 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed] in SNP-major format ...
# Genotype data for 114 individuals and 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 940 SNPs (226 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma] ...
# GWAS summary statistics of 940 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 940 SNPs: 10.5175 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 940 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 940 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:46 UTC on Tue Aug 20 2024
# Overall computational time: 0.19 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:46 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# 903 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 903 individuals and 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 971 SNPs (1248 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 971 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 971 SNPs: 5.10318 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 971 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 971 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:46 UTC on Tue Aug 20 2024
# Overall computational time: 0.22 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:47 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# 2643 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed] in SNP-major format ...
# Genotype data for 2643 individuals and 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1513 SNPs (2791 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1513 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1513 SNPs: 7.08346 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1513 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1513 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:47 UTC on Tue Aug 20 2024
# Overall computational time: 0.40 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:47 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# 38839 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed] in SNP-major format ...
# Genotype data for 38839 individuals and 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 919 SNPs (8651 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 919 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 919 SNPs: 5.22946 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 919 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 919 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:53 UTC on Tue Aug 20 2024
# Overall computational time: 5.85 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:23:53 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma
# --cojo-p 5e-08
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# 1111 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed] in SNP-major format ...
# Genotype data for 1111 individuals and 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1460 SNPs (2388 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1460 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1460 SNPs: 7.52793 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1460 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1460 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 10:23:53 UTC on Tue Aug 20 2024
# Overall computational time: 0.25 sec.

# %% [markdown]
# use p threshold(0.00238) from LD pruning

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_SCARB2 \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-p 3.5e-4 \
    --cojo-slct \
    --out {WORK_DIR}/{ancestry}.all_adj.LDprune.COJO
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:46 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# 851 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed] in SNP-major format ...
# Genotype data for 851 individuals and 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1289 SNPs (2261 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1293 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1293 SNPs: 5.49246 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1289 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1289 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:46 UTC on Tue Aug 20 2024
# Overall computational time: 0.26 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:46 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# 114 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed] in SNP-major format ...
# Genotype data for 114 individuals and 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 940 SNPs (226 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma] ...
# GWAS summary statistics of 940 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 940 SNPs: 10.5175 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 940 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 940 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:47 UTC on Tue Aug 20 2024
# Overall computational time: 0.16 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:47 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# 635 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 635 individuals and 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 911 SNPs (1147 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 911 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 911 SNPs: 5.52256 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 911 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 911 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:47 UTC on Tue Aug 20 2024
# Overall computational time: 0.28 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:47 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# 581 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed] in SNP-major format ...
# Genotype data for 581 individuals and 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1013 SNPs (1367 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1013 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1013 SNPs: 5.2279 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1013 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1013 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:48 UTC on Tue Aug 20 2024
# Overall computational time: 0.19 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:48 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# 1111 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed] in SNP-major format ...
# Genotype data for 1111 individuals and 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1460 SNPs (2388 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1460 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1460 SNPs: 7.52793 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1460 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1460 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:48 UTC on Tue Aug 20 2024
# Overall computational time: 0.26 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:48 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# 38839 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed] in SNP-major format ...
# Genotype data for 38839 individuals and 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 919 SNPs (8651 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 919 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 919 SNPs: 5.22946 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 919 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 919 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 1 associated SNPs are selected.
# Performing joint analysis on all the 1 selected signals ...
# Saving the 1 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.LDprune.COJO.jma.cojo] ...
# Saving the LD structure of 1 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.LDprune.COJO.ldr.cojo] ...
# Saving the conditional analysis results of 918 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.LDprune.COJO.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 14:22:55 UTC on Tue Aug 20 2024
# Overall computational time: 6.63 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:55 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# 5167 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 5167 individuals and 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 951 SNPs (2143 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 951 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 951 SNPs: 5.17038 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 951 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 951 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:56 UTC on Tue Aug 20 2024
# Overall computational time: 0.49 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:56 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# 646 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed] in SNP-major format ...
# Genotype data for 646 individuals and 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 947 SNPs (1569 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 947 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 947 SNPs: 6.27 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 947 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 947 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:56 UTC on Tue Aug 20 2024
# Overall computational time: 0.20 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:56 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# 2643 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed] in SNP-major format ...
# Genotype data for 2643 individuals and 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1513 SNPs (2791 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1513 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1513 SNPs: 7.08346 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1513 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1513 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:57 UTC on Tue Aug 20 2024
# Overall computational time: 0.39 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:57 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# 903 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 903 individuals and 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 971 SNPs (1248 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 971 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 971 SNPs: 5.10318 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 971 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 971 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:57 UTC on Tue Aug 20 2024
# Overall computational time: 0.24 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 14:22:57 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma
# --cojo-p 0.00035
# --cojo-slct
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.LDprune.COJO
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# 2655 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed] in SNP-major format ...
# Genotype data for 2655 individuals and 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1032 SNPs (817 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1033 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1033 SNPs: 7.65083 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1032 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1032 SNPs to select association signals ... (p cutoff = 0.00035; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# No SNPs have been selected.
#
# Analysis finished at 14:22:57 UTC on Tue Aug 20 2024
# Overall computational time: 0.28 sec.

# %%
ancestries = {'AAC','AFR','AJ','AMR','CAS','EAS','EUR','FIN','MDE','SAS','CAH'}

for ancestry in ancestries:
    
    WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
    
    #Select multiple associated SNPs based on significance p-value 5e-08
    #Can change the p-value for significance if needed
    #bfile is referring to the full dataset in plink binary format, e.g. GP2 - whatever you used to run the GWAS
    ! /home/jupyter/tools/gcta-1.94.1-linux-kernel-3-x86_64/gcta64 \
    --bfile {WORK_DIR}/{ancestry}_SCARB2 \
    --maf 0.01 \
    --cojo-file {WORK_DIR}/{ancestry}.all_adj.sumstats.ma \
    --cojo-top-SNPs 10 \
    --out {WORK_DIR}/{ancestry}.all_adj.top10
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:53 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# 2655 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed] in SNP-major format ...
# Genotype data for 2655 individuals and 1849 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1032 SNPs (817 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1033 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1033 SNPs: 7.65083 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1032 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 1032 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 1022 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:54 UTC on Tue Aug 20 2024
# Overall computational time: 1.21 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:54 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# 5167 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 5167 individuals and 3094 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 951 SNPs (2143 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 951 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 951 SNPs: 5.17038 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 951 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 951 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 941 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:56 UTC on Tue Aug 20 2024
# Overall computational time: 1.83 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:56 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# 635 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 635 individuals and 2058 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 911 SNPs (1147 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 911 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 911 SNPs: 5.52256 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 911 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 911 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 901 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:57 UTC on Tue Aug 20 2024
# Overall computational time: 0.64 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:57 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# 646 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed] in SNP-major format ...
# Genotype data for 646 individuals and 2516 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 947 SNPs (1569 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 947 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 947 SNPs: 6.27 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 947 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 947 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 937 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:58 UTC on Tue Aug 20 2024
# Overall computational time: 0.65 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:58 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# 581 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed] in SNP-major format ...
# Genotype data for 581 individuals and 2380 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1013 SNPs (1367 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1013 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1013 SNPs: 5.2279 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1013 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 1013 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 1003 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:58 UTC on Tue Aug 20 2024
# Overall computational time: 0.66 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:29:59 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# 851 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed] in SNP-major format ...
# Genotype data for 851 individuals and 3550 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1289 SNPs (2261 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1293 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1293 SNPs: 5.49246 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1289 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 1289 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 1279 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:29:59 UTC on Tue Aug 20 2024
# Overall computational time: 0.78 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:30:00 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# 114 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed] in SNP-major format ...
# Genotype data for 114 individuals and 1166 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 940 SNPs (226 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma] ...
# GWAS summary statistics of 940 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 940 SNPs: 10.5175 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 940 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 940 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 930 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:30:00 UTC on Tue Aug 20 2024
# Overall computational time: 0.62 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:30:00 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# 903 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed] in SNP-major format ...
# Genotype data for 903 individuals and 2219 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 971 SNPs (1248 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma] ...
# GWAS summary statistics of 971 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 971 SNPs: 5.10318 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 971 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 971 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 961 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:30:01 UTC on Tue Aug 20 2024
# Overall computational time: 0.87 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:30:02 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# 2643 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed] in SNP-major format ...
# Genotype data for 2643 individuals and 4304 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1513 SNPs (2791 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1513 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1513 SNPs: 7.08346 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1513 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 1513 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 1503 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:30:03 UTC on Tue Aug 20 2024
# Overall computational time: 1.58 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:30:03 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# 38839 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed] in SNP-major format ...
# Genotype data for 38839 individuals and 9570 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 919 SNPs (8651 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma] ...
# GWAS summary statistics of 919 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 919 SNPs: 5.22946 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 919 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 919 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 909 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:30:16 UTC on Tue Aug 20 2024
# Overall computational time: 12.43 sec.
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 10:30:16 UTC on Tue Aug 20 2024.
# Hostname: jupyterlabvertexai20240708
#
# Accepted options:
# --bfile /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2
# --maf 0.01
# --cojo-file /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma
# --cojo-top-SNPs 10
# --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.top10
#
#
# Reading PLINK FAM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# 1111 individuals to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.fam].
# Reading PLINK BIM file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bim].
# Reading PLINK BED file from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed] in SNP-major format ...
# Genotype data for 1111 individuals and 3848 SNPs to be included from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.bed].
# Calculating allele frequencies ...
# Filtering SNPs with MAF > 0.01 ...
# After filtering SNPs with MAF > 0.01, there are 1460 SNPs (2388 SNPs with MAF < 0.01).
#
# Reading GWAS summary-level statistics from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma] ...
# GWAS summary statistics of 1460 SNPs read from [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.sumstats.ma].
# Phenotypic variance estimated from summary statistics of all 1460 SNPs: 7.52793 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# 1460 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
# The threshold p-value has been set to 0.5 because of the --cojo-top-SNPs option.
#
# Performing stepwise model selection on 1460 SNPs to select association signals ... (p cutoff = 0.5; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Switched to perform a forward model selection because the significance level is too low...
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# Performing backward elimination...
# Finally, 10 associated SNPs are selected.
# Performing joint analysis on all the 10 selected signals ...
# Saving the 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.top10.jma.cojo] ...
# Saving the LD structure of 10 independent signals to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.top10.ldr.cojo] ...
# Saving the conditional analysis results of 1450 remaining SNPs to [/home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.all_adj.top10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 10:30:17 UTC on Tue Aug 20 2024
# Overall computational time: 1.09 sec.

# %% [markdown]
# Burden Analyses using RVTests

# %%
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

#Loop over all the ancestries and the 2 variant classes - run rvtests for all coding and missense variants
for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running plink to extract {variant_class} variants for ancestry: {ancestry}')
        
        #Extract relevant variants
        ! /home/jupyter/tools/plink2 \
        --pfile {REL7_PATH}/imputed_genotypes/{ancestry}/chr4_{ancestry}_release7_vwb \
        --keep {WORK_DIR}/{ancestry}.samplestoKeep \
        --extract range {WORK_DIR}/{ancestry}_SCARB2.{variant_class}.variantstoKeep.txt \
        --recode vcf-iid \
        --out {WORK_DIR}/{ancestry}_SCARB2.{variant_class}
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running bgzip and tabix for {variant_class} variants for ancestry: {ancestry}')
        
        ## Bgzip and Tabix (zip and index the file)
        ! bgzip -f {WORK_DIR}/{ancestry}_SCARB2.{variant_class}.vcf
        ! tabix -f -p vcf {WORK_DIR}/{ancestry}_SCARB2.{variant_class}.vcf.gz
# Out:
# Running plink to extract exonic variants for ancestry: AAC
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb
#
# Start time: Mon Jul 29 15:19:25 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50656 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.psam.
# 3986699 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.pvar.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --extract bed1: 3986640 variants excluded.
# --keep: 1111 samples remaining.
# 1111 samples (656 females, 455 males; 1111 founders) remaining after main
# filters.
# 285 cases and 801 controls remaining after main filters.
# 59 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.exonic.vcf ...
# 1011131516182022232527283032333537384042444547495052545557596162646667697172747677798183848688899193949698done.
# End time: Mon Jul 29 15:19:26 2024
# Running bgzip and tabix for exonic variants for ancestry: AAC
# Running plink to extract nonsynonymous_lof variants for ancestry: AAC
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb
#
# Start time: Mon Jul 29 15:19:26 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50617 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1111 samples (656 females, 455 males; 1111 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.psam.
# 3986699 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AAC/chr4_AAC_release7_vwb.pvar.
# 1 binary phenotype loaded (285 cases, 801 controls).
# --extract bed1: 3986664 variants excluded.
# --keep: 1111 samples remaining.
# 1111 samples (656 females, 455 males; 1111 founders) remaining after main
# filters.
# 285 cases and 801 controls remaining after main filters.
# 35 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AAC/AAC_SCARB2.nonsynonymous_lof.vcf
# ... 11141720222528313437404245485154576062656871747780828588919497done.
# End time: Mon Jul 29 15:19:27 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AAC
# Running plink to extract exonic variants for ancestry: AFR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb
#
# Start time: Mon Jul 29 15:19:28 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50623 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.psam.
# 4555051 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.pvar.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --extract bed1: 4554988 variants excluded.
# --keep: 2643 samples remaining.
# 2643 samples (1163 females, 1480 males; 2643 founders) remaining after main
# filters.
# 942 cases and 1679 controls remaining after main filters.
# 63 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.exonic.vcf ...
# 1112141517192022232526283031333436383941424446474950525355575860616365666869717374767779808284858788909293959698done.
# End time: Mon Jul 29 15:19:29 2024
# Running bgzip and tabix for exonic variants for ancestry: AFR
# Running plink to extract nonsynonymous_lof variants for ancestry: AFR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb
#
# Start time: Mon Jul 29 15:19:30 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50623 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2643 samples (1163 females, 1480 males; 2643 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.psam.
# 4555051 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AFR/chr4_AFR_release7_vwb.pvar.
# 1 binary phenotype loaded (942 cases, 1679 controls).
# --extract bed1: 4555014 variants excluded.
# --keep: 2643 samples remaining.
# 2643 samples (1163 females, 1480 males; 2643 founders) remaining after main
# filters.
# 942 cases and 1679 controls remaining after main filters.
# 37 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AFR/AFR_SCARB2.nonsynonymous_lof.vcf
# ... 101316182124272932353740434548515456596264677072757881838689919497done.
# End time: Mon Jul 29 15:19:31 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AFR
# Running plink to extract exonic variants for ancestry: AJ
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb
#
# Start time: Mon Jul 29 15:19:32 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50622 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.psam.
# 1669760 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.pvar.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --extract bed1: 1669729 variants excluded.
# --keep: 2655 samples remaining.
# 2655 samples (1007 females, 1648 males; 2655 founders) remaining after main
# filters.
# 1292 cases and 411 controls remaining after main filters.
# 31 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.exonic.vcf ...
# 121619222529323538414548515458616467707477808387909396done.
# End time: Mon Jul 29 15:19:33 2024
# Running bgzip and tabix for exonic variants for ancestry: AJ
# Running plink to extract nonsynonymous_lof variants for ancestry: AJ
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb
#
# Start time: Mon Jul 29 15:19:34 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50617 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2655 samples (1007 females, 1648 males; 2655 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.psam.
# 1669760 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AJ/chr4_AJ_release7_vwb.pvar.
# 1 binary phenotype loaded (1292 cases, 411 controls).
# --extract bed1: 1669741 variants excluded.
# --keep: 2655 samples remaining.
# 2655 samples (1007 females, 1648 males; 2655 founders) remaining after main
# filters.
# 1292 cases and 411 controls remaining after main filters.
# 19 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AJ/AJ_SCARB2.nonsynonymous_lof.vcf
# ... 1015212631364247525763687378848994done.
# End time: Mon Jul 29 15:19:34 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AJ
# Running plink to extract exonic variants for ancestry: AMR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb
#
# Start time: Mon Jul 29 15:19:35 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50618 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.psam.
# 2407746 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.pvar.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --extract bed1: 2407703 variants excluded.
# --keep: 646 samples remaining.
# 646 samples (283 females, 363 males; 646 founders) remaining after main
# filters.
# 458 cases and 155 controls remaining after main filters.
# 43 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.exonic.vcf ...
# 1113161820232527303234373941444648515355586062656769727476798183868890939597done.
# End time: Mon Jul 29 15:19:36 2024
# Running bgzip and tabix for exonic variants for ancestry: AMR
# Running plink to extract nonsynonymous_lof variants for ancestry: AMR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb
#
# Start time: Mon Jul 29 15:19:37 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50617 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 646 samples (283 females, 363 males; 646 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.psam.
# 2407746 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/AMR/chr4_AMR_release7_vwb.pvar.
# 1 binary phenotype loaded (458 cases, 155 controls).
# --extract bed1: 2407717 variants excluded.
# --keep: 646 samples remaining.
# 646 samples (283 females, 363 males; 646 founders) remaining after main
# filters.
# 458 cases and 155 controls remaining after main filters.
# 29 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_AMR/AMR_SCARB2.nonsynonymous_lof.vcf
# ... 1013172024273134374144485155586265687275798286899396done.
# End time: Mon Jul 29 15:19:37 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: AMR
# Running plink to extract exonic variants for ancestry: CAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:38 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50616 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.psam.
# 2200655 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.pvar.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --extract bed1: 2200619 variants excluded.
# --keep: 903 samples remaining.
# 903 samples (464 females, 439 males; 903 founders) remaining after main
# filters.
# 552 cases and 343 controls remaining after main filters.
# 36 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.exonic.vcf ...
# 1113161922252730333638414447505255586163666972757780838688919497done.
# End time: Mon Jul 29 15:19:39 2024
# Running bgzip and tabix for exonic variants for ancestry: CAS
# Running plink to extract nonsynonymous_lof variants for ancestry: CAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:40 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50617 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 903 samples (464 females, 439 males; 903 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.psam.
# 2200655 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAS/chr4_CAS_release7_vwb.pvar.
# 1 binary phenotype loaded (552 cases, 343 controls).
# --extract bed1: 2200633 variants excluded.
# --keep: 903 samples remaining.
# 903 samples (464 females, 439 males; 903 founders) remaining after main
# filters.
# 552 cases and 343 controls remaining after main filters.
# 22 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAS/CAS_SCARB2.nonsynonymous_lof.vcf
# ... 13182227313640455054596368727781869095done.
# End time: Mon Jul 29 15:19:41 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAS
# Running plink to extract exonic variants for ancestry: EAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:41 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50606 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.psam.
# 3235052 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.pvar.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --extract bed1: 3234995 variants excluded.
# --keep: 5167 samples remaining.
# 5167 samples (1889 females, 3278 males; 5167 founders) remaining after main
# filters.
# 2662 cases and 2461 controls remaining after main filters.
# 57 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.exonic.vcf ...
# 101214151719212224262829313335363840424345474950525456575961636466687071737577788082848587899192949698done.
# End time: Mon Jul 29 15:19:42 2024
# Running bgzip and tabix for exonic variants for ancestry: EAS
# Running plink to extract nonsynonymous_lof variants for ancestry: EAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:43 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50615 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5167 samples (1889 females, 3278 males; 5167 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.psam.
# 3235052 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EAS/chr4_EAS_release7_vwb.pvar.
# 1 binary phenotype loaded (2662 cases, 2461 controls).
# --extract bed1: 3235016 variants excluded.
# --keep: 5167 samples remaining.
# 5167 samples (1889 females, 3278 males; 5167 founders) remaining after main
# filters.
# 2662 cases and 2461 controls remaining after main filters.
# 36 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EAS/EAS_SCARB2.nonsynonymous_lof.vcf
# ... 1113161922252730333638414447505255586163666972757780838688919497done.
# End time: Mon Jul 29 15:19:44 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EAS
# Running plink to extract exonic variants for ancestry: EUR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb
#
# Start time: Mon Jul 29 15:19:45 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50613 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.psam.
# 10419161 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.pvar.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --extract bed1: 10418969 variants excluded.
# --keep: 38838 samples remaining.
# 38838 samples (15543 females, 23295 males; 38838 founders) remaining after main
# filters.
# 21197 cases and 9214 controls remaining after main filters.
# 192 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.exonic.vcf ...
# .
# End time: Mon Jul 29 15:19:47 2024
# Running bgzip and tabix for exonic variants for ancestry: EUR
# Running plink to extract nonsynonymous_lof variants for ancestry: EUR
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb
#
# Start time: Mon Jul 29 15:19:48 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50595 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 38839 samples (15543 females, 23296 males; 38839 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.psam.
# 10419161 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/EUR/chr4_EUR_release7_vwb.pvar.
# 1 binary phenotype loaded (21198 cases, 9214 controls).
# --extract bed1: 10419026 variants excluded.
# --keep: 38838 samples remaining.
# 38838 samples (15543 females, 23295 males; 38838 founders) remaining after main
# filters.
# 21197 cases and 9214 controls remaining after main filters.
# 135 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_EUR/EUR_SCARB2.nonsynonymous_lof.vcf
# ... 10111112131414151617171819202021222223242525262728282930313132333434353637373839404041424243444545464748484950515152535454555657575859606061626263646565666768686970717172737474757677777879808081828283848585868788888990919192939494959697979899done.
# End time: Mon Jul 29 15:19:50 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: EUR
# Running plink to extract exonic variants for ancestry: FIN
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb
#
# Start time: Mon Jul 29 15:19:51 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50596 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.psam.
# 891614 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.pvar.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --extract bed1: 891598 variants excluded.
# --keep: 114 samples remaining.
# 114 samples (61 females, 53 males; 114 founders) remaining after main filters.
# 98 cases and 8 controls remaining after main filters.
# 16 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.exonic.vcf ...
# 1218253137435056626875818793done.
# End time: Mon Jul 29 15:19:52 2024
# Running bgzip and tabix for exonic variants for ancestry: FIN
# Running plink to extract nonsynonymous_lof variants for ancestry: FIN
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb
#
# Start time: Mon Jul 29 15:19:53 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50597 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 114 samples (61 females, 53 males; 114 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.psam.
# 891614 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/FIN/chr4_FIN_release7_vwb.pvar.
# 1 binary phenotype loaded (98 cases, 8 controls).
# --extract bed1: 891604 variants excluded.
# --keep: 114 samples remaining.
# 114 samples (61 females, 53 males; 114 founders) remaining after main filters.
# 98 cases and 8 controls remaining after main filters.
# 10 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_FIN/FIN_SCARB2.nonsynonymous_lof.vcf
# ... 102030405060708090done.
# End time: Mon Jul 29 15:19:53 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: FIN
# Running plink to extract exonic variants for ancestry: MDE
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb
#
# Start time: Mon Jul 29 15:19:54 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50598 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.psam.
# 2161336 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.pvar.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --extract bed1: 2161300 variants excluded.
# --keep: 581 samples remaining.
# 581 samples (212 females, 369 males; 581 founders) remaining after main
# filters.
# 311 cases and 225 controls remaining after main filters.
# 36 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.exonic.vcf ...
# 1113161922252730333638414447505255586163666972757780838688919497done.
# End time: Mon Jul 29 15:19:55 2024
# Running bgzip and tabix for exonic variants for ancestry: MDE
# Running plink to extract nonsynonymous_lof variants for ancestry: MDE
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb
#
# Start time: Mon Jul 29 15:19:56 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50606 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 581 samples (212 females, 369 males; 581 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.psam.
# 2161336 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/MDE/chr4_MDE_release7_vwb.pvar.
# 1 binary phenotype loaded (311 cases, 225 controls).
# --extract bed1: 2161310 variants excluded.
# --keep: 581 samples remaining.
# 581 samples (212 females, 369 males; 581 founders) remaining after main
# filters.
# 311 cases and 225 controls remaining after main filters.
# 26 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_MDE/MDE_SCARB2.nonsynonymous_lof.vcf
# ... 1115192326303438424650535761656973768084889296done.
# End time: Mon Jul 29 15:19:56 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: MDE
# Running plink to extract exonic variants for ancestry: SAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:57 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50596 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.psam.
# 1933318 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.pvar.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --extract bed1: 1933284 variants excluded.
# --keep: 635 samples remaining.
# 635 samples (227 females, 408 males; 635 founders) remaining after main
# filters.
# 387 cases and 222 controls remaining after main filters.
# 34 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.exonic.vcf ...
# 111417202326293235384144475052555861646770737679828588919497done.
# End time: Mon Jul 29 15:19:58 2024
# Running bgzip and tabix for exonic variants for ancestry: SAS
# Running plink to extract nonsynonymous_lof variants for ancestry: SAS
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb
#
# Start time: Mon Jul 29 15:19:58 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50596 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 635 samples (227 females, 408 males; 635 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.psam.
# 1933318 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/SAS/chr4_SAS_release7_vwb.pvar.
# 1 binary phenotype loaded (387 cases, 222 controls).
# --extract bed1: 1933299 variants excluded.
# --keep: 635 samples remaining.
# 635 samples (227 females, 408 males; 635 founders) remaining after main
# filters.
# 387 cases and 222 controls remaining after main filters.
# 19 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_SAS/SAS_SCARB2.nonsynonymous_lof.vcf
# ... 1015212631364247525763687378848994done.
# End time: Mon Jul 29 15:19:59 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: SAS
# Running plink to extract exonic variants for ancestry: CAH
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.exonic.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.exonic.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.exonic
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb
#
# Start time: Mon Jul 29 15:20:00 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50596 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.psam.
# 3678288 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.pvar.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --extract bed1: 3678236 variants excluded.
# --keep: 851 samples remaining.
# 851 samples (405 females, 446 males; 851 founders) remaining after main
# filters.
# 525 cases and 302 controls remaining after main filters.
# 52 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.exonic.vcf ...
# 11131517192123252628303234363840424446485051535557596163656769717375767880828486889092949698done.
# End time: Mon Jul 29 15:20:01 2024
# Running bgzip and tabix for exonic variants for ancestry: CAH
# Running plink to extract nonsynonymous_lof variants for ancestry: CAH
# PLINK v2.00a6LM 64-bit Intel (4 Jul 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.nonsynonymous_lof.log.
# Options in effect:
#   --export vcf-iid
#   --extract range /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.nonsynonymous_lof.variantstoKeep.txt
#   --keep /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH.samplestoKeep
#   --out /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.nonsynonymous_lof
#   --pfile /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb
#
# Start time: Mon Jul 29 15:20:02 2024
# Note: --export 'vcf-iid' modifier is deprecated.  Use 'vcf' + 'id-paste=iid'.
# 52223 MiB RAM detected, ~50580 available; reserving 26111 MiB for main
# workspace.
# Using up to 8 compute threads.
# 851 samples (405 females, 446 males; 851 founders) loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.psam.
# 3678288 variants loaded from
# /home/jupyter/workspace/gp2_tier2_eu_release7_30042024/imputed_genotypes/CAH/chr4_CAH_release7_vwb.pvar.
# 1 binary phenotype loaded (525 cases, 302 controls).
# --extract bed1: 3678258 variants excluded.
# --keep: 851 samples remaining.
# 851 samples (405 females, 446 males; 851 founders) remaining after main
# filters.
# 525 cases and 302 controls remaining after main filters.
# 30 variants remaining after main filters.
# --export vcf to
# /home/jupyter/workspace/ws_files/SCARB2/SCARB2_CAH/CAH_SCARB2.nonsynonymous_lof.vcf
# ... 101316202326303336404346505356606366707376808386909396done.
# End time: Mon Jul 29 15:20:02 2024
# Running bgzip and tabix for nonsynonymous_lof variants for ancestry: CAH

# %%
#Run RVtests
ancestries = ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'FIN', 'MDE', 'SAS', 'CAH']
variant_classes = ['exonic', 'nonsynonymous_lof']

for ancestry in ancestries:
    for variant_class in variant_classes:
        
        WORK_DIR = f'~/workspace/ws_files/SCARB2/SCARB2_{ancestry}'
        
        # Print the command to be executed (for debugging purposes)
        print(f'Running RVtests for {variant_class} variants for ancestry: {ancestry}')
        
        ## RVtests with covariates 
        #Make sure the pheno and covariate file starts with the first 5 columsn: fid, iid, fatid, matid, sex
        #The pheno-name flag only works when the pheno/covar file is structured properly
        ! /home/jupyter/tools/rvtests/executable/rvtest --noweb --hide-covar \
        --out {WORK_DIR}/{ancestry}_SCARB2.burden.{variant_class} \
        --kernel skat,skato \
        --inVcf {WORK_DIR}/{ancestry}_SCARB2.{variant_class}.vcf.gz \
        --pheno {WORK_DIR}/{ancestry}_covariate_file.txt \
        --pheno-name PHENO \
        --gene SCARB2 \
        --geneFile ~/workspace/ws_files/TMEM175/refFlat.txt \
        --covar {WORK_DIR}/{ancestry}_covariate_file.txt \
        --covar-name SEX,AGE,PC1,PC2,PC3,PC4,PC5 \
        --freqUpper 0.01

# %% [markdown]
# EUR

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	20918	64	43	8475.92	0.891794	10000	1109	8475.92	1000	0	0.901713

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	20918	64	43	892.339	1	1

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	20918	43	26	3091.69	0.731763	10000	1389	3091.69	1000	0	0.719942

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EUR/EUR_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	20918	43	26	4256.15	1	0.345116

# %% [markdown]
# AAC

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AAC/AAC_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	925	20	16	626.538	0.971408	10000	1062	626.538	1000	0	0.94162

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AAC/AAC_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	925	20	16	473.593	1	0.719617

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AAC/AAC_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	925	11	9	547.367	0.85572	10000	1263	547.367	1000	0	0.791766

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AAC/AAC_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	925	11	9	462.384	1	0.638153

# %% [markdown]
# AFR

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AFR/AFR_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1062	17	12	2540.23	0.518996	10000	1937	2540.23	1000	0	0.516262

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AFR/AFR_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1062	17	12	1066.59	1	0.590661

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AFR/AFR_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1062	9	6	2386.29	0.293053	10000	4078	2386.29	1000	0	0.245218

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AFR/AFR_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1062	9	6	1141.95	0.6	0.402744

# %% [markdown]
# AJ

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AJ/AJ_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1410	5	3	187.979	0.360916	10000	3606	187.979	1000	0	0.277316

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AJ/AJ_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1410	5	3	NA	NA	NA

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AJ/AJ_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1410	4	2	187.979	0.360916	10000	3606	187.979	1000	0	0.277316

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AJ/AJ_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	1410	4	2	NA	NA	NA

# %% [markdown]
# AMR

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AMR/AMR_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	447	15	5	76.8106	0.466648	10000	1730	76.8106	1000	0	0.578035

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AMR/AMR_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	447	15	5	38.4053	0.1	0.466649

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AMR/AMR_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	447	11	4	0	-nan	10000	1000	0	0	1000	0.5

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_AMR/AMR_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	447	11	4	NA	NA	NA

# %% [markdown]
# CAH

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAH/CAH_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	693	15	10	4916.94	0.185781	10000	6012	4916.94	1000	0	0.166334

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAH/CAH_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	693	15	10	2458.47	0	0.300097

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAH/CAH_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	693	8	6	1734.19	0.428815	10000	2561	1734.19	1000	0	0.390472

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAH/CAH_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	693	8	6	867.093	0	0.581358

# %% [markdown]
# CAS

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAS/CAS_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	658	10	7	1034.61	0.149244	10000	8942	1034.61	1000	0	0.111832

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAS/CAS_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	658	10	7	517.304	0	0.233515

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAS/CAS_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	658	7	4	53.0168	0.514372	10000	1537	53.0168	1000	0	0.650618

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_CAS/CAS_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	658	7	4	26.5084	0.4	0.517254

# %% [markdown]
# EAS

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EAS/EAS_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	2523	17	12	3848.26	0.728263	10000	1379	3848.26	1000	0	0.725163

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EAS/EAS_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	2523	17	12	2026.13	1	0.666468

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EAS/EAS_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	2523	12	9	4024.31	0.60396	10000	1692	4024.31	1000	0	0.591017

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_EAS/EAS_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	2523	12	9	3800.46	1	0.447802

# %% [markdown]
# FIN

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_FIN/FIN_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_FIN/FIN_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_FIN/FIN_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_FIN/FIN_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue

# %% [markdown]
# MDE

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_MDE/MDE_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	379	10	5	243.498	0.489121	10000	1430	243.498	1000	0	0.699301

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_MDE/MDE_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	379	10	5	274.609	1	0.276794

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_MDE/MDE_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	379	7	3	183.965	0.361618	10000	1971	183.965	1000	0	0.507357

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_MDE/MDE_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	379	7	3	123.624	1	0.350369

# %% [markdown]
# SAS

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_SAS/SAS_SCARB2.burden.exonic.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	296	9	3	464.996	0.0027725	10000	10000	464.996	128	37	0.01465

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_SAS/SAS_SCARB2.burden.exonic.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	296	9	3	NA	NA	NA

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_SAS/SAS_SCARB2.burden.nonsynonymous_lof.Skat.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	Pvalue	NumPerm	ActualPerm	Stat	NumGreater	NumEqual	PermPvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	296	6	2	464.996	0.0027725	10000	10000	464.996	128	37	0.01465

# %%
#Check EUR all_coding variant results
! cat {WORK_DIR}/SCARB2_SAS/SAS_SCARB2.burden.nonsynonymous_lof.SkatO.assoc
# Out:
# Gene	RANGE	N_INFORMATIVE	NumVar	NumPolyVar	Q	rho	Pvalue
# SCARB2	4:76158738-76213824,4:76158738-76213824	296	6	2	232.498	0	0.000884866
